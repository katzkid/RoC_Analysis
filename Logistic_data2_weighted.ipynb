# %% [markdown]
# ### Import

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        y_prob = clf_model.predict_proba(X_test)[:, 1]
        y_pred = (y_prob >= threshold).astype(int)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data2")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Regular training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = LogisticRegression(fit_intercept=True)
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "Logistic Regression", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Weighted ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds
# Weight the X_train and y_train for cost-sensitive learning
minority_class_weight = np.arange(0.001, 0.999, 0.01)
majority_class_weight = 1.0 - minority_class_weight
list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    for w in minority_class_weight:
        class_weights = {0: 1 - w, 1: w}

        clf_weighted = LogisticRegression(fit_intercept=True, class_weight=class_weights)
        clf_weighted.fit(X_train_fold, y_train_fold)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# --- Starting Fold 2/4 ---
# --- Starting Fold 3/4 ---
# --- Starting Fold 4/4 ---

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Save the data
save_to_pickle(list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader, filename='pickle/Logistic_data2_weighted.pkl')
# Out:
# Data saved to pickle/Logistic_data2_weighted.pkl
# {'best_models': [[{'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.4672131147540984),
#     'threshold': np.float64(0.045788489932194684)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.0078125),
#     'tpr': np.float64(0.48360655737704916),
#     'threshold': np.float64(0.044969319950973884)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.015625),
#     'tpr': np.float64(0.4918032786885246),
#     'threshold': np.float64(0.04174455604642682)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.969),
#                                      1: np.float64(0.030999999999999996)}),
#     'fpr': np.float64(0.0234375),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.11653126857236185)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.9490000000000001),
#                                      1: np.float64(0.05099999999999999)}),
#     'fpr': np.float64(0.03125),
#     'tpr': np.float64(0.5163934426229508),
#     'threshold': np.float64(0.15987615409348385)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.929), 1: np.float64(0.071)}),
#     'fpr': np.float64(0.0390625),
#     'tpr': np.float64(0.5245901639344263),
#     'threshold': np.float64(0.20057616228405764)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.046875),
#     'tpr': np.float64(0.5327868852459017),
#     'threshold': np.float64(0.0314711839961933)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.959),
#                                      1: np.float64(0.040999999999999995)}),
#     'fpr': np.float64(0.0546875),
#     'tpr': np.float64(0.5409836065573771),
#     'threshold': np.float64(0.11529556513412335)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.959),
#                                      1: np.float64(0.040999999999999995)}),
#     'fpr': np.float64(0.0703125),
#     'tpr': np.float64(0.5491803278688525),
#     'threshold': np.float64(0.10798534957204994)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.9390000000000001),
#                                      1: np.float64(0.06099999999999999)}),
#     'fpr': np.float64(0.0859375),
#     'tpr': np.float64(0.5573770491803278),
#     'threshold': np.float64(0.15247926834455808)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}),
#     'fpr': np.float64(0.109375),
#     'tpr': np.float64(0.5655737704918032),
#     'threshold': np.float64(0.0013598495734208006)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.12333333333333334),
#     'tpr': np.float64(0.5733333333333334),
#     'threshold': np.float64(0.6128107468526331)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.13333333333333333),
#     'tpr': np.float64(0.5966666666666667),
#     'threshold': np.float64(0.5921121500909501)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.14),
#     'tpr': np.float64(0.6066666666666667),
#     'threshold': np.float64(0.5893643085997512)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15),
#     'tpr': np.float64(0.6166666666666667),
#     'threshold': np.float64(0.5737868356967218)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.6633333333333333),
#     'threshold': np.float64(0.5425752171226073)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.19333333333333333),
#     'tpr': np.float64(0.6666666666666666),
#     'threshold': np.float64(0.5386871765592103)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.4990000000000001),
#                                      1: np.float64(0.5009999999999999)}),
#     'fpr': np.float64(0.1953125),
#     'tpr': np.float64(0.6721311475409836),
#     'threshold': np.float64(0.6092073470009635)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.2),
#     'tpr': np.float64(0.6733333333333333),
#     'threshold': np.float64(0.529011807242643)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5190000000000001),
#                                      1: np.float64(0.4809999999999999)}),
#     'fpr': np.float64(0.203125),
#     'tpr': np.float64(0.7131147540983607),
#     'threshold': np.float64(0.5376213695083816)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.4990000000000001),
#                                      1: np.float64(0.5009999999999999)}),
#     'fpr': np.float64(0.2109375),
#     'tpr': np.float64(0.7213114754098361),
#     'threshold': np.float64(0.5538995461757676)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.3590000000000001),
#                                      1: np.float64(0.6409999999999999)}),
#     'fpr': np.float64(0.21875),
#     'tpr': np.float64(0.7459016393442623),
#     'threshold': np.float64(0.6916227853215221)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.2490000000000001),
#                                      1: np.float64(0.7509999999999999)}),
#     'fpr': np.float64(0.234375),
#     'tpr': np.float64(0.7540983606557377),
#     'threshold': np.float64(0.7910081044745247)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.2590000000000001),
#                                      1: np.float64(0.7409999999999999)}),
#     'fpr': np.float64(0.25),
#     'tpr': np.float64(0.7868852459016393),
#     'threshold': np.float64(0.769751097564878)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.27900000000000014),
#                                      1: np.float64(0.7209999999999999)}),
#     'fpr': np.float64(0.2734375),
#     'tpr': np.float64(0.7950819672131147),
#     'threshold': np.float64(0.7261980902959815)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.20900000000000007),
#                                      1: np.float64(0.7909999999999999)}),
#     'fpr': np.float64(0.28125),
#     'tpr': np.float64(0.819672131147541),
#     'threshold': np.float64(0.7996167374476566)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.14900000000000013),
#                                      1: np.float64(0.8509999999999999)}),
#     'fpr': np.float64(0.3125),
#     'tpr': np.float64(0.8278688524590164),
#     'threshold': np.float64(0.8589723901679819)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.21900000000000008),
#                                      1: np.float64(0.7809999999999999)}),
#     'fpr': np.float64(0.3203125),
#     'tpr': np.float64(0.8360655737704918),
#     'threshold': np.float64(0.7724340681039478)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.2290000000000001),
#                                      1: np.float64(0.7709999999999999)}),
#     'fpr': np.float64(0.328125),
#     'tpr': np.float64(0.8524590163934426),
#     'threshold': np.float64(0.7481183013432278)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.15900000000000014),
#                                      1: np.float64(0.8409999999999999)}),
#     'fpr': np.float64(0.3359375),
#     'tpr': np.float64(0.8688524590163934),
#     'threshold': np.float64(0.8153279366912454)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.14900000000000013),
#                                      1: np.float64(0.8509999999999999)}),
#     'fpr': np.float64(0.34375),
#     'tpr': np.float64(0.8770491803278688),
#     'threshold': np.float64(0.8263377976420437)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.09900000000000009),
#                                      1: np.float64(0.9009999999999999)}),
#     'fpr': np.float64(0.3515625),
#     'tpr': np.float64(0.8852459016393442),
#     'threshold': np.float64(0.8856844867020394)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.2290000000000001),
#                                      1: np.float64(0.7709999999999999)}),
#     'fpr': np.float64(0.359375),
#     'tpr': np.float64(0.9016393442622951),
#     'threshold': np.float64(0.7089588431552363)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.14900000000000013),
#                                      1: np.float64(0.8509999999999999)}),
#     'fpr': np.float64(0.3984375),
#     'tpr': np.float64(0.9098360655737705),
#     'threshold': np.float64(0.7760599183519522)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.4140625),
#     'tpr': np.float64(0.9426229508196722),
#     'threshold': np.float64(0.9632401587426281)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.039000000000000146),
#                                      1: np.float64(0.9609999999999999)}),
#     'fpr': np.float64(0.421875),
#     'tpr': np.float64(0.9508196721311475),
#     'threshold': np.float64(0.92470406565256)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.4453125),
#     'tpr': np.float64(0.9672131147540983),
#     'threshold': np.float64(0.9576634810592565)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.4609375),
#     'tpr': np.float64(0.9754098360655737),
#     'threshold': np.float64(0.951719966676109)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.4765625),
#     'tpr': np.float64(0.9836065573770492),
#     'threshold': np.float64(0.9484355720456772)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.009000000000000119),
#                                      1: np.float64(0.9909999999999999)}),
#     'fpr': np.float64(0.4921875),
#     'tpr': np.float64(0.9918032786885246),
#     'threshold': np.float64(0.9723306147949512)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.07900000000000018),
#                                      1: np.float64(0.9209999999999998)}),
#     'fpr': np.float64(0.6328125),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.521926365985402)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.44696969696969696),
#     'threshold': np.float64(0.045235389255799965)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.00847457627118644),
#     'tpr': np.float64(0.45454545454545453),
#     'threshold': np.float64(0.03575408767127088)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.01694915254237288),
#     'tpr': np.float64(0.4696969696969697),
#     'threshold': np.float64(0.03372040293248418)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.03389830508474576),
#     'tpr': np.float64(0.4772727272727273),
#     'threshold': np.float64(0.032197853735745255)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.05084745762711865),
#     'tpr': np.float64(0.5378787878787878),
#     'threshold': np.float64(0.026914004672355676)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.979),
#                                      1: np.float64(0.020999999999999998)}),
#     'fpr': np.float64(0.059322033898305086),
#     'tpr': np.float64(0.5454545454545454),
#     'threshold': np.float64(0.051498382220935744)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.9490000000000001),
#                                      1: np.float64(0.05099999999999999)}),
#     'fpr': np.float64(0.0847457627118644),
#     'tpr': np.float64(0.5606060606060606),
#     'threshold': np.float64(0.10006448983923882)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.1016949152542373),
#     'tpr': np.float64(0.5681818181818182),
#     'threshold': np.float64(0.019668560950492662)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.9490000000000001),
#                                      1: np.float64(0.05099999999999999)}),
#     'fpr': np.float64(0.11016949152542373),
#     'tpr': np.float64(0.5757575757575758),
#     'threshold': np.float64(0.08687148305078479)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.899),
#                                      1: np.float64(0.10099999999999998)}),
#     'fpr': np.float64(0.11864406779661017),
#     'tpr': np.float64(0.5909090909090909),
#     'threshold': np.float64(0.15460481951223076)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}),
#     'fpr': np.float64(0.1271186440677966),
#     'tpr': np.float64(0.5984848484848485),
#     'threshold': np.float64(0.0012353915149061665)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}),
#     'fpr': np.float64(0.13559322033898305),
#     'tpr': np.float64(0.6060606060606061),
#     'threshold': np.float64(0.001220015592999984)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.14),
#     'tpr': np.float64(0.6066666666666667),
#     'threshold': np.float64(0.5893643085997512)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}),
#     'fpr': np.float64(0.1440677966101695),
#     'tpr': np.float64(0.6287878787878788),
#     'threshold': np.float64(0.001187410767455153)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.6633333333333333),
#     'threshold': np.float64(0.5425752171226073)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.759),
#                                      1: np.float64(0.24099999999999996)}),
#     'fpr': np.float64(0.1864406779661017),
#     'tpr': np.float64(0.6818181818181818),
#     'threshold': np.float64(0.2653162650002807)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.979),
#                                      1: np.float64(0.020999999999999998)}),
#     'fpr': np.float64(0.2033898305084746),
#     'tpr': np.float64(0.6893939393939394),
#     'threshold': np.float64(0.021593350849465603)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21),
#     'tpr': np.float64(0.7),
#     'threshold': np.float64(0.5138248258215651)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.969),
#                                      1: np.float64(0.030999999999999996)}),
#     'fpr': np.float64(0.211864406779661),
#     'tpr': np.float64(0.7045454545454546),
#     'threshold': np.float64(0.029716683834578764)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.9390000000000001),
#                                      1: np.float64(0.06099999999999999)}),
#     'fpr': np.float64(0.22033898305084745),
#     'tpr': np.float64(0.7121212121212122),
#     'threshold': np.float64(0.05034981488309751)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.629),
#                                      1: np.float64(0.37099999999999994)}),
#     'fpr': np.float64(0.2457627118644068),
#     'tpr': np.float64(0.7727272727272727),
#     'threshold': np.float64(0.3499342561424507)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.649),
#                                      1: np.float64(0.3509999999999999)}),
#     'fpr': np.float64(0.2542372881355932),
#     'tpr': np.float64(0.7803030303030303),
#     'threshold': np.float64(0.32428179215480935)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.619),
#                                      1: np.float64(0.38099999999999995)}),
#     'fpr': np.float64(0.2627118644067797),
#     'tpr': np.float64(0.7878787878787878),
#     'threshold': np.float64(0.3566456809331884)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5090000000000001),
#                                      1: np.float64(0.49099999999999994)}),
#     'fpr': np.float64(0.2711864406779661),
#     'tpr': np.float64(0.803030303030303),
#     'threshold': np.float64(0.4781392706158095)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5790000000000001),
#                                      1: np.float64(0.42099999999999993)}),
#     'fpr': np.float64(0.2796610169491525),
#     'tpr': np.float64(0.8181818181818182),
#     'threshold': np.float64(0.38165597408936885)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.559),
#                                      1: np.float64(0.44099999999999995)}),
#     'fpr': np.float64(0.288135593220339),
#     'tpr': np.float64(0.8333333333333334),
#     'threshold': np.float64(0.39855052484446235)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.06900000000000017),
#                                      1: np.float64(0.9309999999999998)}),
#     'fpr': np.float64(0.3050847457627119),
#     'tpr': np.float64(0.8484848484848485),
#     'threshold': np.float64(0.9293009603167937)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.43900000000000006),
#                                      1: np.float64(0.5609999999999999)}),
#     'fpr': np.float64(0.3135593220338983),
#     'tpr': np.float64(0.8560606060606061),
#     'threshold': np.float64(0.49797526747417364)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.32900000000000007),
#                                      1: np.float64(0.6709999999999999)}),
#     'fpr': np.float64(0.3220338983050847),
#     'tpr': np.float64(0.8712121212121212),
#     'threshold': np.float64(0.6125323966482191)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.31900000000000006),
#                                      1: np.float64(0.6809999999999999)}),
#     'fpr': np.float64(0.3305084745762712),
#     'tpr': np.float64(0.8787878787878788),
#     'threshold': np.float64(0.6077221928905335)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.609),
#                                      1: np.float64(0.39099999999999996)}),
#     'fpr': np.float64(0.3983050847457627),
#     'tpr': np.float64(0.8863636363636364),
#     'threshold': np.float64(0.2579805088089702)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.13900000000000012),
#                                      1: np.float64(0.8609999999999999)}),
#     'fpr': np.float64(0.4152542372881356),
#     'tpr': np.float64(0.9090909090909091),
#     'threshold': np.float64(0.7876133566525734)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.16900000000000015),
#                                      1: np.float64(0.8309999999999998)}),
#     'fpr': np.float64(0.423728813559322),
#     'tpr': np.float64(0.9242424242424242),
#     'threshold': np.float64(0.7370574468414932)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.3490000000000001),
#                                      1: np.float64(0.6509999999999999)}),
#     'fpr': np.float64(0.4406779661016949),
#     'tpr': np.float64(0.9318181818181818),
#     'threshold': np.float64(0.47132528965970627)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5990000000000001),
#                                      1: np.float64(0.4009999999999999)}),
#     'fpr': np.float64(0.4491525423728814),
#     'tpr': np.float64(0.9393939393939394),
#     'threshold': np.float64(0.22100231659755717)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.6890000000000001),
#                                      1: np.float64(0.31099999999999994)}),
#     'fpr': np.float64(0.4661016949152542),
#     'tpr': np.float64(0.946969696969697),
#     'threshold': np.float64(0.14519483958810123)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.629),
#                                      1: np.float64(0.37099999999999994)}),
#     'fpr': np.float64(0.4745762711864407),
#     'tpr': np.float64(0.9545454545454546),
#     'threshold': np.float64(0.18012352444318516)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5990000000000001),
#                                      1: np.float64(0.4009999999999999)}),
#     'fpr': np.float64(0.4830508474576271),
#     'tpr': np.float64(0.9621212121212122),
#     'threshold': np.float64(0.1963560026413563)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.4890000000000001),
#                                      1: np.float64(0.5109999999999999)}),
#     'fpr': np.float64(0.5084745762711864),
#     'tpr': np.float64(0.9696969696969697),
#     'threshold': np.float64(0.26124867112266126)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.5423728813559322),
#     'tpr': np.float64(0.9772727272727273),
#     'threshold': np.float64(0.9129067053006815)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.559322033898305),
#     'tpr': np.float64(0.9848484848484849),
#     'threshold': np.float64(0.8978970307686421)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.16900000000000015),
#                                      1: np.float64(0.8309999999999998)}),
#     'fpr': np.float64(0.5847457627118644),
#     'tpr': np.float64(0.9924242424242424),
#     'threshold': np.float64(0.47767727436317187)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.7033898305084746),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.7870055601934386)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.16923076923076924),
#     'threshold': np.float64(0.18721487580177731)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.008333333333333333),
#     'tpr': np.float64(0.5153846153846153),
#     'threshold': np.float64(0.05827611444315664)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.969),
#                                      1: np.float64(0.030999999999999996)}),
#     'fpr': np.float64(0.016666666666666666),
#     'tpr': np.float64(0.5230769230769231),
#     'threshold': np.float64(0.15063883715744159)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.025),
#     'tpr': np.float64(0.5384615384615384),
#     'threshold': np.float64(0.049059081180188265)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.03333333333333333),
#     'tpr': np.float64(0.5461538461538461),
#     'threshold': np.float64(0.0461898771570858)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.041666666666666664),
#     'tpr': np.float64(0.5692307692307692),
#     'threshold': np.float64(0.03665990206286816)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.05),
#     'tpr': np.float64(0.5923076923076923),
#     'threshold': np.float64(0.030919347155292713)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.959),
#                                      1: np.float64(0.040999999999999995)}),
#     'fpr': np.float64(0.058333333333333334),
#     'tpr': np.float64(0.6),
#     'threshold': np.float64(0.10186787074483672)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.969),
#                                      1: np.float64(0.030999999999999996)}),
#     'fpr': np.float64(0.06666666666666667),
#     'tpr': np.float64(0.6076923076923076),
#     'threshold': np.float64(0.0760078732941555)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.075),
#     'tpr': np.float64(0.6153846153846154),
#     'threshold': np.float64(0.025711406909605713)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.979),
#                                      1: np.float64(0.020999999999999998)}),
#     'fpr': np.float64(0.08333333333333333),
#     'tpr': np.float64(0.6384615384615384),
#     'threshold': np.float64(0.04635589143856951)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.11666666666666667),
#     'tpr': np.float64(0.6615384615384615),
#     'threshold': np.float64(0.020608586654338516)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.125),
#     'tpr': np.float64(0.6692307692307692),
#     'threshold': np.float64(0.02024889336416919)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.9490000000000001),
#                                      1: np.float64(0.05099999999999999)}),
#     'fpr': np.float64(0.13333333333333333),
#     'tpr': np.float64(0.676923076923077),
#     'threshold': np.float64(0.0831740513469621)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.9490000000000001),
#                                      1: np.float64(0.05099999999999999)}),
#     'fpr': np.float64(0.15),
#     'tpr': np.float64(0.6846153846153846),
#     'threshold': np.float64(0.07586210976746831)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.889),
#                                      1: np.float64(0.11099999999999999)}),
#     'fpr': np.float64(0.15833333333333333),
#     'tpr': np.float64(0.7153846153846154),
#     'threshold': np.float64(0.1478120001280279)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.7230769230769231),
#     'threshold': np.float64(0.015507893514732344)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.969),
#                                      1: np.float64(0.030999999999999996)}),
#     'fpr': np.float64(0.19166666666666668),
#     'tpr': np.float64(0.7384615384615385),
#     'threshold': np.float64(0.03853925512247962)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.759),
#                                      1: np.float64(0.24099999999999996)}),
#     'fpr': np.float64(0.20833333333333334),
#     'tpr': np.float64(0.7538461538461538),
#     'threshold': np.float64(0.28309456313770165)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.43900000000000006),
#                                      1: np.float64(0.5609999999999999)}),
#     'fpr': np.float64(0.25),
#     'tpr': np.float64(0.7692307692307693),
#     'threshold': np.float64(0.5930271690690673)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.909),
#                                      1: np.float64(0.09099999999999998)}),
#     'fpr': np.float64(0.26666666666666666),
#     'tpr': np.float64(0.7923076923076923),
#     'threshold': np.float64(0.0783289458060514)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.909),
#                                      1: np.float64(0.09099999999999998)}),
#     'fpr': np.float64(0.275),
#     'tpr': np.float64(0.8),
#     'threshold': np.float64(0.07430785838393923)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.7190000000000001),
#                                      1: np.float64(0.28099999999999997)}),
#     'fpr': np.float64(0.2833333333333333),
#     'tpr': np.float64(0.8076923076923077),
#     'threshold': np.float64(0.2576644274652847)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}),
#     'fpr': np.float64(0.2916666666666667),
#     'tpr': np.float64(0.8153846153846154),
#     'threshold': np.float64(0.0010999096567380878)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.649),
#                                      1: np.float64(0.3509999999999999)}),
#     'fpr': np.float64(0.3),
#     'tpr': np.float64(0.8307692307692308),
#     'threshold': np.float64(0.30470735623921147)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5990000000000001),
#                                      1: np.float64(0.4009999999999999)}),
#     'fpr': np.float64(0.30833333333333335),
#     'tpr': np.float64(0.8384615384615385),
#     'threshold': np.float64(0.3400313599959925)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.7090000000000001),
#                                      1: np.float64(0.291)}),
#     'fpr': np.float64(0.325),
#     'tpr': np.float64(0.8461538461538461),
#     'threshold': np.float64(0.21988287362441528)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.4590000000000001),
#                                      1: np.float64(0.5409999999999999)}),
#     'fpr': np.float64(0.3416666666666667),
#     'tpr': np.float64(0.8538461538461538),
#     'threshold': np.float64(0.45914938250405357)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.07900000000000018),
#                                      1: np.float64(0.9209999999999998)}),
#     'fpr': np.float64(0.38333333333333336),
#     'tpr': np.float64(0.8769230769230769),
#     'threshold': np.float64(0.8428070807027417)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.07900000000000018),
#                                      1: np.float64(0.9209999999999998)}),
#     'fpr': np.float64(0.39166666666666666),
#     'tpr': np.float64(0.8923076923076924),
#     'threshold': np.float64(0.836958547988152)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.049000000000000155),
#                                      1: np.float64(0.9509999999999998)}),
#     'fpr': np.float64(0.4),
#     'tpr': np.float64(0.9230769230769231),
#     'threshold': np.float64(0.8825993418192268)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.039000000000000146),
#                                      1: np.float64(0.9609999999999999)}),
#     'fpr': np.float64(0.4083333333333333),
#     'tpr': np.float64(0.9384615384615385),
#     'threshold': np.float64(0.8943434050513015)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.44166666666666665),
#     'tpr': np.float64(0.9461538461538461),
#     'threshold': np.float64(0.9377944920725388)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.009000000000000119),
#                                      1: np.float64(0.9909999999999999)}),
#     'fpr': np.float64(0.45),
#     'tpr': np.float64(0.9538461538461539),
#     'threshold': np.float64(0.9715438730045725)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.009000000000000119),
#                                      1: np.float64(0.9909999999999999)}),
#     'fpr': np.float64(0.4583333333333333),
#     'tpr': np.float64(0.9615384615384616),
#     'threshold': np.float64(0.9702178888177433)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.009000000000000119),
#                                      1: np.float64(0.9909999999999999)}),
#     'fpr': np.float64(0.4666666666666667),
#     'tpr': np.float64(0.9692307692307692),
#     'threshold': np.float64(0.9699619873207963)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.05900000000000016),
#                                      1: np.float64(0.9409999999999998)}),
#     'fpr': np.float64(0.475),
#     'tpr': np.float64(0.9846153846153847),
#     'threshold': np.float64(0.7767621788574552)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.009000000000000119),
#                                      1: np.float64(0.9909999999999999)}),
#     'fpr': np.float64(0.6),
#     'tpr': np.float64(0.9923076923076923),
#     'threshold': np.float64(0.92672875338727)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.009000000000000119),
#                                      1: np.float64(0.9909999999999999)}),
#     'fpr': np.float64(0.6333333333333333),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.9151982117628219)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.4482758620689655),
#     'threshold': np.float64(0.048046000648681024)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.007462686567164179),
#     'tpr': np.float64(0.47413793103448276),
#     'threshold': np.float64(0.0424409384135488)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}),
#     'fpr': np.float64(0.014925373134328358),
#     'tpr': np.float64(0.4827586206896552),
#     'threshold': np.float64(0.042299668202557685)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.929), 1: np.float64(0.071)}),
#     'fpr': np.float64(0.022388059701492536),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.21172476414604616)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}),
#     'fpr': np.float64(0.029850746268656716),
#     'tpr': np.float64(0.5603448275862069),
#     'threshold': np.float64(0.0014228838677222992)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.899),
#                                      1: np.float64(0.10099999999999998)}),
#     'fpr': np.float64(0.04477611940298507),
#     'tpr': np.float64(0.5862068965517241),
#     'threshold': np.float64(0.19016551632489873)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.849),
#                                      1: np.float64(0.15099999999999997)}),
#     'fpr': np.float64(0.05970149253731343),
#     'tpr': np.float64(0.603448275862069),
#     'threshold': np.float64(0.2569589842047123)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.849),
#                                      1: np.float64(0.15099999999999997)}),
#     'fpr': np.float64(0.06716417910447761),
#     'tpr': np.float64(0.6120689655172413),
#     'threshold': np.float64(0.25420907374107027)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.809),
#                                      1: np.float64(0.19099999999999998)}),
#     'fpr': np.float64(0.08955223880597014),
#     'tpr': np.float64(0.6206896551724138),
#     'threshold': np.float64(0.30117564861465523)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.7490000000000001),
#                                      1: np.float64(0.25099999999999995)}),
#     'fpr': np.float64(0.09701492537313433),
#     'tpr': np.float64(0.6293103448275862),
#     'threshold': np.float64(0.3680144535852861)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}),
#     'fpr': np.float64(0.12686567164179105),
#     'tpr': np.float64(0.6379310344827587),
#     'threshold': np.float64(0.0013011588021954402)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.929), 1: np.float64(0.071)}),
#     'fpr': np.float64(0.1417910447761194),
#     'tpr': np.float64(0.646551724137931),
#     'threshold': np.float64(0.10277638918960996)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.559),
#                                      1: np.float64(0.44099999999999995)}),
#     'fpr': np.float64(0.15671641791044777),
#     'tpr': np.float64(0.6551724137931034),
#     'threshold': np.float64(0.5432504881055631)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.4690000000000001),
#                                      1: np.float64(0.5309999999999999)}),
#     'fpr': np.float64(0.1791044776119403),
#     'tpr': np.float64(0.6724137931034483),
#     'threshold': np.float64(0.6161237013204126)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.41900000000000004),
#                                      1: np.float64(0.581)}),
#     'fpr': np.float64(0.19402985074626866),
#     'tpr': np.float64(0.6810344827586207),
#     'threshold': np.float64(0.6575011830579957)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.40900000000000014),
#                                      1: np.float64(0.5909999999999999)}),
#     'fpr': np.float64(0.20149253731343283),
#     'tpr': np.float64(0.6896551724137931),
#     'threshold': np.float64(0.6638928868223256)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21),
#     'tpr': np.float64(0.7),
#     'threshold': np.float64(0.5138248258215651)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21333333333333335),
#     'tpr': np.float64(0.7033333333333334),
#     'threshold': np.float64(0.5052511534785067)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.43900000000000006),
#                                      1: np.float64(0.5609999999999999)}),
#     'fpr': np.float64(0.22388059701492538),
#     'tpr': np.float64(0.7068965517241379),
#     'threshold': np.float64(0.6009449818975086)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.609),
#                                      1: np.float64(0.39099999999999996)}),
#     'fpr': np.float64(0.23134328358208955),
#     'tpr': np.float64(0.7241379310344828),
#     'threshold': np.float64(0.4024222207765601)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5690000000000001),
#                                      1: np.float64(0.43099999999999994)}),
#     'fpr': np.float64(0.2462686567164179),
#     'tpr': np.float64(0.75),
#     'threshold': np.float64(0.4370831616115807)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.5090000000000001),
#                                      1: np.float64(0.49099999999999994)}),
#     'fpr': np.float64(0.2537313432835821),
#     'tpr': np.float64(0.7586206896551724),
#     'threshold': np.float64(0.4837004360336667)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.41900000000000004),
#                                      1: np.float64(0.581)}),
#     'fpr': np.float64(0.26119402985074625),
#     'tpr': np.float64(0.7758620689655172),
#     'threshold': np.float64(0.5570197193431379)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.3890000000000001),
#                                      1: np.float64(0.6109999999999999)}),
#     'fpr': np.float64(0.26865671641791045),
#     'tpr': np.float64(0.7844827586206896),
#     'threshold': np.float64(0.5862415467243746)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.21900000000000008),
#                                      1: np.float64(0.7809999999999999)}),
#     'fpr': np.float64(0.291044776119403),
#     'tpr': np.float64(0.7931034482758621),
#     'threshold': np.float64(0.7645918112612876)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.049000000000000155),
#                                      1: np.float64(0.9509999999999998)}),
#     'fpr': np.float64(0.29850746268656714),
#     'tpr': np.float64(0.8275862068965517),
#     'threshold': np.float64(0.9462721602021493)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.06900000000000017),
#                                      1: np.float64(0.9309999999999998)}),
#     'fpr': np.float64(0.30597014925373134),
#     'tpr': np.float64(0.8448275862068966),
#     'threshold': np.float64(0.9208217792912141)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.029000000000000137),
#                                      1: np.float64(0.9709999999999999)}),
#     'fpr': np.float64(0.31343283582089554),
#     'tpr': np.float64(0.853448275862069),
#     'threshold': np.float64(0.9654776517029592)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.1190000000000001),
#                                      1: np.float64(0.8809999999999999)}),
#     'fpr': np.float64(0.3208955223880597),
#     'tpr': np.float64(0.8879310344827587),
#     'threshold': np.float64(0.8480652289111351)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.17900000000000016),
#                                      1: np.float64(0.8209999999999998)}),
#     'fpr': np.float64(0.3283582089552239),
#     'tpr': np.float64(0.9051724137931034),
#     'threshold': np.float64(0.7628723630402598)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.12900000000000011),
#                                      1: np.float64(0.8709999999999999)}),
#     'fpr': np.float64(0.34328358208955223),
#     'tpr': np.float64(0.9137931034482759),
#     'threshold': np.float64(0.8127624018640836)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.06900000000000017),
#                                      1: np.float64(0.9309999999999998)}),
#     'fpr': np.float64(0.3582089552238806),
#     'tpr': np.float64(0.9224137931034483),
#     'threshold': np.float64(0.8867753006003494)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.41900000000000004),
#                                      1: np.float64(0.581)}),
#     'fpr': np.float64(0.3880597014925373),
#     'tpr': np.float64(0.9310344827586207),
#     'threshold': np.float64(0.39601422111505424)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.09900000000000009),
#                                      1: np.float64(0.9009999999999999)}),
#     'fpr': np.float64(0.40298507462686567),
#     'tpr': np.float64(0.9396551724137931),
#     'threshold': np.float64(0.8204034466850022)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.029000000000000137),
#                                      1: np.float64(0.9709999999999999)}),
#     'fpr': np.float64(0.4253731343283582),
#     'tpr': np.float64(0.9482758620689655),
#     'threshold': np.float64(0.9325005061336339)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.029000000000000137),
#                                      1: np.float64(0.9709999999999999)}),
#     'fpr': np.float64(0.4552238805970149),
#     'tpr': np.float64(0.9568965517241379),
#     'threshold': np.float64(0.9241016052139311)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.019000000000000128),
#                                      1: np.float64(0.9809999999999999)}),
#     'fpr': np.float64(0.4626865671641791),
#     'tpr': np.float64(0.9655172413793104),
#     'threshold': np.float64(0.946630331710297)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.039000000000000146),
#                                      1: np.float64(0.9609999999999999)}),
#     'fpr': np.float64(0.47761194029850745),
#     'tpr': np.float64(0.9741379310344828),
#     'threshold': np.float64(0.8886220440074222)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.029000000000000137),
#                                      1: np.float64(0.9709999999999999)}),
#     'fpr': np.float64(0.4925373134328358),
#     'tpr': np.float64(0.9827586206896551),
#     'threshold': np.float64(0.906005117659989)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0.029000000000000137),
#                                      1: np.float64(0.9709999999999999)}),
#     'fpr': np.float64(0.5149253731343284),
#     'tpr': np.float64(0.9913793103448276),
#     'threshold': np.float64(0.8748476812324645)},
#    {'model': LogisticRegression(class_weight={0: np.float64(0
#          0.3916173 , 0.38613937, 0.37488422, 0.37376655, 0.37273492,
#          0.37078469, 0.35481691, 0.35438355, 0.35037054, 0.34849693,
#          0.34506844, 0.3435108 , 0.33436833, 0.33076733, 0.33047434,
#          0.33028278, 0.32589732, 0.31592191, 0.31493237, 0.3114461 ,
#          0.31002279, 0.30708706, 0.29775991, 0.29533317, 0.28724221,
#          0.28645115, 0.28305874, 0.28248536, 0.27591325, 0.27583821,
#          0.27475734, 0.27262154, 0.27261047, 0.27138951, 0.2652133 ,
#          0.26476858, 0.26443569, 0.26198753, 0.2549473 , 0.25162899,
#          0.24105439, 0.24037919, 0.23319289, 0.2319992 , 0.21978977,
#          0.21789182, 0.21323005, 0.21012376, 0.20137866, 0.1991743 ,
#          0.19267026, 0.19174481, 0.19076747, 0.18967964, 0.18944254,
#          0.18777554, 0.18412117, 0.18379505, 0.18192144, 0.17945039,
#          0.16978321, 0.16748933, 0.164734  , 0.16369108, 0.16366304,
#          0.16225953, 0.15495405, 0.14640905, 0.10930001, 0.10892123,
#          0.10767635, 0.10712183, 0.09504582, 0.08834955, 0.0134105 ]),
#   'name': 'Logistic Regression',
#   'auc': np.float64(0.8326333333333332),
#   'model': LogisticRegression()},
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x7c54353e5700>}

# %% [markdown]
# # Load pickle

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Load the data
list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader = load_from_pickle(filename='pickle/Logistic_data2_weighted.pkl')
# Out:
# Data loaded successfully.

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
plot_roc_comparison(
    results_lists=results_lists,
    names=["Fold 1", "Fold 2", "Fold 3", "Fold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4"],
    results_original_roc=results_original_roc
)

# %% [markdown]
# ### Ensemble prediction using voting

# %%
import numpy as np

# --- Loop through all the FPR values to generate the ensemble ROC curve ---



results_tuple = predict_ensemble_and_evaluate(list_folds_best_models=list_folds_best_models,
    test_loader=test_loader)

ensemble_results_soft = results_tuple['soft_voting']
ensemble_results_hard = results_tuple['hard_voting']
# Out:
# Creating a single ensemble from 177 models across all folds.
# Extracting full dataset...
# Getting predictions from all models...
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
results_lists.append(ensemble_results_soft)
results_lists.append(ensemble_results_hard)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["Fold 1", "Fold 2", "Fold 3", "Fold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Ensemble_voting_soft", "Ensemble_voting_hard"],
    results_original_roc=results_original_roc
)
# Out:
# --- Plotting all ROC curves for comparison ---
