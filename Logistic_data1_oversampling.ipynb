# %% [markdown]
# ### Imports

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        y_prob = clf_model.predict_proba(X_test)[:, 1]
        y_pred = (y_prob >= threshold).astype(int)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data1")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Oversampling

# %%
import numpy as np
from collections import Counter
# --- Configuration ---
EPSILON = 1e-9
# EXPECTED_MODES_PER_CLASS, etc. removed
# FIXED_TARGET_STD_SYNTHETIC removed

# --- Parameter for KDE-like generator ---
SIGMA_KDE_PERTURBATION = 0.1 # Adjust as needed

# --- This block generates the list of ratios for your experiment ---
def generate_ratios(train_data):
    # 1. Get original class counts from your train_dataset

    # --- Initial Data Analysis ---
    counter = Counter(train_data[:, -1])  # Assuming the last column is the class label
    Class0_initial = counter.get(0, 0)
    Class1_initial = counter.get(1, 0)


    class_ratio_low = 0.1   
    class_ratio_high = 100.0 
    num_points_below = 100 
    num_points_above = 100 

    if Class1_initial == 0 and Class0_initial == 0:
        print("ERROR: Both classes have zero samples initially. Cannot proceed.")
        alpha_target_actual_values = [] 
        current_class_ratio = 1.0
    elif Class1_initial == 0:
        current_class_ratio = np.inf 
    else:
        current_class_ratio = Class0_initial / Class1_initial

    # ... (alpha_target_actual_values generation - same robust version) ...
    alpha_target_list = []
    if Class0_initial > 0 or Class1_initial > 0: 
        if current_class_ratio > 0 and not np.isinf(current_class_ratio): 
            alpha_target_list.append(current_class_ratio)
        _safe_class_ratio_low = max(class_ratio_low, EPSILON)
        if current_class_ratio > _safe_class_ratio_low and not np.isinf(current_class_ratio): 
            try:
                alpha_b = np.geomspace(_safe_class_ratio_low, current_class_ratio, num_points_below, endpoint=False)
                alpha_target_list.extend(alpha_b)
            except ValueError: pass
        if current_class_ratio < class_ratio_high and current_class_ratio >= 0 and not np.isinf(current_class_ratio): 
            try:
                _start_geom_above = max(current_class_ratio, _safe_class_ratio_low) 
                if class_ratio_high > _start_geom_above:
                    alpha_a = np.geomspace(_start_geom_above, class_ratio_high, num_points_above, endpoint=True)
                    if not np.isclose(_start_geom_above, current_class_ratio) and current_class_ratio >=_safe_class_ratio_low and current_class_ratio <= class_ratio_high :
                        alpha_target_list.append(current_class_ratio)
                    alpha_target_list.extend(alpha_a)
                elif np.isclose(class_ratio_high, _start_geom_above):
                    alpha_target_list.append(class_ratio_high)
            except ValueError: pass
        if not alpha_target_list and (Class0_initial > 0 or Class1_initial > 0): 
            if not np.isinf(current_class_ratio) and current_class_ratio > 0:
                alpha_target_list.append(current_class_ratio)
            else: 
                alpha_target_list.extend(np.geomspace(_safe_class_ratio_low, class_ratio_high, num_points_below + num_points_above))
        alpha_target_actual_values = np.unique(alpha_target_list)
        alpha_target_actual_values = np.sort(alpha_target_actual_values[alpha_target_actual_values >= 0]) 
        alpha_target_actual_values = alpha_target_actual_values[alpha_target_actual_values >= _safe_class_ratio_low] 
        alpha_target_actual_values = alpha_target_actual_values[alpha_target_actual_values <= class_ratio_high]
        if not alpha_target_actual_values.size and (Class0_initial > 0 or Class1_initial > 0) : 
            if not np.isinf(current_class_ratio) and current_class_ratio > _safe_class_ratio_low and current_class_ratio < class_ratio_high:
                alpha_target_actual_values = np.array([current_class_ratio])
            else: 
                alpha_target_actual_values = np.array([(_safe_class_ratio_low + class_ratio_high)/2.0])


    print(f"INFO: Initial C0={Class0_initial}, C1={Class1_initial}, Ratio(0/1): {current_class_ratio if Class1_initial > 0 else 'N/A'}")
    print(f"INFO: Target ratios (w values): {alpha_target_actual_values}")
    print(f"INFO: KDE-like perturbation sigma: {SIGMA_KDE_PERTURBATION}")
    print(f"INFO: Standard deviation of synthetic samples will NOT be modified after generation.")

    return alpha_target_actual_values, Class0_initial, Class1_initial

# %%
import numpy as np
from collections import Counter


def oversample_dataset_KDE(Class0_initial, Class1_initial, alpha_target, train_data):
    """
    Oversamples a dataset to a target ratio using a KDE-like method.
    This version contains fixes for shape errors when no samples are generated.
    """
    # --- Determine Oversampling Strategy ---
    oversampled_class_label_by_strategy = -1
    initial_count_of_oversampled_class = -1
    final_count_of_oversampled_class = -1

    if Class1_initial == 0 and Class0_initial > 0:
        current_class_ratio = np.inf
    elif Class1_initial == 0 and Class0_initial == 0:
        current_class_ratio = 1.0 # Or some other neutral value
    else:
        current_class_ratio = Class0_initial / Class1_initial

    # Decide which class to oversample or if we should do nothing
    if abs(alpha_target - current_class_ratio) < EPSILON:
        # Ratios are the same, do nothing
        initial_count_of_oversampled_class = Class1_initial # Placeholder
        final_count_of_oversampled_class = Class1_initial   # Placeholder
    elif alpha_target > current_class_ratio:
        # Target has more C0 relative to C1 -> Oversample C0
        oversampled_class_label_by_strategy = 0
        initial_count_of_oversampled_class = Class0_initial
        final_count_of_oversampled_class = int(round(Class1_initial * alpha_target))
    else: # alpha_target < current_class_ratio
        # Target has more C1 relative to C0 -> Oversample C1
        oversampled_class_label_by_strategy = 1
        initial_count_of_oversampled_class = Class1_initial
        final_count_of_oversampled_class = int(round(Class0_initial / alpha_target))

    num_synthetic_to_generate = max(0, final_count_of_oversampled_class - initial_count_of_oversampled_class)
    print(f"  INFO: Strategy: Oversample class {oversampled_class_label_by_strategy} from {initial_count_of_oversampled_class} to {final_count_of_oversampled_class} (generating {num_synthetic_to_generate} samples).")


    # --- KDE-like Synthetic Sample Generation ---
    if num_synthetic_to_generate > 0:
        print(f"  INFO: Using KDE-like generator. Perturbation sigma: {SIGMA_KDE_PERTURBATION}")
        X_new_synthetic = []
        y_new_synthetic = []

        indices_class = np.where(train_data[:, -1] == oversampled_class_label_by_strategy)[0]
        
        if len(indices_class) > 0:
            for _ in range(num_synthetic_to_generate):
                idx_star = np.random.choice(indices_class)
                X_star = train_data[idx_star, :-1]
                epsilon_noise = np.random.randn(*X_star.shape)
                X_prime = X_star + SIGMA_KDE_PERTURBATION * epsilon_noise
                X_new_synthetic.append(X_prime)
                y_new_synthetic.append(oversampled_class_label_by_strategy)

            X_new_synthetic_arr = np.array(X_new_synthetic)
            y_new_synthetic_arr = np.array(y_new_synthetic)
            X_resampled = np.vstack((train_data[:, :-1], X_new_synthetic_arr))
            y_resampled = np.concatenate((train_data[:, -1], y_new_synthetic_arr))
            resampled_counts = Counter(y_resampled)
            print(f"  INFO: KDE-like generation complete. New C0={resampled_counts.get(0,0)}, C1={resampled_counts.get(1,0)}")
        else:
             # This can happen if the class to oversample has 0 members
            print("  WARNING: Cannot generate samples for a class with 0 members. Returning original data.")
            X_resampled = train_data[:, :-1]
            y_resampled = train_data[:, -1]

    else: # num_synthetic_to_generate is 0
        print("  INFO: No synthetic samples were required or generated.")
        # --- THIS IS THE CRITICAL FIX ---
        # Correctly slice the original data instead of copying the whole array
        X_resampled = train_data[:, :-1]
        y_resampled = train_data[:, -1]
        # ----------------------------

    return X_resampled, y_resampled

# %% [markdown]
# ### Regular training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = LogisticRegression(fit_intercept=True)
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "Logistic Regression", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Oversampling ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds

list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    alpha_target_actual_values, Class0_initial, Class1_initial  = generate_ratios(np.c_[X_train_fold, y_train_fold])  # Combine features and labels for ratio generation
    for w_idx, w in enumerate(alpha_target_actual_values):
        print(f"\n--- Processing target ratio w ({w_idx+1}/{len(alpha_target_actual_values)}): {w:.4f} ---")
        X_train_resampled, y_train_resampled = oversample_dataset_KDE(Class0_initial, Class1_initial, w, np.c_[X_train_fold, y_train_fold])

        clf_weighted = LogisticRegression(fit_intercept=True)
        clf_weighted.fit(X_train_resampled, y_train_resampled)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# INFO: Initial C0=372, C1=378, Ratio(0/1): 0.9841269841269841
# INFO: Target ratios (w values): [  0.1          0.10231293   0.10467935   0.10710051   0.10957767
#    0.11211212   0.11470519   0.11735824   0.12007265   0.12284984
#    0.12569127   0.12859842   0.13157281   0.13461599   0.13772956
#    0.14091514   0.14417441   0.14750906   0.15092084   0.15441153
#    0.15798295   0.16163698   0.16537553   0.16920055   0.17311403
#    0.17711803   0.18121465   0.18540601   0.18969432   0.19408181
#    0.19857078   0.20316358   0.2078626    0.21267032   0.21758923
#    0.22262191   0.22777099   0.23303917   0.2384292    0.24394389
#    0.24958614   0.25535888   0.26126515   0.26730802   0.27349066
#    0.2798163    0.28628825   0.29290989   0.29968468   0.30661617
#    0.31370798   0.32096382   0.32838748   0.33598285   0.34375389
#    0.35170466   0.35983934   0.36816216   0.37667748   0.38538976
#    0.39430355   0.4034235    0.4127544    0.42230111   0.43206862
#    0.44206206   0.45228663   0.46274769   0.47345071   0.48440129
#    0.49560514   0.50706812   0.51879624   0.53079562   0.54307254
#    0.55563341   0.56848481   0.58163345   0.59508621   0.60885013
#    0.62293239   0.63734036   0.65208158   0.66716376   0.68259477
#    0.69838269   0.71453578   0.73106247   0.74797142   0.76527146
#    0.78297163   0.8010812    0.81960962   0.8385666    0.85796204
#    0.87780608   0.8981091    0.91888171   0.94013477   0.96187941
#    0.98412698   1.03115357   1.08042733   1.13205564   1.18615101
#    1.24283133   1.30222013   1.36444682   1.42964703   1.49796283
#    1.5695431    1.64454385   1.72312851   1.80546835   1.8917428
#    1.98213989   2.0768566    2.17609936   2.28008445   2.38903847
#    2.50319887   2.62281443   2.74814584   2.87946621   3.01706174
#    3.16123228   3.31229202   3.47057017   3.63641164   3.81017787
#    3.99224753   4.18301741   4.38290324   4.59234063   4.811786
#    5.04171759   5.28263647   5.53506769   5.79956135   6.07669386
#    6.36706918   6.6713201    6.99010967   7.32413263   7.67411691
#    8.04082521   8.4250567    8.82764873   9.24947864   9.69146574
#   10.15457322  10.63981033  11.14823454  11.68095383  12.23912917
#   12.82397695  13.43677174  14.07884898  14.75160793  15.45651472
#   16.19510554  16.96898998  17.77985455  18.62946635  19.51967692
#   20.45242628  21.42974714  22.45376936  23.52672457  24.65095102
#   25.82889873  27.06313477  28.35634887  29.71135932  31.13111906
#   32.61872212  34.17741043  35.81058078  37.5217923   39.31477422
#   41.19343392  43.16186552  45.22435879  47.38540847  49.64972409
#   52.02224021  54.50812721  57.11280253  59.84194246  62.70149457
#   65.69769061  68.83706013  72.12644467  75.57301273  79.18427532
#   82.96810238  86.93273994  91.08682802  95.43941954 100.        ]
# INFO: KDE-like perturbation sigma: 0.1
# INFO: Standard deviation of synthetic samples will NOT be modified after generation.
#
# --- Processing target ratio w (1/200): 0.1000 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3720 (generating 3342 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3720
#
# --- Processing target ratio w (2/200): 0.1023 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3636 (generating 3258 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3636
#
# --- Processing target ratio w (3/200): 0.1047 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3554 (generating 3176 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3554
#
# --- Processing target ratio w (4/200): 0.1071 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3473 (generating 3095 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3473
#
# --- Processing target ratio w (5/200): 0.1096 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3395 (generating 3017 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3395
#
# --- Processing target ratio w (6/200): 0.1121 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3318 (generating 2940 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3318
#
# --- Processing target ratio w (7/200): 0.1147 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3243 (generating 2865 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3243
#
# --- Processing target ratio w (8/200): 0.1174 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3170 (generating 2792 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3170
#
# --- Processing target ratio w (9/200): 0.1201 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3098 (generating 2720 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3098
#
# --- Processing target ratio w (10/200): 0.1228 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3028 (generating 2650 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3028
#
# --- Processing target ratio w (11/200): 0.1257 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2960 (generating 2582 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2960
#
# --- Processing target ratio w (12/200): 0.1286 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2893 (generating 2515 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2893
#
# --- Processing target ratio w (13/200): 0.1316 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2827 (generating 2449 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2827
#
# --- Processing target ratio w (14/200): 0.1346 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2763 (generating 2385 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2763
#
# --- Processing target ratio w (15/200): 0.1377 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2701 (generating 2323 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2701
#
# --- Processing target ratio w (16/200): 0.1409 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2640 (generating 2262 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2640
#
# --- Processing target ratio w (17/200): 0.1442 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2580 (generating 2202 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2580
#
# --- Processing target ratio w (18/200): 0.1475 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2522 (generating 2144 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2522
#
# --- Processing target ratio w (19/200): 0.1509 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2465 (generating 2087 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2465
#
# --- Processing target ratio w (20/200): 0.1544 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2409 (generating 2031 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2409
#
# --- Processing target ratio w (21/200): 0.1580 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2355 (generating 1977 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2355
#
# --- Processing target ratio w (22/200): 0.1616 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2301 (generating 1923 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2301
#
# --- Processing target ratio w (23/200): 0.1654 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2249 (generating 1871 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2249
#
# --- Processing target ratio w (24/200): 0.1692 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2199 (generating 1821 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2199
#
# --- Processing target ratio w (25/200): 0.1731 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2149 (generating 1771 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2149
#
# --- Processing target ratio w (26/200): 0.1771 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2100 (generating 1722 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2100
#
# --- Processing target ratio w (27/200): 0.1812 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2053 (generating 1675 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2053
#
# --- Processing target ratio w (28/200): 0.1854 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2006 (generating 1628 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2006
#
# --- Processing target ratio w (29/200): 0.1897 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1961 (generating 1583 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1961
#
# --- Processing target ratio w (30/200): 0.1941 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1917 (generating 1539 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1917
#
# --- Processing target ratio w (31/200): 0.1986 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1873 (generating 1495 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1873
#
# --- Processing target ratio w (32/200): 0.2032 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1831 (generating 1453 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1831
#
# --- Processing target ratio w (33/200): 0.2079 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1790 (generating 1412 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1790
#
# --- Processing target ratio w (34/200): 0.2127 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1749 (generating 1371 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1749
#
# --- Processing target ratio w (35/200): 0.2176 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1710 (generating 1332 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1710
#
# --- Processing target ratio w (36/200): 0.2226 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1671 (generating 1293 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1671
#
# --- Processing target ratio w (37/200): 0.2278 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1633 (generating 1255 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1633
#
# --- Processing target ratio w (38/200): 0.2330 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1596 (generating 1218 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1596
#
# --- Processing target ratio w (39/200): 0.2384 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1560 (generating 1182 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1560
#
# --- Processing target ratio w (40/200): 0.2439 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1525 (generating 1147 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1525
#
# --- Processing target ratio w (41/200): 0.2496 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1490 (generating 1112 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1490
#
# --- Processing target ratio w (42/200): 0.2554 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1457 (generating 1079 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1457
#
# --- Processing target ratio w (43/200): 0.2613 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1424 (generating 1046 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1424
#
# --- Processing target ratio w (44/200): 0.2673 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1392 (generating 1014 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1392
#
# --- Processing target ratio w (45/200): 0.2735 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1360 (generating 982 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1360
#
# --- Processing target ratio w (46/200): 0.2798 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1329 (generating 951 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1329
#
# --- Processing target ratio w (47/200): 0.2863 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1299 (generating 921 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1299
#
# --- Processing target ratio w (48/200): 0.2929 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1270 (generating 892 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1270
#
# --- Processing target ratio w (49/200): 0.2997 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1241 (generating 863 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1241
#
# --- Processing target ratio w (50/200): 0.3066 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1213 (generating 835 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1213
#
# --- Processing target ratio w (51/200): 0.3137 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1186 (generating 808 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1186
#
# --- Processing target ratio w (52/200): 0.3210 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1159 (generating 781 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1159
#
# --- Processing target ratio w (53/200): 0.3284 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1133 (generating 755 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1133
#
# --- Processing target ratio w (54/200): 0.3360 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1107 (generating 729 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1107
#
# --- Processing target ratio w (55/200): 0.3438 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1082 (generating 704 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1082
#
# --- Processing target ratio w (56/200): 0.3517 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1058 (generating 680 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1058
#
# --- Processing target ratio w (57/200): 0.3598 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1034 (generating 656 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1034
#
# --- Processing target ratio w (58/200): 0.3682 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1010 (generating 632 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1010
#
# --- Processing target ratio w (59/200): 0.3767 ---
#   INFO: Strategy: Oversample class 1 from 378 to 988 (generating 610 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=988
#
# --- Processing target ratio w (60/200): 0.3854 ---
#   INFO: Strategy: Oversample class 1 from 378 to 965 (generating 587 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=965
#
# --- Processing target ratio w (61/200): 0.3943 ---
#   INFO: Strategy: Oversample class 1 from 378 to 943 (generating 565 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=943
#
# --- Processing target ratio w (62/200): 0.4034 ---
#   INFO: Strategy: Oversample class 1 from 378 to 922 (generating 544 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=922
#
# --- Processing target ratio w (63/200): 0.4128 ---
#   INFO: Strategy: Oversample class 1 from 378 to 901 (generating 523 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=901
#
# --- Processing target ratio w (64/200): 0.4223 ---
#   INFO: Strategy: Oversample class 1 from 378 to 881 (generating 503 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=881
#
# --- Processing target ratio w (65/200): 0.4321 ---
#   INFO: Strategy: Oversample class 1 from 378 to 861 (generating 483 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=861
#
# --- Processing target ratio w (66/200): 0.4421 ---
#   INFO: Strategy: Oversample class 1 from 378 to 842 (generating 464 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=842
#
# --- Processing target ratio w (67/200): 0.4523 ---
#   INFO: Strategy: Oversample class 1 from 378 to 822 (generating 444 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=822
#
# --- Processing target ratio w (68/200): 0.4627 ---
#   INFO: Strategy: Oversample class 1 from 378 to 804 (generating 426 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=804
#
# --- Processing target ratio w (69/200): 0.4735 ---
#   INFO: Strategy: Oversample class 1 from 378 to 786 (generating 408 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=786
#
# --- Processing target ratio w (70/200): 0.4844 ---
#   INFO: Strategy: Oversample class 1 from 378 to 768 (generating 390 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=768
#
# --- Processing target ratio w (71/200): 0.4956 ---
#   INFO: Strategy: Oversample class 1 from 378 to 751 (generating 373 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=751
#
# --- Processing target ratio w (72/200): 0.5071 ---
#   INFO: Strategy: Oversample class 1 from 378 to 734 (generating 356 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=734
#
# --- Processing target ratio w (73/200): 0.5188 ---
#   INFO: Strategy: Oversample class 1 from 378 to 717 (generating 339 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=717
#
# --- Processing target ratio w (74/200): 0.5308 ---
#   INFO: Strategy: Oversample class 1 from 378 to 701 (generating 323 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=701
#
# --- Processing target ratio w (75/200): 0.5431 ---
#   INFO: Strategy: Oversample class 1 from 378 to 685 (generating 307 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=685
#
# --- Processing target ratio w (76/200): 0.5556 ---
#   INFO: Strategy: Oversample class 1 from 378 to 670 (generating 292 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=670
#
# --- Processing target ratio w (77/200): 0.5685 ---
#   INFO: Strategy: Oversample class 1 from 378 to 654 (generating 276 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=654
#
# --- Processing target ratio w (78/200): 0.5816 ---
#   INFO: Strategy: Oversample class 1 from 378 to 640 (generating 262 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=640
#
# --- Processing target ratio w (79/200): 0.5951 ---
#   INFO: Strategy: Oversample class 1 from 378 to 625 (generating 247 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=625
#
# --- Processing target ratio w (80/200): 0.6089 ---
#   INFO: Strategy: Oversample class 1 from 378 to 611 (generating 233 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=611
#
# --- Processing target ratio w (81/200): 0.6229 ---
#   INFO: Strategy: Oversample class 1 from 378 to 597 (generating 219 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=597
#
# --- Processing target ratio w (82/200): 0.6373 ---
#   INFO: Strategy: Oversample class 1 from 378 to 584 (generating 206 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=584
#
# --- Processing target ratio w (83/200): 0.6521 ---
#   INFO: Strategy: Oversample class 1 from 378 to 570 (generating 192 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=570
#
# --- Processing target ratio w (84/200): 0.6672 ---
#   INFO: Strategy: Oversample class 1 from 378 to 558 (generating 180 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=558
#
# --- Processing target ratio w (85/200): 0.6826 ---
#   INFO: Strategy: Oversample class 1 from 378 to 545 (generating 167 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=545
#
# --- Processing target ratio w (86/200): 0.6984 ---
#   INFO: Strategy: Oversample class 1 from 378 to 533 (generating 155 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=533
#
# --- Processing target ratio w (87/200): 0.7145 ---
#   INFO: Strategy: Oversample class 1 from 378 to 521 (generating 143 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=521
#
# --- Processing target ratio w (88/200): 0.7311 ---
#   INFO: Strategy: Oversample class 1 from 378 to 509 (generating 131 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=509
#
# --- Processing target ratio w (89/200): 0.7480 ---
#   INFO: Strategy: Oversample class 1 from 378 to 497 (generating 119 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=497
#
# --- Processing target ratio w (90/200): 0.7653 ---
#   INFO: Strategy: Oversample class 1 from 378 to 486 (generating 108 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=486
#
# --- Processing target ratio w (91/200): 0.7830 ---
#   INFO: Strategy: Oversample class 1 from 378 to 475 (generating 97 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=475
#
# --- Processing target ratio w (92/200): 0.8011 ---
#   INFO: Strategy: Oversample class 1 from 378 to 464 (generating 86 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=464
#
# --- Processing target ratio w (93/200): 0.8196 ---
#   INFO: Strategy: Oversample class 1 from 378 to 454 (generating 76 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=454
#
# --- Processing target ratio w (94/200): 0.8386 ---
#   INFO: Strategy: Oversample class 1 from 378 to 444 (generating 66 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=444
#
# --- Processing target ratio w (95/200): 0.8580 ---
#   INFO: Strategy: Oversample class 1 from 378 to 434 (generating 56 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=434
#
# --- Processing target ratio w (96/200): 0.8778 ---
#   INFO: Strategy: Oversample class 1 from 378 to 424 (generating 46 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=424
#
# --- Processing target ratio w (97/200): 0.8981 ---
#   INFO: Strategy: Oversample class 1 from 378 to 414 (generating 36 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=414
#
# --- Processing target ratio w (98/200): 0.9189 ---
#   INFO: Strategy: Oversample class 1 from 378 to 405 (generating 27 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=405
#
# --- Processing target ratio w (99/200): 0.9401 ---
#   INFO: Strategy: Oversample class 1 from 378 to 396 (generating 18 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=396
#
# --- Processing target ratio w (100/200): 0.9619 ---
#   INFO: Strategy: Oversample class 1 from 378 to 387 (generating 9 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=387
#
# --- Processing target ratio w (101/200): 0.9841 ---
#   INFO: Strategy: Oversample class -1 from 378 to 378 (generating 0 samples).
#   INFO: No synthetic samples were required or generated.
#
# --- Processing target ratio w (102/200): 1.0312 ---
#   INFO: Strategy: Oversample class 0 from 372 to 390 (generating 18 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=390, C1=378
#
# --- Processing target ratio w (103/200): 1.0804 ---
#   INFO: Strategy: Oversample class 0 from 372 to 408 (generating 36 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=408, C1=378
#
# --- Processing target ratio w (104/200): 1.1321 ---
#   INFO: Strategy: Oversample class 0 from 372 to 428 (generating 56 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=428, C1=378
#
# --- Processing target ratio w (105/200): 1.1862 ---
#   INFO: Strategy: Oversample class 0 from 372 to 448 (generating 76 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=448, C1=378
#
# --- Processing target ratio w (106/200): 1.2428 ---
#   INFO: Strategy: Oversample class 0 from 372 to 470 (generating 98 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=470, C1=378
#
# --- Processing target ratio w (107/200): 1.3022 ---
#   INFO: Strategy: Oversample class 0 from 372 to 492 (generating 120 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=492, C1=378
#
# --- Processing target ratio w (108/200): 1.3644 ---
#   INFO: Strategy: Oversample class 0 from 372 to 516 (generating 144 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=516, C1=378
#
# --- Processing target ratio w (109/200): 1.4296 ---
#   INFO: Strategy: Oversample class 0 from 372 to 540 (generating 168 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=540, C1=378
#
# --- Processing target ratio w (110/200): 1.4980 ---
#   INFO: Strategy: Oversample class 0 from 372 to 566 (generating 194 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=566, C1=378
#
# --- Processing target ratio w (111/200): 1.5695 ---
#   INFO: Strategy: Oversample class 0 from 372 to 593 (generating 221 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=593, C1=378
#
# --- Processing target ratio w (112/200): 1.6445 ---
#   INFO: Strategy: Oversample class 0 from 372 to 622 (generating 250 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=622, C1=378
#
# --- Processing target ratio w (113/200): 1.7231 ---
#   INFO: Strategy: Oversample class 0 from 372 to 651 (generating 279 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=651, C1=378
#
# --- Processing target ratio w (114/200): 1.8055 ---
#   INFO: Strategy: Oversample class 0 from 372 to 682 (generating 310 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=682, C1=378
#
# --- Processing target ratio w (115/200): 1.8917 ---
#   INFO: Strategy: Oversample class 0 from 372 to 715 (generating 343 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=715, C1=378
#
# --- Processing target ratio w (116/200): 1.9821 ---
#   INFO: Strategy: Oversample class 0 from 372 to 749 (generating 377 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=749, C1=378
#
# --- Processing target ratio w (117/200): 2.0769 ---
#   INFO: Strategy: Oversample class 0 from 372 to 785 (generating 413 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=785, C1=378
#
# --- Processing target ratio w (118/200): 2.1761 ---
#   INFO: Strategy: Oversample class 0 from 372 to 823 (generating 451 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=823, C1=378
#
# --- Processing target ratio w (119/200): 2.2801 ---
#   INFO: Strategy: Oversample class 0 from 372 to 862 (generating 490 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=862, C1=378
#
# --- Processing target ratio w (120/200): 2.3890 ---
#   INFO: Strategy: Oversample class 0 from 372 to 903 (generating 531 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=903, C1=378
#
# --- Processing target ratio w (121/200): 2.5032 ---
#   INFO: Strategy: Oversample class 0 from 372 to 946 (generating 574 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=946, C1=378
#
# --- Processing target ratio w (122/200): 2.6228 ---
#   INFO: Strategy: Oversample class 0 from 372 to 991 (generating 619 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=991, C1=378
#
# --- Processing target ratio w (123/200): 2.7481 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1039 (generating 667 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1039, C1=378
#
# --- Processing target ratio w (124/200): 2.8795 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1088 (generating 716 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1088, C1=378
#
# --- Processing target ratio w (125/200): 3.0171 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1140 (generating 768 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1140, C1=378
#
# --- Processing target ratio w (126/200): 3.1612 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1195 (generating 823 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1195, C1=378
#
# --- Processing target ratio w (127/200): 3.3123 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1252 (generating 880 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1252, C1=378
#
# --- Processing target ratio w (128/200): 3.4706 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1312 (generating 940 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1312, C1=378
#
# --- Processing target ratio w (129/200): 3.6364 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1375 (generating 1003 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1375, C1=378
#
# --- Processing target ratio w (130/200): 3.8102 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1440 (generating 1068 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1440, C1=378
#
# --- Processing target ratio w (131/200): 3.9922 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1509 (generating 1137 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1509, C1=378
#
# --- Processing target ratio w (132/200): 4.1830 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1581 (generating 1209 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1581, C1=378
#
# --- Processing target ratio w (133/200): 4.3829 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1657 (generating 1285 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1657, C1=378
#
# --- Processing target ratio w (134/200): 4.5923 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1736 (generating 1364 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1736, C1=378
#
# --- Processing target ratio w (135/200): 4.8118 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1819 (generating 1447 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1819, C1=378
#
# --- Processing target ratio w (136/200): 5.0417 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1906 (generating 1534 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1906, C1=378
#
# --- Processing target ratio w (137/200): 5.2826 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1997 (generating 1625 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1997, C1=378
#
# --- Processing target ratio w (138/200): 5.5351 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2092 (generating 1720 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2092, C1=378
#
# --- Processing target ratio w (139/200): 5.7996 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2192 (generating 1820 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2192, C1=378
#
# --- Processing target ratio w (140/200): 6.0767 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2297 (generating 1925 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2297, C1=378
#
# --- Processing target ratio w (141/200): 6.3671 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2407 (generating 2035 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2407, C1=378
#
# --- Processing target ratio w (142/200): 6.6713 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2522 (generating 2150 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2522, C1=378
#
# --- Processing target ratio w (143/200): 6.9901 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2642 (generating 2270 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2642, C1=378
#
# --- Processing target ratio w (144/200): 7.3241 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2769 (generating 2397 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2769, C1=378
#
# --- Processing target ratio w (145/200): 7.6741 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2901 (generating 2529 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2901, C1=378
#
# --- Processing target ratio w (146/200): 8.0408 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3039 (generating 2667 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3039, C1=378
#
# --- Processing target ratio w (147/200): 8.4251 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3185 (generating 2813 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3185, C1=378
#
# --- Processing target ratio w (148/200): 8.8276 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3337 (generating 2965 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3337, C1=378
#
# --- Processing target ratio w (149/200): 9.2495 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3496 (generating 3124 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3496, C1=378
#
# --- Processing target ratio w (150/200): 9.6915 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3663 (generating 3291 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3663, C1=378
#
# --- Processing target ratio w (151/200): 10.1546 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3838 (generating 3466 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3838, C1=378
#
# --- Processing target ratio w (152/200): 10.6398 ---
#   INFO: Strategy: Oversample class 0 from 372 to 4022 (generating 3650 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4022, C1=378
#
# --- Processing target ratio w (153/200): 11.1482 ---
#   INFO: Strategy: Oversample class 0 from 372 to 4214 (generating 3842 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4214, C1=378
#
# --- Processing target ratio w (154/200): 11.6810 ---
#   INFO: Strategy: Oversample class 0 from 372 to 4415 (generating 4043 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4415, C1=378
#
# --- Processing target ratio w (155/200): 12.2391 ---
#   INFO: Strategy: Oversample class 0 from 372 to 4626 (generating 4254 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4626, C1=378
#
# --- Processing target ratio w (156/200): 12.8240 ---
#   INFO: Strategy: Oversample class 0 from 372 to 4847 (generating 4475 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4847, C1=378
#
# --- Processing target ratio w (157/200): 13.4368 ---
#   INFO: Strategy: Oversample class 0 from 372 to 5079 (generating 4707 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5079, C1=378
#
# --- Processing target ratio w (158/200): 14.0788 ---
#   INFO: Strategy: Oversample class 0 from 372 to 5322 (generating 4950 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5322, C1=378
#
# --- Processing target ratio w (159/200): 14.7516 ---
#   INFO: Strategy: Oversample class 0 from 372 to 5576 (generating 5204 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5576, C1=378
#
# --- Processing target ratio w (160/200): 15.4565 ---
#   INFO: Strategy: Oversample class 0 from 372 to 5843 (generating 5471 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5843, C1=378
#
# --- Processing target ratio w (161/200): 16.1951 ---
#   INFO: Strategy: Oversample class 0 from 372 to 6122 (generating 5750 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6122, C1=378
#
# --- Processing target ratio w (162/200): 16.9690 ---
#   INFO: Strategy: Oversample class 0 from 372 to 6414 (generating 6042 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6414, C1=378
#
# --- Processing target ratio w (163/200): 17.7799 ---
#   INFO: Strategy: Oversample class 0 from 372 to 6721 (generating 6349 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6721, C1=378
#
# --- Processing target ratio w (164/200): 18.6295 ---
#   INFO: Strategy: Oversample class 0 from 372 to 7042 (generating 6670 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7042, C1=378
#
# --- Processing target ratio w (165/200): 19.5197 ---
#   INFO: Strategy: Oversample class 0 from 372 to 7378 (generating 7006 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7378, C1=378
#
# --- Processing target ratio w (166/200): 20.4524 ---
#   INFO: Strategy: Oversample class 0 from 372 to 7731 (generating 7359 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7731, C1=378
#
# --- Processing target ratio w (167/200): 21.4297 ---
#   INFO: Strategy: Oversample class 0 from 372 to 8100 (generating 7728 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8100, C1=378
#
# --- Processing target ratio w (168/200): 22.4538 ---
#   INFO: Strategy: Oversample class 0 from 372 to 8488 (generating 8116 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8488, C1=378
#
# --- Processing target ratio w (169/200): 23.5267 ---
#   INFO: Strategy: Oversample class 0 from 372 to 8893 (generating 8521 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8893, C1=378
#
# --- Processing target ratio w (170/200): 24.6510 ---
#   INFO: Strategy: Oversample class 0 from 372 to 9318 (generating 8946 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=9318, C1=378
#
# --- Processing target ratio w (171/200): 25.8289 ---
#   INFO: Strategy: Oversample class 0 from 372 to 9763 (generating 9391 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=9763, C1=378
#
# --- Processing target ratio w (172/200): 27.0631 ---
#   INFO: Strategy: Oversample class 0 from 372 to 10230 (generating 9858 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=10230, C1=378
#
# --- Processing target ratio w (173/200): 28.3563 ---
#   INFO: Strategy: Oversample class 0 from 372 to 10719 (generating 10347 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=10719, C1=378
#
# --- Processing target ratio w (174/200): 29.7114 ---
#   INFO: Strategy: Oversample class 0 from 372 to 11231 (generating 10859 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=11231, C1=378
#
# --- Processing target ratio w (175/200): 31.1311 ---
#   INFO: Strategy: Oversample class 0 from 372 to 11768 (generating 11396 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=11768, C1=378
#
# --- Processing target ratio w (176/200): 32.6187 ---
#   INFO: Strategy: Oversample class 0 from 372 to 12330 (generating 11958 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=12330, C1=378
#
# --- Processing target ratio w (177/200): 34.1774 ---
#   INFO: Strategy: Oversample class 0 from 372 to 12919 (generating 12547 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=12919, C1=378
#
# --- Processing target ratio w (178/200): 35.8106 ---
#   INFO: Strategy: Oversample class 0 from 372 to 13536 (generating 13164 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=13536, C1=378
#
# --- Processing target ratio w (179/200): 37.5218 ---
#   INFO: Strategy: Oversample class 0 from 372 to 14183 (generating 13811 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=14183, C1=378
#
# --- Processing target ratio w (180/200): 39.3148 ---
#   INFO: Strategy: Oversample class 0 from 372 to 14861 (generating 14489 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=14861, C1=378
#
# --- Processing target ratio w (181/200): 41.1934 ---
#   INFO: Strategy: Oversample class 0 from 372 to 15571 (generating 15199 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=15571, C1=378
#
# --- Processing target ratio w (182/200): 43.1619 ---
#   INFO: Strategy: Oversample class 0 from 372 to 16315 (generating 15943 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
# ...
#   INFO: KDE-like generation complete. New C0=1988, C1=384
#
# --- Processing target ratio w (138/200): 5.4252 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2083 (generating 1717 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2083, C1=384
#
# --- Processing target ratio w (139/200): 5.6863 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2184 (generating 1818 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2184, C1=384
#
# --- Processing target ratio w (140/200): 5.9599 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2289 (generating 1923 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2289, C1=384
#
# --- Processing target ratio w (141/200): 6.2468 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2399 (generating 2033 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2399, C1=384
#
# --- Processing target ratio w (142/200): 6.5474 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2514 (generating 2148 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2514, C1=384
#
# --- Processing target ratio w (143/200): 6.8625 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2635 (generating 2269 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2635, C1=384
#
# --- Processing target ratio w (144/200): 7.1927 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2762 (generating 2396 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2762, C1=384
#
# --- Processing target ratio w (145/200): 7.5389 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2895 (generating 2529 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2895, C1=384
#
# --- Processing target ratio w (146/200): 7.9017 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3034 (generating 2668 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3034, C1=384
#
# --- Processing target ratio w (147/200): 8.2819 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3180 (generating 2814 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3180, C1=384
#
# --- Processing target ratio w (148/200): 8.6805 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3333 (generating 2967 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3333, C1=384
#
# --- Processing target ratio w (149/200): 9.0982 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3494 (generating 3128 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3494, C1=384
#
# --- Processing target ratio w (150/200): 9.5361 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3662 (generating 3296 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3662, C1=384
#
# --- Processing target ratio w (151/200): 9.9950 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3838 (generating 3472 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3838, C1=384
#
# --- Processing target ratio w (152/200): 10.4760 ---
#   INFO: Strategy: Oversample class 0 from 366 to 4023 (generating 3657 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4023, C1=384
#
# --- Processing target ratio w (153/200): 10.9801 ---
#   INFO: Strategy: Oversample class 0 from 366 to 4216 (generating 3850 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4216, C1=384
#
# --- Processing target ratio w (154/200): 11.5085 ---
#   INFO: Strategy: Oversample class 0 from 366 to 4419 (generating 4053 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4419, C1=384
#
# --- Processing target ratio w (155/200): 12.0623 ---
#   INFO: Strategy: Oversample class 0 from 366 to 4632 (generating 4266 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4632, C1=384
#
# --- Processing target ratio w (156/200): 12.6428 ---
#   INFO: Strategy: Oversample class 0 from 366 to 4855 (generating 4489 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4855, C1=384
#
# --- Processing target ratio w (157/200): 13.2513 ---
#   INFO: Strategy: Oversample class 0 from 366 to 5088 (generating 4722 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5088, C1=384
#
# --- Processing target ratio w (158/200): 13.8890 ---
#   INFO: Strategy: Oversample class 0 from 366 to 5333 (generating 4967 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5333, C1=384
#
# --- Processing target ratio w (159/200): 14.5573 ---
#   INFO: Strategy: Oversample class 0 from 366 to 5590 (generating 5224 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5590, C1=384
#
# --- Processing target ratio w (160/200): 15.2579 ---
#   INFO: Strategy: Oversample class 0 from 366 to 5859 (generating 5493 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5859, C1=384
#
# --- Processing target ratio w (161/200): 15.9922 ---
#   INFO: Strategy: Oversample class 0 from 366 to 6141 (generating 5775 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6141, C1=384
#
# --- Processing target ratio w (162/200): 16.7618 ---
#   INFO: Strategy: Oversample class 0 from 366 to 6437 (generating 6071 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6437, C1=384
#
# --- Processing target ratio w (163/200): 17.5684 ---
#   INFO: Strategy: Oversample class 0 from 366 to 6746 (generating 6380 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6746, C1=384
#
# --- Processing target ratio w (164/200): 18.4139 ---
#   INFO: Strategy: Oversample class 0 from 366 to 7071 (generating 6705 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7071, C1=384
#
# --- Processing target ratio w (165/200): 19.3000 ---
#   INFO: Strategy: Oversample class 0 from 366 to 7411 (generating 7045 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7411, C1=384
#
# --- Processing target ratio w (166/200): 20.2288 ---
#   INFO: Strategy: Oversample class 0 from 366 to 7768 (generating 7402 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7768, C1=384
#
# --- Processing target ratio w (167/200): 21.2023 ---
#   INFO: Strategy: Oversample class 0 from 366 to 8142 (generating 7776 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8142, C1=384
#
# --- Processing target ratio w (168/200): 22.2227 ---
#   INFO: Strategy: Oversample class 0 from 366 to 8533 (generating 8167 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8533, C1=384
#
# --- Processing target ratio w (169/200): 23.2921 ---
#   INFO: Strategy: Oversample class 0 from 366 to 8944 (generating 8578 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8944, C1=384
#
# --- Processing target ratio w (170/200): 24.4130 ---
#   INFO: Strategy: Oversample class 0 from 366 to 9375 (generating 9009 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=9375, C1=384
#
# --- Processing target ratio w (171/200): 25.5879 ---
#   INFO: Strategy: Oversample class 0 from 366 to 9826 (generating 9460 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=9826, C1=384
#
# --- Processing target ratio w (172/200): 26.8192 ---
#   INFO: Strategy: Oversample class 0 from 366 to 10299 (generating 9933 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=10299, C1=384
#
# --- Processing target ratio w (173/200): 28.1099 ---
#   INFO: Strategy: Oversample class 0 from 366 to 10794 (generating 10428 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=10794, C1=384
#
# --- Processing target ratio w (174/200): 29.4626 ---
#   INFO: Strategy: Oversample class 0 from 366 to 11314 (generating 10948 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=11314, C1=384
#
# --- Processing target ratio w (175/200): 30.8805 ---
#   INFO: Strategy: Oversample class 0 from 366 to 11858 (generating 11492 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=11858, C1=384
#
# --- Processing target ratio w (176/200): 32.3666 ---
#   INFO: Strategy: Oversample class 0 from 366 to 12429 (generating 12063 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=12429, C1=384
#
# --- Processing target ratio w (177/200): 33.9242 ---
#   INFO: Strategy: Oversample class 0 from 366 to 13027 (generating 12661 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=13027, C1=384
#
# --- Processing target ratio w (178/200): 35.5568 ---
#   INFO: Strategy: Oversample class 0 from 366 to 13654 (generating 13288 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=13654, C1=384
#
# --- Processing target ratio w (179/200): 37.2679 ---
#   INFO: Strategy: Oversample class 0 from 366 to 14311 (generating 13945 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=14311, C1=384
#
# --- Processing target ratio w (180/200): 39.0614 ---
#   INFO: Strategy: Oversample class 0 from 366 to 15000 (generating 14634 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=15000, C1=384
#
# --- Processing target ratio w (181/200): 40.9412 ---
#   INFO: Strategy: Oversample class 0 from 366 to 15721 (generating 15355 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=15721, C1=384
#
# --- Processing target ratio w (182/200): 42.9114 ---
#   INFO: Strategy: Oversample class 0 from 366 to 16478 (generating 16112 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=16478, C1=384
#
# --- Processing target ratio w (183/200): 44.9765 ---
#   INFO: Strategy: Oversample class 0 from 366 to 17271 (generating 16905 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=17271, C1=384
#
# --- Processing target ratio w (184/200): 47.1409 ---
#   INFO: Strategy: Oversample class 0 from 366 to 18102 (generating 17736 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=18102, C1=384
#
# --- Processing target ratio w (185/200): 49.4095 ---
#   INFO: Strategy: Oversample class 0 from 366 to 18973 (generating 18607 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=18973, C1=384
#
# --- Processing target ratio w (186/200): 51.7873 ---
#   INFO: Strategy: Oversample class 0 from 366 to 19886 (generating 19520 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=19886, C1=384
#
# --- Processing target ratio w (187/200): 54.2795 ---
#   INFO: Strategy: Oversample class 0 from 366 to 20843 (generating 20477 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=20843, C1=384
#
# --- Processing target ratio w (188/200): 56.8916 ---
#   INFO: Strategy: Oversample class 0 from 366 to 21846 (generating 21480 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=21846, C1=384
#
# --- Processing target ratio w (189/200): 59.6295 ---
#   INFO: Strategy: Oversample class 0 from 366 to 22898 (generating 22532 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=22898, C1=384
#
# --- Processing target ratio w (190/200): 62.4991 ---
#   INFO: Strategy: Oversample class 0 from 366 to 24000 (generating 23634 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=24000, C1=384
#
# --- Processing target ratio w (191/200): 65.5068 ---
#   INFO: Strategy: Oversample class 0 from 366 to 25155 (generating 24789 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=25155, C1=384
#
# --- Processing target ratio w (192/200): 68.6592 ---
#   INFO: Strategy: Oversample class 0 from 366 to 26365 (generating 25999 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=26365, C1=384
#
# --- Processing target ratio w (193/200): 71.9634 ---
#   INFO: Strategy: Oversample class 0 from 366 to 27634 (generating 27268 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=27634, C1=384
#
# --- Processing target ratio w (194/200): 75.4265 ---
#   INFO: Strategy: Oversample class 0 from 366 to 28964 (generating 28598 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=28964, C1=384
#
# --- Processing target ratio w (195/200): 79.0564 ---
#   INFO: Strategy: Oversample class 0 from 366 to 30358 (generating 29992 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=30358, C1=384
#
# --- Processing target ratio w (196/200): 82.8609 ---
#   INFO: Strategy: Oversample class 0 from 366 to 31819 (generating 31453 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=31819, C1=384
#
# --- Processing target ratio w (197/200): 86.8485 ---
#   INFO: Strategy: Oversample class 0 from 366 to 33350 (generating 32984 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=33350, C1=384
#
# --- Processing target ratio w (198/200): 91.0279 ---
#   INFO: Strategy: Oversample class 0 from 366 to 34955 (generating 34589 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=34955, C1=384
#
# --- Processing target ratio w (199/200): 95.4086 ---
#   INFO: Strategy: Oversample class 0 from 366 to 36637 (generating 36271 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=36637, C1=384
#
# --- Processing target ratio w (200/200): 100.0000 ---
#   INFO: Strategy: Oversample class 0 from 366 to 38400 (generating 38034 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=38400, C1=384

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
plot_roc_comparison(
    results_lists=results_lists,
    names=["Fold 1", "Fold 2", "Fold 3", "Fold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4"],
    results_original_roc=results_original_roc
)

# %% [markdown]
# ### Ensemble prediction using voting

# %%
# --- Loop through all the FPR values to generate the ensemble ROC curve ---

ensemble_results_soft = []
ensemble_results_hard = []

print("\n--- Generating Ensemble ROC Curve by iterating through FPR values ---")
# We iterate from a low to high target_fpr to trace the curve
for target_fpr in np.linspace(0.0, 1.0, 50): 
    # 1. Assign the function's output to a single variable first.
    result_tuple = predict_ensemble_and_evaluate(
        list_folds_best_models=list_folds_best_models,
        test_loader=test_loader,
        target_fpr=target_fpr
    )
    
    if result_tuple is not None:
        
        for voting_method, metrics in result_tuple.items():
            # Create a dictionary for each point and append it to the list
            if voting_method == 'soft_voting':
                point_dict = {'fpr': metrics['fpr'], 'tpr': metrics['tpr']}
                ensemble_results_soft.append(point_dict)
            else:
                point_dict = {'fpr': metrics['fpr'], 'tpr': metrics['tpr']}
                ensemble_results_hard.append(point_dict)
            
        
# Ensure the curve starts at (0, 0)
    if not ensemble_results_soft or ensemble_results_soft[0]['fpr'] > 0.0:
        ensemble_results_soft.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if ensemble_results_soft[-1]['fpr'] < 1.0 or ensemble_results_soft[-1]['tpr'] < 1.0:
        ensemble_results_soft.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    if not ensemble_results_hard or ensemble_results_hard[0]['fpr'] > 0.0:
        ensemble_results_hard.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if ensemble_results_hard[-1]['fpr'] < 1.0 or ensemble_results_hard[-1]['tpr'] < 1.0:
        ensemble_results_hard.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })
# Out:
# --- Generating Ensemble ROC Curve by iterating through FPR values ---
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0000
# Soft Voting -> Achieved [TPR: 0.0000, FPR: 0.0000]
# Hard Voting -> Resulted in [TPR: 0.0000, FPR: 0.0000]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0204
# Soft Voting -> Achieved [TPR: 0.3300, FPR: 0.0200]
# Hard Voting -> Resulted in [TPR: 0.3700, FPR: 0.0233]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0408
# Soft Voting -> Achieved [TPR: 0.3867, FPR: 0.0400]
# Hard Voting -> Resulted in [TPR: 0.4033, FPR: 0.0367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0612
# Soft Voting -> Achieved [TPR: 0.4200, FPR: 0.0600]
# Hard Voting -> Resulted in [TPR: 0.4200, FPR: 0.0600]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0816
# Soft Voting -> Achieved [TPR: 0.4300, FPR: 0.0900]
# Hard Voting -> Resulted in [TPR: 0.4367, FPR: 0.0800]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1020
# Soft Voting -> Achieved [TPR: 0.4367, FPR: 0.1133]
# Hard Voting -> Resulted in [TPR: 0.4367, FPR: 0.0800]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1224
# Soft Voting -> Achieved [TPR: 0.4467, FPR: 0.1200]
# Hard Voting -> Resulted in [TPR: 0.4400, FPR: 0.0833]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1429
# Soft Voting -> Achieved [TPR: 0.4533, FPR: 0.1400]
# Hard Voting -> Resulted in [TPR: 0.4433, FPR: 0.0900]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1633
# Soft Voting -> Achieved [TPR: 0.4600, FPR: 0.1500]
# Hard Voting -> Resulted in [TPR: 0.4467, FPR: 0.1167]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1837
# Soft Voting -> Achieved [TPR: 0.4600, FPR: 0.1500]
# Hard Voting -> Resulted in [TPR: 0.4367, FPR: 0.1167]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2041
# Soft Voting -> Achieved [TPR: 0.4600, FPR: 0.2000]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.2333]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2245
# Soft Voting -> Achieved [TPR: 0.4600, FPR: 0.2000]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.2333]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2449
# Soft Voting -> Achieved [TPR: 0.4600, FPR: 0.2000]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.2333]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2653
# Soft Voting -> Achieved [TPR: 0.4633, FPR: 0.2900]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.2367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2857
# Soft Voting -> Achieved [TPR: 0.4633, FPR: 0.2900]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.2367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3061
# Soft Voting -> Achieved [TPR: 0.4633, FPR: 0.2900]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.2367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3265
# Soft Voting -> Achieved [TPR: 0.4567, FPR: 0.3400]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.3267]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3469
# Soft Voting -> Achieved [TPR: 0.4567, FPR: 0.3400]
# Hard Voting -> Resulted in [TPR: 0.4633, FPR: 0.3267]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3673
# Soft Voting -> Achieved [TPR: 0.0667, FPR: 0.3633]
# Hard Voting -> Resulted in [TPR: 0.2467, FPR: 0.2933]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3878
# Soft Voting -> Achieved [TPR: 0.0367, FPR: 0.3867]
# Hard Voting -> Resulted in [TPR: 0.2500, FPR: 0.3667]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4082
# Soft Voting -> Achieved [TPR: 0.0200, FPR: 0.4067]
# Hard Voting -> Resulted in [TPR: 0.0000, FPR: 0.3367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4286
# Soft Voting -> Achieved [TPR: 0.0233, FPR: 0.4267]
# Hard Voting -> Resulted in [TPR: 0.0100, FPR: 0.3733]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4490
# Soft Voting -> Achieved [TPR: 0.0333, FPR: 0.4467]
# Hard Voting -> Resulted in [TPR: 0.3067, FPR: 0.5367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4694
# Soft Voting -> Achieved [TPR: 0.0400, FPR: 0.4667]
# Hard Voting -> Resulted in [TPR: 0.3533, FPR: 0.5400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4898
# Soft Voting -> Achieved [TPR: 0.0600, FPR: 0.4900]
# Hard Voting -> Resulted in [TPR: 0.7600, FPR: 0.5467]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.5102
# Soft Voting -> Achieved [TPR: 0.0833, FPR: 0.5100]
# Hard Voting -> Resulted in [TPR: 0.7800, FPR: 0.5467]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.5306
# Soft Voting -> Achieved [TPR: 0.2033, FPR: 0.5300]
# Hard Voting -> Resulted in [TPR: 0.8900, FPR: 0.5600]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.5510
# Soft Voting -> Achieved [TPR: 0.8367, FPR: 0.5500]
# Hard Voting -> Resulted in [TPR: 0.9500, FPR: 0.5867]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.5714
# Soft Voting -> Achieved [TPR: 0.9233, FPR: 0.5700]
# Hard Voting -> Resulted in [TPR: 0.9500, FPR: 0.5867]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.5918
# Soft Voting -> Achieved [TPR: 0.9500, FPR: 0.5900]
# Hard Voting -> Resulted in [TPR: 0.9833, FPR: 0.6367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.6122
# Soft Voting -> Achieved [TPR: 0.9800, FPR: 0.6067]
# Hard Voting -> Resulted in [TPR: 0.9833, FPR: 0.6367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.6327
# Soft Voting -> Achieved [TPR: 0.9833, FPR: 0.6367]
# Hard Voting -> Resulted in [TPR: 0.9833, FPR: 0.6367]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.6531
# Soft Voting -> Achieved [TPR: 0.9833, FPR: 0.6367]
# Hard Voting -> Resulted in [TPR: 0.9867, FPR: 0.6433]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.6735
# Soft Voting -> Achieved [TPR: 0.9867, FPR: 0.6867]
# Hard Voting -> Resulted in [TPR: 0.9867, FPR: 0.6433]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.6939
# Soft Voting -> Achieved [TPR: 0.9867, FPR: 0.6867]
# Hard Voting -> Resulted in [TPR: 0.9900, FPR: 0.7067]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.7143
# Soft Voting -> Achieved [TPR: 0.9933, FPR: 0.7200]
# Hard Voting -> Resulted in [TPR: 0.9967, FPR: 0.7167]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.7347
# Soft Voting -> Achieved [TPR: 0.9933, FPR: 0.7333]
# Hard Voting -> Resulted in [TPR: 1.0000, FPR: 0.7467]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.7551
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.7467]
# Hard Voting -> Resulted in [TPR: 1.0000, FPR: 0.7467]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.7755
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.7467]
# Hard Voting -> Resulted in [TPR: 1.0000, FPR: 0.7467]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
#
# --- Ensemble Results ---
# Target FPR: 0.7959
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.7433]
# Hard Voting -> Resulted in [TPR: 0.9967, FPR: 0.7467]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
#
# --- Ensemble Results ---
# Target FPR: 0.8163
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.7500]
# Hard Voting -> Resulted in [TPR: 1.0000, FPR: 1.0000]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
#
# --- Ensemble Results ---
# Target FPR: 0.8367
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.7500]
# Hard Voting -> Resulted in [TPR: 1.0000, FPR: 1.0000]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
#
# --- Ensemble Results ---
# Target FPR: 0.8571
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.7500]
# Hard Voting -> Resulted in [TPR: 1.0000, FPR: 1.0000]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
#
# --- Ensemble Results ---
# Target FPR: 0.8776
# Soft Voting -> Achieved [TPR: 1.0000, FPR: 1.0000]
# Hard Voting -> Resulted in [TPR: 1.0000, FPR: 1.0000]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
results_lists.append(ensemble_results_soft)
results_lists.append(ensemble_results_hard)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["Fold 1", "Fold 2", "Fold 3", "Fold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Ensemble_voting_soft", "Ensemble_voting_hard"],
    results_original_roc=results_original_roc
)
# Out:
# --- Plotting all ROC curves for comparison ---
