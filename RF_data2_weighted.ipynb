# %% [markdown]
# ### Import

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        #y_prob = clf_model.predict_proba(X_test)[:, 1]
        #y_pred = (y_prob >= threshold).astype(int)
        y_pred = clf_model.predict(X_test)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data2")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Regular training

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "RF Regression", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Weighted ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds
# Weight the X_train and y_train for cost-sensitive learning
minority_class_weight = np.arange(0.001, 0.999, 0.01)
majority_class_weight = 1.0 - minority_class_weight
list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    for w in minority_class_weight:
        class_weights = {0: 1 - w, 1: w}

        clf_weighted = RandomForestClassifier(class_weight=class_weights, random_state=42)
        clf_weighted.fit(X_train_fold, y_train_fold)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# --- Starting Fold 2/4 ---
# --- Starting Fold 3/4 ---
# --- Starting Fold 4/4 ---

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Save the data
save_to_pickle(list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader, filename='pickle/RF_data2_weighted.pkl')
# Out:
# Data saved to pickle/RF_data2_weighted.pkl
# {'best_models': [[{'model': RandomForestClassifier(class_weight={0: np.float64(0.779),
#                                          1: np.float64(0.22099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.45901639344262296),
#     'threshold': np.float64(0.94)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5390000000000001),
#                                          1: np.float64(0.4609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0078125),
#     'tpr': np.float64(0.47540983606557374),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.769),
#                                          1: np.float64(0.23099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.015625),
#     'tpr': np.float64(0.48360655737704916),
#     'threshold': np.float64(0.9)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.769),
#                                          1: np.float64(0.23099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.0234375),
#     'tpr': np.float64(0.4918032786885246),
#     'threshold': np.float64(0.88)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.909),
#                                          1: np.float64(0.09099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.0390625),
#     'tpr': np.float64(0.5163934426229508),
#     'threshold': np.float64(0.88)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.0546875),
#     'tpr': np.float64(0.5245901639344263),
#     'threshold': np.float64(0.81)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.009000000000000119),
#                                          1: np.float64(0.9909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0625),
#     'tpr': np.float64(0.5491803278688525),
#     'threshold': np.float64(0.77)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0703125),
#     'tpr': np.float64(0.5573770491803278),
#     'threshold': np.float64(0.77)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5390000000000001),
#                                          1: np.float64(0.4609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.078125),
#     'tpr': np.float64(0.5737704918032787),
#     'threshold': np.float64(0.76)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.859),
#                                          1: np.float64(0.141)},
#                            random_state=42),
#     'fpr': np.float64(0.0859375),
#     'tpr': np.float64(0.5819672131147541),
#     'threshold': np.float64(0.79)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.859),
#                                          1: np.float64(0.141)},
#                            random_state=42),
#     'fpr': np.float64(0.09375),
#     'tpr': np.float64(0.5983606557377049),
#     'threshold': np.float64(0.78)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4790000000000001),
#                                          1: np.float64(0.5209999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.109375),
#     'tpr': np.float64(0.6229508196721312),
#     'threshold': np.float64(0.73)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4790000000000001),
#                                          1: np.float64(0.5209999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.125),
#     'tpr': np.float64(0.6311475409836066),
#     'threshold': np.float64(0.71)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.619),
#                                          1: np.float64(0.38099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.1328125),
#     'tpr': np.float64(0.6475409836065574),
#     'threshold': np.float64(0.69)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.26900000000000013),
#                                          1: np.float64(0.7309999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.140625),
#     'tpr': np.float64(0.6721311475409836),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1484375),
#     'tpr': np.float64(0.680327868852459),
#     'threshold': np.float64(0.64)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2290000000000001),
#                                          1: np.float64(0.7709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.15625),
#     'tpr': np.float64(0.6885245901639344),
#     'threshold': np.float64(0.66)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2290000000000001),
#                                          1: np.float64(0.7709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.171875),
#     'tpr': np.float64(0.7049180327868853),
#     'threshold': np.float64(0.63)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1953125),
#     'tpr': np.float64(0.7131147540983607),
#     'threshold': np.float64(0.61)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3490000000000001),
#                                          1: np.float64(0.6509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2109375),
#     'tpr': np.float64(0.7213114754098361),
#     'threshold': np.float64(0.61)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.549),
#                                          1: np.float64(0.45099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.2265625),
#     'tpr': np.float64(0.7295081967213115),
#     'threshold': np.float64(0.58)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.899),
#                                          1: np.float64(0.10099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.234375),
#     'tpr': np.float64(0.7377049180327869),
#     'threshold': np.float64(0.59)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.549),
#                                          1: np.float64(0.45099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.2421875),
#     'tpr': np.float64(0.7459016393442623),
#     'threshold': np.float64(0.57)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.799),
#                                          1: np.float64(0.20099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.265625),
#     'tpr': np.float64(0.7622950819672131),
#     'threshold': np.float64(0.54)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.2890625),
#     'tpr': np.float64(0.7704918032786885),
#     'threshold': np.float64(0.51)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.6890000000000001),
#                                          1: np.float64(0.31099999999999994)},
#                            random_state=42),
#     'fpr': np.float64(0.3046875),
#     'tpr': np.float64(0.7786885245901639),
#     'threshold': np.float64(0.49)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.3125),
#     'tpr': np.float64(0.7950819672131147),
#     'threshold': np.float64(0.47)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.3203125),
#     'tpr': np.float64(0.8032786885245902),
#     'threshold': np.float64(0.45)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.549),
#                                          1: np.float64(0.45099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.328125),
#     'tpr': np.float64(0.8114754098360656),
#     'threshold': np.float64(0.47)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5890000000000001),
#                                          1: np.float64(0.4109999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3359375),
#     'tpr': np.float64(0.819672131147541),
#     'threshold': np.float64(0.44)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.019000000000000128),
#                                          1: np.float64(0.9809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.34375),
#     'tpr': np.float64(0.8278688524590164),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.929),
#                                          1: np.float64(0.071)},
#                            random_state=42),
#     'fpr': np.float64(0.3515625),
#     'tpr': np.float64(0.8360655737704918),
#     'threshold': np.float64(0.41)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4790000000000001),
#                                          1: np.float64(0.5209999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.359375),
#     'tpr': np.float64(0.8524590163934426),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4790000000000001),
#                                          1: np.float64(0.5209999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.375),
#     'tpr': np.float64(0.860655737704918),
#     'threshold': np.float64(0.39)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5390000000000001),
#                                          1: np.float64(0.4609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3828125),
#     'tpr': np.float64(0.8688524590163934),
#     'threshold': np.float64(0.37)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4990000000000001),
#                                          1: np.float64(0.5009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.390625),
#     'tpr': np.float64(0.8770491803278688),
#     'threshold': np.float64(0.36)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.43900000000000006),
#                                          1: np.float64(0.5609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.40625),
#     'tpr': np.float64(0.8852459016393442),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.43900000000000006),
#                                          1: np.float64(0.5609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.4140625),
#     'tpr': np.float64(0.8934426229508197),
#     'threshold': np.float64(0.31)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.43900000000000006),
#                                          1: np.float64(0.5609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.4296875),
#     'tpr': np.float64(0.9016393442622951),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.453125),
#     'tpr': np.float64(0.9098360655737705),
#     'threshold': np.float64(0.29)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5990000000000001),
#                                          1: np.float64(0.4009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.4609375),
#     'tpr': np.float64(0.9180327868852459),
#     'threshold': np.float64(0.26)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.769),
#                                          1: np.float64(0.23099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.46875),
#     'tpr': np.float64(0.9262295081967213),
#     'threshold': np.float64(0.26)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.47),
#     'tpr': np.float64(0.9266666666666666),
#     'threshold': np.float64(0.25)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.4765625),
#     'tpr': np.float64(0.9344262295081968),
#     'threshold': np.float64(0.25)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.48),
#     'tpr': np.float64(0.9366666666666666),
#     'threshold': np.float64(0.23)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.48333333333333334),
#     'tpr': np.float64(0.94),
#     'threshold': np.float64(0.22)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.484375),
#     'tpr': np.float64(0.9426229508196722),
#     'threshold': np.float64(0.24)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.559),
#                                          1: np.float64(0.44099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.4921875),
#     'tpr': np.float64(0.9508196721311475),
#     'threshold': np.float64(0.2)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.49333333333333335),
#     'tpr': np.float64(0.9533333333333334),
#     'threshold': np.float64(0.19)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.639),
#                                          1: np.float64(0.36099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(0.9590163934426229),
#     'threshold': np.float64(0.18)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.5033333333333333),
#     'tpr': np.float64(0.96),
#     'threshold': np.float64(0.18)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.5133333333333333),
#     'tpr': np.float64(0.9633333333333334),
#     'threshold': np.float64(0.17)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.17900000000000016),
#                                          1: np.float64(0.8209999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.515625),
#     'tpr': np.float64(0.9754098360655737),
#     'threshold': np.float64(0.15)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.5266666666666666),
#     'tpr': np.float64(0.9866666666666667),
#     'threshold': np.float64(0.13)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.53),
#     'tpr': np.float64(0.99),
#     'threshold': np.float64(0.12)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.06900000000000017),
#                                          1: np.float64(0.9309999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.5546875),
#     'tpr': np.float64(0.9918032786885246),
#     'threshold': np.float64(0.1)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.56),
#     'tpr': np.float64(0.9933333333333333),
#     'threshold': np.float64(0.07)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.5625),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.08)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': RandomForestClassifier(class_weight={0: np.float64(0.829),
#                                          1: np.float64(0.17099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.44696969696969696),
#     'threshold': np.float64(0.9)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.00847457627118644),
#     'tpr': np.float64(0.4621212121212121),
#     'threshold': np.float64(0.88)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.013333333333333334),
#     'tpr': np.float64(0.4633333333333333),
#     'threshold': np.float64(0.87)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.769),
#                                          1: np.float64(0.23099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.01694915254237288),
#     'tpr': np.float64(0.4772727272727273),
#     'threshold': np.float64(0.82)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.03389830508474576),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.78)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0423728813559322),
#     'tpr': np.float64(0.5075757575757576),
#     'threshold': np.float64(0.77)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.849),
#                                          1: np.float64(0.15099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.05084745762711865),
#     'tpr': np.float64(0.5378787878787878),
#     'threshold': np.float64(0.74)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.859),
#                                          1: np.float64(0.141)},
#                            random_state=42),
#     'fpr': np.float64(0.059322033898305086),
#     'tpr': np.float64(0.553030303030303),
#     'threshold': np.float64(0.7)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3690000000000001),
#                                          1: np.float64(0.6309999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.06779661016949153),
#     'tpr': np.float64(0.5757575757575758),
#     'threshold': np.float64(0.69)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3690000000000001),
#                                          1: np.float64(0.6309999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.07627118644067797),
#     'tpr': np.float64(0.5833333333333334),
#     'threshold': np.float64(0.68)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3690000000000001),
#                                          1: np.float64(0.6309999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.09322033898305085),
#     'tpr': np.float64(0.5984848484848485),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.809),
#                                          1: np.float64(0.19099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.11864406779661017),
#     'tpr': np.float64(0.6060606060606061),
#     'threshold': np.float64(0.66)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4990000000000001),
#                                          1: np.float64(0.5009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1271186440677966),
#     'tpr': np.float64(0.6136363636363636),
#     'threshold': np.float64(0.64)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.09900000000000009),
#                                          1: np.float64(0.9009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.13559322033898305),
#     'tpr': np.float64(0.6212121212121212),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.029000000000000137),
#                                          1: np.float64(0.9709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1440677966101695),
#     'tpr': np.float64(0.6287878787878788),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3890000000000001),
#                                          1: np.float64(0.6109999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.15254237288135594),
#     'tpr': np.float64(0.6363636363636364),
#     'threshold': np.float64(0.61)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16),
#     'tpr': np.float64(0.6366666666666667),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.16101694915254236),
#     'tpr': np.float64(0.6590909090909091),
#     'threshold': np.float64(0.59)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.18),
#     'tpr': np.float64(0.6633333333333333),
#     'threshold': np.float64(0.58)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.09900000000000009),
#                                          1: np.float64(0.9009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1864406779661017),
#     'tpr': np.float64(0.6893939393939394),
#     'threshold': np.float64(0.57)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21333333333333335),
#     'tpr': np.float64(0.69),
#     'threshold': np.float64(0.55)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.09900000000000009),
#                                          1: np.float64(0.9009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.22033898305084745),
#     'tpr': np.float64(0.7045454545454546),
#     'threshold': np.float64(0.55)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.22666666666666666),
#     'tpr': np.float64(0.7066666666666667),
#     'threshold': np.float64(0.54)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.42900000000000005),
#                                          1: np.float64(0.571)},
#                            random_state=42),
#     'fpr': np.float64(0.2288135593220339),
#     'tpr': np.float64(0.7196969696969697),
#     'threshold': np.float64(0.52)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2390000000000001),
#                                          1: np.float64(0.7609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2457627118644068),
#     'tpr': np.float64(0.7272727272727273),
#     'threshold': np.float64(0.53)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2390000000000001),
#                                          1: np.float64(0.7609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2542372881355932),
#     'tpr': np.float64(0.7424242424242424),
#     'threshold': np.float64(0.52)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2390000000000001),
#                                          1: np.float64(0.7609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2796610169491525),
#     'tpr': np.float64(0.75),
#     'threshold': np.float64(0.51)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.999),
#                                          1: np.float64(0.001)},
#                            random_state=42),
#     'fpr': np.float64(0.2966101694915254),
#     'tpr': np.float64(0.7575757575757576),
#     'threshold': np.float64(0.49)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.3),
#     'tpr': np.float64(0.76),
#     'threshold': np.float64(0.47)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.649),
#                                          1: np.float64(0.3509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3050847457627119),
#     'tpr': np.float64(0.7651515151515151),
#     'threshold': np.float64(0.47)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.31),
#     'tpr': np.float64(0.7666666666666667),
#     'threshold': np.float64(0.46)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2290000000000001),
#                                          1: np.float64(0.7709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3135593220338983),
#     'tpr': np.float64(0.7803030303030303),
#     'threshold': np.float64(0.47)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.649),
#                                          1: np.float64(0.3509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3220338983050847),
#     'tpr': np.float64(0.7878787878787878),
#     'threshold': np.float64(0.46)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2290000000000001),
#                                          1: np.float64(0.7709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3305084745762712),
#     'tpr': np.float64(0.7954545454545454),
#     'threshold': np.float64(0.45)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.649),
#                                          1: np.float64(0.3509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3474576271186441),
#     'tpr': np.float64(0.8106060606060606),
#     'threshold': np.float64(0.45)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.18900000000000017),
#                                          1: np.float64(0.8109999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.3559322033898305),
#     'tpr': np.float64(0.8181818181818182),
#     'threshold': np.float64(0.38)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.18900000000000017),
#                                          1: np.float64(0.8109999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.3644067796610169),
#     'tpr': np.float64(0.8257575757575758),
#     'threshold': np.float64(0.37)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.26900000000000013),
#                                          1: np.float64(0.7309999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3728813559322034),
#     'tpr': np.float64(0.8333333333333334),
#     'threshold': np.float64(0.42)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.06900000000000017),
#                                          1: np.float64(0.9309999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.3813559322033898),
#     'tpr': np.float64(0.8787878787878788),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.43900000000000006),
#                                          1: np.float64(0.5609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.4067796610169492),
#     'tpr': np.float64(0.8863636363636364),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.6890000000000001),
#                                          1: np.float64(0.31099999999999994)},
#                            random_state=42),
#     'fpr': np.float64(0.4152542372881356),
#     'tpr': np.float64(0.9090909090909091),
#     'threshold': np.float64(0.33)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.4322033898305085),
#     'tpr': np.float64(0.9393939393939394),
#     'threshold': np.float64(0.32)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.4406779661016949),
#     'tpr': np.float64(0.946969696969697),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.899),
#                                          1: np.float64(0.10099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.4576271186440678),
#     'tpr': np.float64(0.9621212121212122),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.4661016949152542),
#     'tpr': np.float64(0.9696969696969697),
#     'threshold': np.float64(0.26)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.4745762711864407),
#     'tpr': np.float64(0.9772727272727273),
#     'threshold': np.float64(0.25)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.759),
#                                          1: np.float64(0.24099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.5084745762711864),
#     'tpr': np.float64(0.9848484848484849),
#     'threshold': np.float64(0.21)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.5254237288135594),
#     'tpr': np.float64(0.9924242424242424),
#     'threshold': np.float64(0.08)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.009000000000000119),
#                                          1: np.float64(0.9909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.559322033898305),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.04)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': RandomForestClassifier(class_weight={0: np.float64(0.4690000000000001),
#                                          1: np.float64(0.5309999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.5076923076923077),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.1090000000000001),
#                                          1: np.float64(0.8909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.008333333333333333),
#     'tpr': np.float64(0.5461538461538461),
#     'threshold': np.float64(0.88)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3590000000000001),
#                                          1: np.float64(0.6409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.016666666666666666),
#     'tpr': np.float64(0.5692307692307692),
#     'threshold': np.float64(0.84)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.929),
#                                          1: np.float64(0.071)},
#                            random_state=42),
#     'fpr': np.float64(0.025),
#     'tpr': np.float64(0.6),
#     'threshold': np.float64(0.86)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.779),
#                                          1: np.float64(0.22099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.041666666666666664),
#     'tpr': np.float64(0.6230769230769231),
#     'threshold': np.float64(0.82)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7190000000000001),
#                                          1: np.float64(0.28099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.05),
#     'tpr': np.float64(0.6384615384615384),
#     'threshold': np.float64(0.8)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.058333333333333334),
#     'tpr': np.float64(0.6461538461538462),
#     'threshold': np.float64(0.76)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.759),
#                                          1: np.float64(0.24099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.06666666666666667),
#     'tpr': np.float64(0.6692307692307692),
#     'threshold': np.float64(0.75)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.659),
#                                          1: np.float64(0.34099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.08333333333333333),
#     'tpr': np.float64(0.6846153846153846),
#     'threshold': np.float64(0.71)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.849),
#                                          1: np.float64(0.15099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.09166666666666666),
#     'tpr': np.float64(0.6923076923076923),
#     'threshold': np.float64(0.7)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.679),
#                                          1: np.float64(0.32099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.1),
#     'tpr': np.float64(0.7),
#     'threshold': np.float64(0.68)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.649),
#                                          1: np.float64(0.3509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.10833333333333334),
#     'tpr': np.float64(0.7153846153846154),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.31900000000000006),
#                                          1: np.float64(0.6809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.125),
#     'tpr': np.float64(0.7230769230769231),
#     'threshold': np.float64(0.61)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.879),
#                                          1: np.float64(0.12099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.13333333333333333),
#     'tpr': np.float64(0.7307692307692307),
#     'threshold': np.float64(0.61)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.15),
#     'tpr': np.float64(0.7615384615384615),
#     'threshold': np.float64(0.56)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.15833333333333333),
#     'tpr': np.float64(0.7692307692307693),
#     'threshold': np.float64(0.54)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.799),
#                                          1: np.float64(0.20099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.16666666666666666),
#     'tpr': np.float64(0.7769230769230769),
#     'threshold': np.float64(0.55)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3890000000000001),
#                                          1: np.float64(0.6109999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.175),
#     'tpr': np.float64(0.7923076923076923),
#     'threshold': np.float64(0.5)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7390000000000001),
#                                          1: np.float64(0.26099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.8),
#     'threshold': np.float64(0.53)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.799),
#                                          1: np.float64(0.20099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.19166666666666668),
#     'tpr': np.float64(0.8076923076923077),
#     'threshold': np.float64(0.53)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3890000000000001),
#                                          1: np.float64(0.6109999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2),
#     'tpr': np.float64(0.8153846153846154),
#     'threshold': np.float64(0.48)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.899),
#                                          1: np.float64(0.10099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.225),
#     'tpr': np.float64(0.823076923076923),
#     'threshold': np.float64(0.49)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.15900000000000014),
#                                          1: np.float64(0.8409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.23333333333333334),
#     'tpr': np.float64(0.8461538461538461),
#     'threshold': np.float64(0.43)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.859),
#                                          1: np.float64(0.141)},
#                            random_state=42),
#     'fpr': np.float64(0.26666666666666666),
#     'tpr': np.float64(0.8615384615384616),
#     'threshold': np.float64(0.42)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.07900000000000018),
#                                          1: np.float64(0.9209999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.2833333333333333),
#     'tpr': np.float64(0.8692307692307693),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.07900000000000018),
#                                          1: np.float64(0.9209999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.2916666666666667),
#     'tpr': np.float64(0.8769230769230769),
#     'threshold': np.float64(0.39)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.659),
#                                          1: np.float64(0.34099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.3),
#     'tpr': np.float64(0.8846153846153846),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.07900000000000018),
#                                          1: np.float64(0.9209999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.31666666666666665),
#     'tpr': np.float64(0.9076923076923077),
#     'threshold': np.float64(0.35)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.07900000000000018),
#                                          1: np.float64(0.9209999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.3333333333333333),
#     'tpr': np.float64(0.9153846153846154),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5290000000000001),
#                                          1: np.float64(0.4709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.35),
#     'tpr': np.float64(0.9230769230769231),
#     'threshold': np.float64(0.31)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5090000000000001),
#                                          1: np.float64(0.49099999999999994)},
#                            random_state=42),
#     'fpr': np.float64(0.375),
#     'tpr': np.float64(0.9307692307692308),
#     'threshold': np.float64(0.26)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.639),
#                                          1: np.float64(0.36099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.39166666666666666),
#     'tpr': np.float64(0.9461538461538461),
#     'threshold': np.float64(0.24)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.32900000000000007),
#                                          1: np.float64(0.6709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.4),
#     'tpr': np.float64(0.9615384615384616),
#     'threshold': np.float64(0.25)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.07900000000000018),
#                                          1: np.float64(0.9209999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.4083333333333333),
#     'tpr': np.float64(0.9769230769230769),
#     'threshold': np.float64(0.22)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7390000000000001),
#                                          1: np.float64(0.26099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.425),
#     'tpr': np.float64(0.9846153846153847),
#     'threshold': np.float64(0.19)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.549),
#                                          1: np.float64(0.45099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.4583333333333333),
#     'tpr': np.float64(0.9923076923076923),
#     'threshold': np.float64(0.13)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.769),
#                                          1: np.float64(0.23099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.5083333333333333),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.06)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': RandomForestClassifier(class_weight={0: np.float64(0.19900000000000018),
#                                          1: np.float64(0.8009999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.43103448275862066),
#     'threshold': np.float64(0.96)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.0033333333333333335),
#     'tpr': np.float64(0.43666666666666665),
#     'threshold': np.float64(0.91)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.006666666666666667),
#     'tpr': np.float64(0.44333333333333336),
#     'threshold': np.float64(0.89)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.029000000000000137),
#                                          1: np.float64(0.9709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.007462686567164179),
#     'tpr': np.float64(0.4482758620689655),
#     'threshold': np.float64(0.93)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.01),
#     'tpr': np.float64(0.45666666666666667),
#     'threshold': np.float64(0.88)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.013333333333333334),
#     'tpr': np.float64(0.4633333333333333),
#     'threshold': np.float64(0.87)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.869),
#                                          1: np.float64(0.13099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.014925373134328358),
#     'tpr': np.float64(0.46551724137931033),
#     'threshold': np.float64(0.9)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.02),
#     'tpr': np.float64(0.47),
#     'threshold': np.float64(0.85)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.839),
#                                          1: np.float64(0.16099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.022388059701492536),
#     'tpr': np.float64(0.4827586206896552),
#     'threshold': np.float64(0.88)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.839),
#                                          1: np.float64(0.16099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.029850746268656716),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.83)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.03731343283582089),
#     'tpr': np.float64(0.5172413793103449),
#     'threshold': np.float64(0.81)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.999),
#                                          1: np.float64(0.001)},
#                            random_state=42),
#     'fpr': np.float64(0.05223880597014925),
#     'tpr': np.float64(0.5258620689655172),
#     'threshold': np.float64(0.78)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.05970149253731343),
#     'tpr': np.float64(0.5431034482758621),
#     'threshold': np.float64(0.79)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7290000000000001),
#                                          1: np.float64(0.27099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.07462686567164178),
#     'tpr': np.float64(0.5603448275862069),
#     'threshold': np.float64(0.74)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.799),
#                                          1: np.float64(0.20099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.08208955223880597),
#     'tpr': np.float64(0.5689655172413793),
#     'threshold': np.float64(0.72)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7290000000000001),
#                                          1: np.float64(0.27099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.08955223880597014),
#     'tpr': np.float64(0.5948275862068966),
#     'threshold': np.float64(0.71)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7490000000000001),
#                                          1: np.float64(0.25099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.09701492537313433),
#     'tpr': np.float64(0.6206896551724138),
#     'threshold': np.float64(0.68)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.799),
#                                          1: np.float64(0.20099999999999996)},
# ...
#      'thresholds': array([ inf, 1.  , 0.99, 0.98, 0.97, 0.96, 0.95, 0.94, 0.93, 0.89, 0.87,
#             0.84, 0.82, 0.8 , 0.79, 0.77, 0.75, 0.74, 0.72, 0.71, 0.7 , 0.69,
#             0.67, 0.64, 0.63, 0.62, 0.59, 0.54, 0.53, 0.52, 0.51, 0.5 , 0.49,
#             0.48, 0.47, 0.46, 0.45, 0.44, 0.43, 0.42, 0.41, 0.38, 0.36, 0.34,
#             0.33, 0.31, 0.3 , 0.29, 0.28, 0.27, 0.26, 0.25, 0.24, 0.23, 0.22,
#             0.2 , 0.19, 0.15, 0.13, 0.12, 0.11, 0.1 , 0.09, 0.08, 0.07, 0.06,
#             0.04, 0.02, 0.01, 0.  ])}},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0
#          0.47      , 0.47      , 0.47666667, 0.48      , 0.48333333,
#          0.49333333, 0.49333333, 0.50333333, 0.51333333, 0.51666667,
#          0.52333333, 0.52666667, 0.52666667, 0.53      , 0.54333333,
#          0.55      , 0.56      , 0.57      , 0.58666667, 0.59666667,
#          0.62666667, 0.65666667, 0.74666667, 1.        ]),
#   'tpr': array([0.        , 0.23      , 0.3       , 0.32333333, 0.37      ,
#          0.39666667, 0.40666667, 0.42333333, 0.43      , 0.43666667,
#          0.44      , 0.44333333, 0.45666667, 0.46333333, 0.46333333,
#          0.47      , 0.47333333, 0.47666667, 0.48      , 0.48666667,
#          0.49666667, 0.51      , 0.52666667, 0.53      , 0.54666667,
#          0.55      , 0.55      , 0.55333333, 0.57      , 0.58      ,
#          0.59      , 0.6       , 0.60666667, 0.61333333, 0.61666667,
#          0.62333333, 0.63666667, 0.64      , 0.64666667, 0.65666667,
#          0.66333333, 0.67333333, 0.68      , 0.69      , 0.70666667,
#          0.71333333, 0.72      , 0.72333333, 0.73      , 0.74333333,
#          0.76      , 0.76666667, 0.77      , 0.78666667, 0.79333333,
#          0.8       , 0.80333333, 0.81      , 0.82666667, 0.83333333,
#          0.84      , 0.84      , 0.85      , 0.85666667, 0.86      ,
#          0.87      , 0.87333333, 0.88666667, 0.89333333, 0.90666667,
#          0.91666667, 0.92666667, 0.93      , 0.93666667, 0.94      ,
#          0.95      , 0.95333333, 0.96      , 0.96333333, 0.96666667,
#          0.97333333, 0.98      , 0.98666667, 0.99      , 0.99      ,
#          0.99      , 0.99333333, 0.99333333, 0.99666667, 0.99666667,
#          1.        , 1.        , 1.        , 1.        ]),
#   'thresholds': array([ inf, 1.  , 0.99, 0.98, 0.97, 0.95, 0.94, 0.93, 0.92, 0.91, 0.9 ,
#          0.89, 0.88, 0.87, 0.86, 0.85, 0.84, 0.83, 0.82, 0.81, 0.8 , 0.77,
#          0.76, 0.75, 0.74, 0.73, 0.72, 0.71, 0.7 , 0.69, 0.68, 0.67, 0.66,
#          0.65, 0.64, 0.63, 0.62, 0.61, 0.6 , 0.59, 0.58, 0.57, 0.56, 0.55,
#          0.54, 0.53, 0.52, 0.5 , 0.49, 0.48, 0.47, 0.46, 0.45, 0.44, 0.43,
#          0.42, 0.41, 0.4 , 0.39, 0.38, 0.37, 0.36, 0.35, 0.34, 0.33, 0.32,
#          0.31, 0.29, 0.28, 0.27, 0.26, 0.25, 0.24, 0.23, 0.22, 0.2 , 0.19,
#          0.18, 0.17, 0.16, 0.15, 0.14, 0.13, 0.12, 0.1 , 0.08, 0.07, 0.06,
#          0.05, 0.04, 0.03, 0.02, 0.01, 0.  ]),
#   'name': 'RF Regression',
#   'auc': np.float64(0.8513166666666666),
#   'model': RandomForestClassifier(random_state=42)},
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x7d8cbc628dd0>}

# %% [markdown]
# # Load pickle

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Load the data
list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader = load_from_pickle(filename='pickle/RF_data2_weighted.pkl')
# Out:
# Data loaded successfully.

# %% [markdown]
# ### Ensemble prediction using voting

# %%
import numpy as np

# --- Loop through all the FPR values to generate the ensemble ROC curve ---



results_tuple, prior_proba = predict_ensemble_and_evaluate(list_folds_best_models=list_folds_best_models,
    test_loader=test_loader)

ensemble_results_soft = results_tuple['soft_voting']
ensemble_results_hard = results_tuple['hard_voting']
misclassification_risk = results_tuple['misclassification_risk']
# Out:
# Creating a single ensemble from 195 models across all folds.
# Extracting full dataset...
# Getting predictions from all models...
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>

# %% [markdown]
# ## Load NP curve pickle

# %%
from predict_ensemble_and_evaluate import load_from_pickle_constrained_roc

# Load the constrained ROC curve results
constrained_points = load_from_pickle_constrained_roc(filename='pickle/RF_Data2_NP_roc_curve.pkl')
# Out:
# Constrained ROC curve points loaded from pickle/RF_Data2_NP_roc_curve.pkl

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
results_lists.append(constrained_points)
results_lists.append(ensemble_results_hard)
results_lists.append(misclassification_risk)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["MaxROCFold 1", "MaxROCFold 2", "MaxROCFold 3", "MaxROCFold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Neyman_Pearson", "Ensemble_voting_hard", "Misclassification_Risk"],
    results_original_roc=results_original_roc, plot_name="RF_weighted_data2", prior_prob=prior_proba
)
# Out:
# --- Plotting all ROC curves for comparison ---

# %% [markdown]
# ## Bootstrap method

# %%
from sklearn.utils import resample

#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds

list_weighted_clfs = []

# Weight the X_train and y_train for cost-sensitive learning
minority_class_weight = np.arange(0.001, 0.999, 0.01)
majority_class_weight = 1.0 - minority_class_weight

n_iterations = 4
n_size = int(len(train_data[:, -1]) * 0.75)

original_indices = np.arange(len(train_data[:, -1]))

for ii in range(n_iterations):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Iteration {ii + 1}/{n_iterations} ---")
    train_indices = resample(original_indices, replace=True, n_samples=n_size, random_state=ii)
    test_indices = np.setdiff1d(original_indices, train_indices, assume_unique=False)

    X_train_fold = train_data[train_indices][:, :-1]
    y_train_fold = train_data[train_indices][:, -1]
    X_test_fold = train_data[test_indices][:, :-1]
    y_test_fold = train_data[test_indices][:, -1]
    
    for w in minority_class_weight:
        class_weights = {0: 1 - w, 1: w}

        clf_weighted = RandomForestClassifier(class_weight=class_weights, random_state=42)
        clf_weighted.fit(X_train_fold, y_train_fold)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
    best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs.copy())
    list_folds_best_models.append(best_clfs.copy())
# Out:
# --- Starting Iteration 1/4 ---
# --- Starting Iteration 2/4 ---
# --- Starting Iteration 3/4 ---
# --- Starting Iteration 4/4 ---

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Save the data
save_to_pickle(list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader, filename='pickle/RF_data2_weighted_bootstrap.pkl')
# Out:
# Data saved to pickle/RF_data2_weighted_bootstrap.pkl
# {'best_models': [[{'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.4495798319327731),
#     'threshold': np.float64(0.96)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.004424778761061947),
#     'tpr': np.float64(0.4789915966386555),
#     'threshold': np.float64(0.94)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.879),
#                                          1: np.float64(0.12099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.008849557522123894),
#     'tpr': np.float64(0.49159663865546216),
#     'threshold': np.float64(0.94)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.8190000000000001),
#                                          1: np.float64(0.18099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.01327433628318584),
#     'tpr': np.float64(0.4957983193277311),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.959),
#                                          1: np.float64(0.040999999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.017699115044247787),
#     'tpr': np.float64(0.5126050420168067),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.659),
#                                          1: np.float64(0.34099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.02654867256637168),
#     'tpr': np.float64(0.5252100840336135),
#     'threshold': np.float64(0.87)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.030973451327433628),
#     'tpr': np.float64(0.5336134453781513),
#     'threshold': np.float64(0.87)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.035398230088495575),
#     'tpr': np.float64(0.542016806722689),
#     'threshold': np.float64(0.86)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.6990000000000001),
#                                          1: np.float64(0.30099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.03982300884955752),
#     'tpr': np.float64(0.5546218487394958),
#     'threshold': np.float64(0.83)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.559),
#                                          1: np.float64(0.44099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.04424778761061947),
#     'tpr': np.float64(0.5588235294117647),
#     'threshold': np.float64(0.8)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.6990000000000001),
#                                          1: np.float64(0.30099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.048672566371681415),
#     'tpr': np.float64(0.5630252100840336),
#     'threshold': np.float64(0.81)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.05309734513274336),
#     'tpr': np.float64(0.5798319327731093),
#     'threshold': np.float64(0.77)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.06637168141592921),
#     'tpr': np.float64(0.5966386554621849),
#     'threshold': np.float64(0.75)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5290000000000001),
#                                          1: np.float64(0.4709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.07079646017699115),
#     'tpr': np.float64(0.6218487394957983),
#     'threshold': np.float64(0.72)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5290000000000001),
#                                          1: np.float64(0.4709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.08849557522123894),
#     'tpr': np.float64(0.6260504201680672),
#     'threshold': np.float64(0.71)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7390000000000001),
#                                          1: np.float64(0.26099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.09734513274336283),
#     'tpr': np.float64(0.6302521008403361),
#     'threshold': np.float64(0.7)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7390000000000001),
#                                          1: np.float64(0.26099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.10176991150442478),
#     'tpr': np.float64(0.6386554621848739),
#     'threshold': np.float64(0.69)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4690000000000001),
#                                          1: np.float64(0.5309999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.10619469026548672),
#     'tpr': np.float64(0.6428571428571429),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.11061946902654868),
#     'tpr': np.float64(0.6512605042016807),
#     'threshold': np.float64(0.65)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7390000000000001),
#                                          1: np.float64(0.26099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.11504424778761062),
#     'tpr': np.float64(0.6554621848739496),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.21900000000000008),
#                                          1: np.float64(0.7809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.11946902654867257),
#     'tpr': np.float64(0.6764705882352942),
#     'threshold': np.float64(0.64)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.21900000000000008),
#                                          1: np.float64(0.7809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.12389380530973451),
#     'tpr': np.float64(0.6848739495798319),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.13716814159292035),
#     'tpr': np.float64(0.6890756302521008),
#     'threshold': np.float64(0.61)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7090000000000001),
#                                          1: np.float64(0.291)},
#                            random_state=42),
#     'fpr': np.float64(0.14601769911504425),
#     'tpr': np.float64(0.6932773109243697),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.08900000000000019),
#                                          1: np.float64(0.9109999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.1504424778761062),
#     'tpr': np.float64(0.7016806722689075),
#     'threshold': np.float64(0.6)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1592920353982301),
#     'tpr': np.float64(0.7310924369747899),
#     'threshold': np.float64(0.59)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.16371681415929204),
#     'tpr': np.float64(0.7436974789915967),
#     'threshold': np.float64(0.58)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.20900000000000007),
#                                          1: np.float64(0.7909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.18141592920353983),
#     'tpr': np.float64(0.7478991596638656),
#     'threshold': np.float64(0.56)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3490000000000001),
#                                          1: np.float64(0.6509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2079646017699115),
#     'tpr': np.float64(0.7521008403361344),
#     'threshold': np.float64(0.53)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.3490000000000001),
#                                          1: np.float64(0.6509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.21238938053097345),
#     'tpr': np.float64(0.7605042016806722),
#     'threshold': np.float64(0.52)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.559),
#                                          1: np.float64(0.44099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.2168141592920354),
#     'tpr': np.float64(0.773109243697479),
#     'threshold': np.float64(0.53)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.24336283185840707),
#     'tpr': np.float64(0.7773109243697479),
#     'threshold': np.float64(0.5)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.24778761061946902),
#     'tpr': np.float64(0.7815126050420168),
#     'threshold': np.float64(0.48)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.252212389380531),
#     'tpr': np.float64(0.7857142857142857),
#     'threshold': np.float64(0.47)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4990000000000001),
#                                          1: np.float64(0.5009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2610619469026549),
#     'tpr': np.float64(0.7941176470588235),
#     'threshold': np.float64(0.47)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.40900000000000014),
#                                          1: np.float64(0.5909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.26548672566371684),
#     'tpr': np.float64(0.7983193277310925),
#     'threshold': np.float64(0.45)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.40900000000000014),
#                                          1: np.float64(0.5909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2743362831858407),
#     'tpr': np.float64(0.8025210084033614),
#     'threshold': np.float64(0.44)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.889),
#                                          1: np.float64(0.11099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.27876106194690264),
#     'tpr': np.float64(0.8235294117647058),
#     'threshold': np.float64(0.43)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.889),
#                                          1: np.float64(0.11099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.29646017699115046),
#     'tpr': np.float64(0.8319327731092437),
#     'threshold': np.float64(0.42)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.889),
#                                          1: np.float64(0.11099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3008849557522124),
#     'tpr': np.float64(0.8403361344537815),
#     'threshold': np.float64(0.41)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.889),
#                                          1: np.float64(0.11099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3053097345132743),
#     'tpr': np.float64(0.8529411764705882),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.889),
#                                          1: np.float64(0.11099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3141592920353982),
#     'tpr': np.float64(0.8571428571428571),
#     'threshold': np.float64(0.39)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.989),
#                                          1: np.float64(0.011)},
#                            random_state=42),
#     'fpr': np.float64(0.3230088495575221),
#     'tpr': np.float64(0.865546218487395),
#     'threshold': np.float64(0.38)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9490000000000001),
#                                          1: np.float64(0.05099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.33185840707964603),
#     'tpr': np.float64(0.8697478991596639),
#     'threshold': np.float64(0.38)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.336283185840708),
#     'tpr': np.float64(0.8823529411764706),
#     'threshold': np.float64(0.37)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.3407079646017699),
#     'tpr': np.float64(0.8907563025210085),
#     'threshold': np.float64(0.36)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.34513274336283184),
#     'tpr': np.float64(0.8991596638655462),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.35398230088495575),
#     'tpr': np.float64(0.9033613445378151),
#     'threshold': np.float64(0.33)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.549),
#                                          1: np.float64(0.45099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.36283185840707965),
#     'tpr': np.float64(0.907563025210084),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.789),
#                                          1: np.float64(0.21099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.3672566371681416),
#     'tpr': np.float64(0.9117647058823529),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.789),
#                                          1: np.float64(0.21099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.37168141592920356),
#     'tpr': np.float64(0.9159663865546218),
#     'threshold': np.float64(0.29)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.679),
#                                          1: np.float64(0.32099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.37610619469026546),
#     'tpr': np.float64(0.9201680672268907),
#     'threshold': np.float64(0.27)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.8190000000000001),
#                                          1: np.float64(0.18099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.38495575221238937),
#     'tpr': np.float64(0.9327731092436975),
#     'threshold': np.float64(0.28)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5990000000000001),
#                                          1: np.float64(0.4009999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3893805309734513),
#     'tpr': np.float64(0.9369747899159664),
#     'threshold': np.float64(0.25)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7090000000000001),
#                                          1: np.float64(0.291)},
#                            random_state=42),
#     'fpr': np.float64(0.4026548672566372),
#     'tpr': np.float64(0.9411764705882353),
#     'threshold': np.float64(0.23)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.859),
#                                          1: np.float64(0.141)},
#                            random_state=42),
#     'fpr': np.float64(0.415929203539823),
#     'tpr': np.float64(0.9453781512605042),
#     'threshold': np.float64(0.24)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.799),
#                                          1: np.float64(0.20099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.42035398230088494),
#     'tpr': np.float64(0.9537815126050421),
#     'threshold': np.float64(0.24)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7290000000000001),
#                                          1: np.float64(0.27099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.42920353982300885),
#     'tpr': np.float64(0.957983193277311),
#     'threshold': np.float64(0.18)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.629),
#                                          1: np.float64(0.37099999999999994)},
#                            random_state=42),
#     'fpr': np.float64(0.4336283185840708),
#     'tpr': np.float64(0.9621848739495799),
#     'threshold': np.float64(0.2)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.43805309734513276),
#     'tpr': np.float64(0.9663865546218487),
#     'threshold': np.float64(0.19)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.759),
#                                          1: np.float64(0.24099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.4557522123893805),
#     'tpr': np.float64(0.9705882352941176),
#     'threshold': np.float64(0.16)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5890000000000001),
#                                          1: np.float64(0.4109999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.46017699115044247),
#     'tpr': np.float64(0.9747899159663865),
#     'threshold': np.float64(0.12)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.559),
#                                          1: np.float64(0.44099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.4646017699115044),
#     'tpr': np.float64(0.9831932773109243),
#     'threshold': np.float64(0.12)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.559),
#                                          1: np.float64(0.44099999999999995)},
#                            random_state=42),
#     'fpr': np.float64(0.47345132743362833),
#     'tpr': np.float64(0.9873949579831933),
#     'threshold': np.float64(0.11)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.44900000000000007),
#                                          1: np.float64(0.5509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.48672566371681414),
#     'tpr': np.float64(0.9915966386554622),
#     'threshold': np.float64(0.08)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.029000000000000137),
#                                          1: np.float64(0.9709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.5221238938053098),
#     'tpr': np.float64(0.9957983193277311),
#     'threshold': np.float64(0.05)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7290000000000001),
#                                          1: np.float64(0.27099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.5663716814159292),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.05)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': 'original_baseline',
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.42333333333333334),
#     'threshold': np.float64(0.93)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.0033333333333333335),
#     'tpr': np.float64(0.43666666666666665),
#     'threshold': np.float64(0.91)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.006666666666666667),
#     'tpr': np.float64(0.44333333333333336),
#     'threshold': np.float64(0.89)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.01),
#     'tpr': np.float64(0.45666666666666667),
#     'threshold': np.float64(0.88)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.013333333333333334),
#     'tpr': np.float64(0.4633333333333333),
#     'threshold': np.float64(0.87)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.02),
#     'tpr': np.float64(0.47),
#     'threshold': np.float64(0.85)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.02666666666666667),
#     'tpr': np.float64(0.47333333333333333),
#     'threshold': np.float64(0.84)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.03),
#     'tpr': np.float64(0.4766666666666667),
#     'threshold': np.float64(0.83)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.03666666666666667),
#     'tpr': np.float64(0.48),
#     'threshold': np.float64(0.82)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.043333333333333335),
#     'tpr': np.float64(0.4866666666666667),
#     'threshold': np.float64(0.81)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.05333333333333334),
#     'tpr': np.float64(0.49666666666666665),
#     'threshold': np.float64(0.8)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.06666666666666667),
#     'tpr': np.float64(0.51),
#     'threshold': np.float64(0.77)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.07333333333333333),
#     'tpr': np.float64(0.5266666666666666),
#     'threshold': np.float64(0.76)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.08),
#     'tpr': np.float64(0.53),
#     'threshold': np.float64(0.75)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.08666666666666667),
#     'tpr': np.float64(0.5466666666666666),
#     'threshold': np.float64(0.74)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.09),
#     'tpr': np.float64(0.55),
#     'threshold': np.float64(0.73)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.10333333333333333),
#     'tpr': np.float64(0.5533333333333333),
#     'threshold': np.float64(0.71)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.789),
#                                          1: np.float64(0.21099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.10869565217391304),
#     'tpr': np.float64(0.5569620253164557),
#     'threshold': np.float64(0.72)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.789),
#                                          1: np.float64(0.21099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.11304347826086956),
#     'tpr': np.float64(0.5611814345991561),
#     'threshold': np.float64(0.71)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.11333333333333333),
#     'tpr': np.float64(0.57),
#     'threshold': np.float64(0.7)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.12333333333333334),
#     'tpr': np.float64(0.59),
#     'threshold': np.float64(0.68)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.839),
#                                          1: np.float64(0.16099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.12608695652173912),
#     'tpr': np.float64(0.5907172995780591),
#     'threshold': np.float64(0.68)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.839),
#                                          1: np.float64(0.16099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.13043478260869565),
#     'tpr': np.float64(0.5991561181434599),
#     'threshold': np.float64(0.67)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.13666666666666666),
#     'tpr': np.float64(0.6),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.889),
#                                          1: np.float64(0.11099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1391304347826087),
#     'tpr': np.float64(0.6033755274261603),
#     'threshold': np.float64(0.67)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.14),
#     'tpr': np.float64(0.6066666666666667),
#     'threshold': np.float64(0.66)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.14347826086956522),
#     'tpr': np.float64(0.6160337552742616),
#     'threshold': np.float64(0.66)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.969),
#                                          1: np.float64(0.030999999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.14782608695652175),
#     'tpr': np.float64(0.6286919831223629),
#     'threshold': np.float64(0.65)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.15217391304347827),
#     'tpr': np.float64(0.6329113924050633),
#     'threshold': np.float64(0.66)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1565217391304348),
#     'tpr': np.float64(0.6413502109704642),
#     'threshold': np.float64(0.64)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.549),
#                                          1: np.float64(0.45099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.1608695652173913),
#     'tpr': np.float64(0.6455696202531646),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.549),
#                                          1: np.float64(0.45099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.16521739130434782),
#     'tpr': np.float64(0.6540084388185654),
#     'threshold': np.float64(0.61)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.59)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.17391304347826086),
#     'tpr': np.float64(0.6624472573839663),
#     'threshold': np.float64(0.62)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.18),
#     'tpr': np.float64(0.6633333333333333),
#     'threshold': np.float64(0.58)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1826086956521739),
#     'tpr': np.float64(0.6751054852320675),
#     'threshold': np.float64(0.6)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.19130434782608696),
#     'tpr': np.float64(0.6877637130801688),
#     'threshold': np.float64(0.57)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.31900000000000006),
#                                          1: np.float64(0.6809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.1956521739130435),
#     'tpr': np.float64(0.6919831223628692),
#     'threshold': np.float64(0.53)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.879),
#                                          1: np.float64(0.12099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.20434782608695654),
#     'tpr': np.float64(0.7046413502109705),
#     'threshold': np.float64(0.56)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2290000000000001),
#                                          1: np.float64(0.7709999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.20869565217391303),
#     'tpr': np.float64(0.7130801687763713),
#     'threshold': np.float64(0.51)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.15900000000000014),
#                                          1: np.float64(0.8409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.21304347826086956),
#     'tpr': np.float64(0.729957805907173),
#     'threshold': np.float64(0.48)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.15900000000000014),
#                                          1: np.float64(0.8409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.22608695652173913),
#     'tpr': np.float64(0.7426160337552743),
#     'threshold': np.float64(0.47)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.15900000000000014),
#                                          1: np.float64(0.8409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2391304347826087),
#     'tpr': np.float64(0.7679324894514767),
#     'threshold': np.float64(0.45)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.15900000000000014),
#                                          1: np.float64(0.8409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.24782608695652175),
#     'tpr': np.float64(0.7848101265822784),
#     'threshold': np.float64(0.43)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.15900000000000014),
#                                          1: np.float64(0.8409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2565217391304348),
#     'tpr': np.float64(0.7890295358649789),
#     'threshold': np.float64(0.42)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.13900000000000012),
#                                          1: np.float64(0.8609999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2826086956521739),
#     'tpr': np.float64(0.8059071729957806),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.1090000000000001),
#                                          1: np.float64(0.8909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.29130434782608694),
#     'tpr': np.float64(0.810126582278481),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.2956521739130435),
#     'tpr': np.float64(0.8143459915611815),
#     'threshold': np.float64(0.42)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.1090000000000001),
#                                          1: np.float64(0.8909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3),
#     'tpr': np.float64(0.8270042194092827),
#     'threshold': np.float64(0.39)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3130434782608696),
#     'tpr': np.float64(0.8354430379746836),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3217391304347826),
#     'tpr': np.float64(0.8523206751054853),
#     'threshold': np.float64(0.38)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.769),
#                                          1: np.float64(0.23099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.3347826086956522),
#     'tpr': np.float64(0.8607594936708861),
#     'threshold': np.float64(0.35)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.919),
#                                          1: np.float64(0.08099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.34347826086956523),
#     'tpr': np.float64(0.8649789029535865),
#     'threshold': np.float64(0.35)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.979),
#                                          1: np.float64(0.020999999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.34782608695652173),
#     'tpr': np.float64(0.869198312236287),
#     'threshold': np.float64(0.35)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.639),
#                                          1: np.float64(0.36099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.3521739130434783),
#     'tpr': np.float64(0.8734177215189873),
#     'threshold': np.float64(0.32)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.2590000000000001),
#                                          1: np.float64(0.7409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.3565217391304348),
#     'tpr': np.float64(0.8776371308016878),
#     'threshold': np.float64(0.33)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.6890000000000001),
#                                          1: np.float64(0.31099999999999994)},
#                            random_state=42),
#     'fpr': np.float64(0.36086956521739133),
#     'tpr': np.float64(0.8818565400843882),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.769),
#                                          1: np.float64(0.23099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.3695652173913043),
#     'tpr': np.float64(0.8860759493670886),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.859),
#                                          1: np.float64(0.141)},
#                            random_state=42),
#     'fpr': np.float64(0.3782608695652174),
#     'tpr': np.float64(0.8987341772151899),
#     'threshold': np.float64(0.31)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.929),
#                                          1: np.float64(0.071)},
#                            random_state=42),
#     'fpr': np.float64(0.3826086956521739),
#     'tpr': np.float64(0.9029535864978903),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.929),
#                                          1: np.float64(0.071)},
#                            random_state=42),
#     'fpr': np.float64(0.3869565217391304),
#     'tpr': np.float64(0.9071729957805907),
#     'threshold': np.float64(0.29)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.929),
#                                          1: np.float64(0.071)},
#                            random_state=42),
#     'fpr': np.float64(0.391304347826087),
#     'tpr': np.float64(0.9156118143459916),
#     'threshold': np.float64(0.28)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.649),
#                                          1: np.float64(0.3509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.4043478260869565),
#     'tpr': np.float64(0.9282700421940928),
#     'threshold': np.float64(0.26)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.649),
#                                          1: np.float64(0.3509999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.40869565217391307),
#     'tpr': np.float64(0.9324894514767933),
#     'threshold': np.float64(0.25)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7190000000000001),
#                                          1: np.float64(0.28099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.41739130434782606),
#     'tpr': np.float64(0.9535864978902954),
#     'threshold': np.float64(0.22)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.779),
#                                          1: np.float64(0.22099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.43043478260869567),
#     'tpr': np.float64(0.9662447257383966),
#     'threshold': np.float64(0.2)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.6890000000000001),
#                                          1: np.float64(0.31099999999999994)},
#                            random_state=42),
#     'fpr': np.float64(0.44782608695652176),
#     'tpr': np.float64(0.9746835443037974),
#     'threshold': np.float64(0.17)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7290000000000001),
#                                          1: np.float64(0.27099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.46956521739130436),
#     'tpr': np.float64(0.9789029535864979),
#     'threshold': np.float64(0.17)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.9390000000000001),
#                                          1: np.float64(0.06099999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.48695652173913045),
#     'tpr': np.float64(0.9831223628691983),
#     'threshold': np.float64(0.15)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5790000000000001),
#                                          1: np.float64(0.42099999999999993)},
#                            random_state=42),
#     'fpr': np.float64(0.5043478260869565),
#     'tpr': np.float64(0.9873417721518988),
#     'threshold': np.float64(0.12)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.53),
#     'tpr': np.float64(0.99),
#     'threshold': np.float64(0.12)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.7190000000000001),
#                                          1: np.float64(0.28099999999999997)},
#                            random_state=42),
#     'fpr': np.float64(0.5391304347826087),
#     'tpr': np.float64(0.9915611814345991),
#     'threshold': np.float64(0.08)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.56),
#     'tpr': np.float64(0.9933333333333333),
#     'threshold': np.float64(0.07)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.5866666666666667),
#     'tpr': np.float64(0.9966666666666667),
#     'threshold': np.float64(0.05)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.6266666666666667),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.03)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': 'original_baseline',
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.42333333333333334),
#     'threshold': np.float64(0.93)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.0033333333333333335),
#     'tpr': np.float64(0.43666666666666665),
#     'threshold': np.float64(0.91)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.006666666666666667),
#     'tpr': np.float64(0.44333333333333336),
#     'threshold': np.float64(0.89)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.31900000000000006),
#                                          1: np.float64(0.6809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.008298755186721992),
#     'tpr': np.float64(0.4888888888888889),
#     'threshold': np.float64(0.92)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.609),
#                                          1: np.float64(0.39099999999999996)},
#                            random_state=42),
#     'fpr': np.float64(0.016597510373443983),
#     'tpr': np.float64(0.49777777777777776),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.999),
#                                          1: np.float64(0.001)},
#                            random_state=42),
#     'fpr': np.float64(0.024896265560165973),
#     'tpr': np.float64(0.5066666666666667),
#     'threshold': np.float64(0.93)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.6890000000000001),
#                                          1: np.float64(0.31099999999999994)},
#                            random_state=42),
#     'fpr': np.float64(0.029045643153526972),
#     'tpr': np.float64(0.5111111111111111),
#     'threshold': np.float64(0.89)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.999),
#                                          1: np.float64(0.001)},
#                            random_state=42),
#     'fpr': np.float64(0.03319502074688797),
#     'tpr': np.float64(0.5244444444444445),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.40900000000000014),
#                                          1: np.float64(0.5909999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.04149377593360996),
#     'tpr': np.float64(0.5377777777777778),
#     'threshold': np.float64(0.85)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.4590000000000001),
#                                          1: np.float64(0.5409999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.04979253112033195),
#     'tpr': np.float64(0.5511111111111111),
#     'threshold': np.float64(0.82)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.29900000000000015),
#                                          1: np.float64(0.7009999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.058091286307053944),
#     'tpr': np.float64(0.56),
#     'threshold': np.float64(0.8)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.989),
#                                          1: np.float64(0.011)},
#                            random_state=42),
#     'fpr': np.float64(0.06224066390041494),
#     'tpr': np.float64(0.5644444444444444),
#     'threshold': np.float64(0.82)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.989),
#                                          1: np.float64(0.011)},
#                            random_state=42),
#     'fpr': np.float64(0.06639004149377593),
#     'tpr': np.float64(0.5733333333333334),
#     'threshold': np.float64(0.81)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.899),
#                                          1: np.float64(0.10099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.07053941908713693),
#     'tpr': np.float64(0.5911111111111111),
#     'threshold': np.float64(0.76)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.07883817427385892),
#     'tpr': np.float64(0.6),
#     'threshold': np.float64(0.74)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.879),
#                                          1: np.float64(0.12099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.08298755186721991),
#     'tpr': np.float64(0.6044444444444445),
#     'threshold': np.float64(0.75)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.08713692946058091),
#     'tpr': np.float64(0.6088888888888889),
#     'threshold': np.float64(0.72)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.899),
#                                          1: np.float64(0.10099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0.0912863070539419),
#     'tpr': np.float64(0.6133333333333333),
#     'threshold': np.float64(0.72)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.5190000000000001),
#                                          1: np.float64(0.4809999999999999)},
#                            random_state=42),
#     'fpr': np.float64(0.0954356846473029),
#     'tpr': np.float64(0.6311111111111111),
#     'threshold': np.float64(0.7)},
#    {'model': RandomForestClassifier(class_weight={0: np.float64(0.869),
#                                          1: np.float64(0.13099999999999998)},
#                            random_state=42),
#     'fpr': np.float64(0
thresholds': array([ inf, 1.  , 0.99, 0.98, 0.97, 0.95, 0.94, 0.93, 0.92, 0.91, 0.9 ,
#          0.89, 0.88, 0.87, 0.86, 0.85, 0.84, 0.83, 0.82, 0.81, 0.8 , 0.77,
#          0.76, 0.75, 0.74, 0.73, 0.72, 0.71, 0.7 , 0.69, 0.68, 0.67, 0.66,
#          0.65, 0.64, 0.63, 0.62, 0.61, 0.6 , 0.59, 0.58, 0.57, 0.56, 0.55,
#          0.54, 0.53, 0.52, 0.5 , 0.49, 0.48, 0.47, 0.46, 0.45, 0.44, 0.43,
#          0.42, 0.41, 0.4 , 0.39, 0.38, 0.37, 0.36, 0.35, 0.34, 0.33, 0.32,
#          0.31, 0.29, 0.28, 0.27, 0.26, 0.25, 0.24, 0.23, 0.22, 0.2 , 0.19,
#          0.18, 0.17, 0.16, 0.15, 0.14, 0.13, 0.12, 0.1 , 0.08, 0.07, 0.06,
#          0.05, 0.04, 0.03, 0.02, 0.01, 0.  ]),
#   'name': 'RF Regression',
#   'auc': np.float64(0.8513166666666666),
#   'model': RandomForestClassifier(random_state=42)},
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x7d8ca7bb4bf0>}

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Load the data
list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader = load_from_pickle(filename='pickle/RF_data2_weighted_bootstrap.pkl')
# Out:
# Data loaded successfully.

# %%
import numpy as np

# --- Loop through all the FPR values to generate the ensemble ROC curve ---



results_tuple, prior_proba = predict_ensemble_and_evaluate(list_folds_best_models=list_folds_best_models,
    test_loader=test_loader)

ensemble_results_soft = results_tuple['soft_voting']
ensemble_results_hard = results_tuple['hard_voting']
misclassification_risk = results_tuple['misclassification_risk']
# Out:
# Creating a single ensemble from 293 models across all folds.
# Extracting full dataset...
# Getting predictions from all models...
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
results_lists.append(constrained_points)
results_lists.append(ensemble_results_hard)
results_lists.append(misclassification_risk)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["MaxROCFold 1", "MaxROCFold 2", "MaxROCFold 3", "MaxROCFold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Neyman_Pearson", "Ensemble_voting_hard", "Misclassification_Risk"],
    results_original_roc=results_original_roc, plot_name="RF_weighted_data2_bootstrap", prior_prob=prior_proba
)
# Out:
# --- Plotting all ROC curves for comparison ---
