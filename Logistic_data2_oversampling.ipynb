# %% [markdown]
# ### Imports

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        y_prob = clf_model.predict_proba(X_test)[:, 1]
        y_pred = (y_prob >= threshold).astype(int)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data2")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Oversampling

# %%
import numpy as np
from collections import Counter
# --- Configuration ---
EPSILON = 1e-9
# EXPECTED_MODES_PER_CLASS, etc. removed
# FIXED_TARGET_STD_SYNTHETIC removed

# --- Parameter for KDE-like generator ---
SIGMA_KDE_PERTURBATION = 0.1 # Adjust as needed

# --- This block generates the list of ratios for your experiment ---
def generate_ratios(train_data):
    # 1. Get original class counts from your train_dataset

    # --- Initial Data Analysis ---
    counter = Counter(train_data[:, -1])  # Assuming the last column is the class label
    Class0_initial = counter.get(0, 0)
    Class1_initial = counter.get(1, 0)


    class_ratio_low = 0.1   
    class_ratio_high = 100.0 
    num_points_below = 50 
    num_points_above = 50 

    if Class1_initial == 0 and Class0_initial == 0:
        print("ERROR: Both classes have zero samples initially. Cannot proceed.")
        alpha_target_actual_values = [] 
        current_class_ratio = 1.0
    elif Class1_initial == 0:
        current_class_ratio = np.inf 
    else:
        current_class_ratio = Class0_initial / Class1_initial

    # ... (alpha_target_actual_values generation - same robust version) ...
    alpha_target_list = []
    if Class0_initial > 0 or Class1_initial > 0: 
        if current_class_ratio > 0 and not np.isinf(current_class_ratio): 
            alpha_target_list.append(current_class_ratio)
        _safe_class_ratio_low = max(class_ratio_low, EPSILON)
        if current_class_ratio > _safe_class_ratio_low and not np.isinf(current_class_ratio): 
            try:
                alpha_b = np.geomspace(_safe_class_ratio_low, current_class_ratio, num_points_below, endpoint=False)
                alpha_target_list.extend(alpha_b)
            except ValueError: pass
        if current_class_ratio < class_ratio_high and current_class_ratio >= 0 and not np.isinf(current_class_ratio): 
            try:
                _start_geom_above = max(current_class_ratio, _safe_class_ratio_low) 
                if class_ratio_high > _start_geom_above:
                    alpha_a = np.geomspace(_start_geom_above, class_ratio_high, num_points_above, endpoint=True)
                    if not np.isclose(_start_geom_above, current_class_ratio) and current_class_ratio >=_safe_class_ratio_low and current_class_ratio <= class_ratio_high :
                        alpha_target_list.append(current_class_ratio)
                    alpha_target_list.extend(alpha_a)
                elif np.isclose(class_ratio_high, _start_geom_above):
                    alpha_target_list.append(class_ratio_high)
            except ValueError: pass
        if not alpha_target_list and (Class0_initial > 0 or Class1_initial > 0): 
            if not np.isinf(current_class_ratio) and current_class_ratio > 0:
                alpha_target_list.append(current_class_ratio)
            else: 
                alpha_target_list.extend(np.geomspace(_safe_class_ratio_low, class_ratio_high, num_points_below + num_points_above))
        alpha_target_actual_values = np.unique(alpha_target_list)
        alpha_target_actual_values = np.sort(alpha_target_actual_values[alpha_target_actual_values >= 0]) 
        alpha_target_actual_values = alpha_target_actual_values[alpha_target_actual_values >= _safe_class_ratio_low] 
        alpha_target_actual_values = alpha_target_actual_values[alpha_target_actual_values <= class_ratio_high]
        if not alpha_target_actual_values.size and (Class0_initial > 0 or Class1_initial > 0) : 
            if not np.isinf(current_class_ratio) and current_class_ratio > _safe_class_ratio_low and current_class_ratio < class_ratio_high:
                alpha_target_actual_values = np.array([current_class_ratio])
            else: 
                alpha_target_actual_values = np.array([(_safe_class_ratio_low + class_ratio_high)/2.0])


    print(f"INFO: Initial C0={Class0_initial}, C1={Class1_initial}, Ratio(0/1): {current_class_ratio if Class1_initial > 0 else 'N/A'}")
    print(f"INFO: Target ratios (w values): {alpha_target_actual_values}")
    print(f"INFO: KDE-like perturbation sigma: {SIGMA_KDE_PERTURBATION}")
    print(f"INFO: Standard deviation of synthetic samples will NOT be modified after generation.")

    return alpha_target_actual_values, Class0_initial, Class1_initial

# %%
import numpy as np
from collections import Counter


def oversample_dataset_KDE(Class0_initial, Class1_initial, alpha_target, train_data):
    """
    Oversamples a dataset to a target ratio using a KDE-like method.
    This version contains fixes for shape errors when no samples are generated.
    """
    # --- Determine Oversampling Strategy ---
    oversampled_class_label_by_strategy = -1
    initial_count_of_oversampled_class = -1
    final_count_of_oversampled_class = -1

    if Class1_initial == 0 and Class0_initial > 0:
        current_class_ratio = np.inf
    elif Class1_initial == 0 and Class0_initial == 0:
        current_class_ratio = 1.0 # Or some other neutral value
    else:
        current_class_ratio = Class0_initial / Class1_initial

    # Decide which class to oversample or if we should do nothing
    if abs(alpha_target - current_class_ratio) < EPSILON:
        # Ratios are the same, do nothing
        initial_count_of_oversampled_class = Class1_initial # Placeholder
        final_count_of_oversampled_class = Class1_initial   # Placeholder
    elif alpha_target > current_class_ratio:
        # Target has more C0 relative to C1 -> Oversample C0
        oversampled_class_label_by_strategy = 0
        initial_count_of_oversampled_class = Class0_initial
        final_count_of_oversampled_class = int(round(Class1_initial * alpha_target))
    else: # alpha_target < current_class_ratio
        # Target has more C1 relative to C0 -> Oversample C1
        oversampled_class_label_by_strategy = 1
        initial_count_of_oversampled_class = Class1_initial
        final_count_of_oversampled_class = int(round(Class0_initial / alpha_target))

    num_synthetic_to_generate = max(0, final_count_of_oversampled_class - initial_count_of_oversampled_class)
    print(f"  INFO: Strategy: Oversample class {oversampled_class_label_by_strategy} from {initial_count_of_oversampled_class} to {final_count_of_oversampled_class} (generating {num_synthetic_to_generate} samples).")


    # --- KDE-like Synthetic Sample Generation ---
    if num_synthetic_to_generate > 0:
        print(f"  INFO: Using KDE-like generator. Perturbation sigma: {SIGMA_KDE_PERTURBATION}")
        X_new_synthetic = []
        y_new_synthetic = []

        indices_class = np.where(train_data[:, -1] == oversampled_class_label_by_strategy)[0]
        
        if len(indices_class) > 0:
            for _ in range(num_synthetic_to_generate):
                idx_star = np.random.choice(indices_class)
                X_star = train_data[idx_star, :-1]
                epsilon_noise = np.random.randn(*X_star.shape)
                X_prime = X_star + SIGMA_KDE_PERTURBATION * epsilon_noise
                X_new_synthetic.append(X_prime)
                y_new_synthetic.append(oversampled_class_label_by_strategy)

            X_new_synthetic_arr = np.array(X_new_synthetic)
            y_new_synthetic_arr = np.array(y_new_synthetic)
            X_resampled = np.vstack((train_data[:, :-1], X_new_synthetic_arr))
            y_resampled = np.concatenate((train_data[:, -1], y_new_synthetic_arr))
            resampled_counts = Counter(y_resampled)
            print(f"  INFO: KDE-like generation complete. New C0={resampled_counts.get(0,0)}, C1={resampled_counts.get(1,0)}")
        else:
             # This can happen if the class to oversample has 0 members
            print("  WARNING: Cannot generate samples for a class with 0 members. Returning original data.")
            X_resampled = train_data[:, :-1]
            y_resampled = train_data[:, -1]

    else: # num_synthetic_to_generate is 0
        print("  INFO: No synthetic samples were required or generated.")
        # --- THIS IS THE CRITICAL FIX ---
        # Correctly slice the original data instead of copying the whole array
        X_resampled = train_data[:, :-1]
        y_resampled = train_data[:, -1]
        # ----------------------------

    return X_resampled, y_resampled

# %% [markdown]
# ### Regular training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = LogisticRegression(fit_intercept=True)
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "Logistic Regression", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Oversampling ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds

list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    alpha_target_actual_values, Class0_initial, Class1_initial  = generate_ratios(np.c_[X_train_fold, y_train_fold])  # Combine features and labels for ratio generation
    for w_idx, w in enumerate(alpha_target_actual_values):
        print(f"\n--- Processing target ratio w ({w_idx+1}/{len(alpha_target_actual_values)}): {w:.4f} ---")
        X_train_resampled, y_train_resampled = oversample_dataset_KDE(Class0_initial, Class1_initial, w, np.c_[X_train_fold, y_train_fold])

        clf_weighted = LogisticRegression(fit_intercept=True)
        clf_weighted.fit(X_train_resampled, y_train_resampled)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# INFO: Initial C0=372, C1=378, Ratio(0/1): 0.9841269841269841
# INFO: Target ratios (w values): [  0.1          0.10467935   0.10957767   0.11470519   0.12007265
#    0.12569127   0.13157281   0.13772956   0.14417441   0.15092084
#    0.15798295   0.16537553   0.17311403   0.18121465   0.18969432
#    0.19857078   0.2078626    0.21758923   0.22777099   0.2384292
#    0.24958614   0.26126515   0.27349066   0.28628825   0.29968468
#    0.31370798   0.32838748   0.34375389   0.35983934   0.37667748
#    0.39430355   0.4127544    0.43206862   0.45228663   0.47345071
#    0.49560514   0.51879624   0.54307254   0.56848481   0.59508621
#    0.62293239   0.65208158   0.68259477   0.71453578   0.74797142
#    0.78297163   0.81960962   0.85796204   0.8981091    0.94013477
#    0.98412698   1.08145706   1.18841307   1.30594702   1.43510507
#    1.57703684   1.73300566   1.90439977   2.09274474   2.29971702
#    2.52715884   2.77709464   3.05174906   3.35356679   3.68523426
#    4.04970362   4.45021896   4.89034524   5.37399997   5.90548812
#    6.48954039   7.13135539   7.83664584   8.61168945   9.46338481
#   10.39931276  11.42780392  12.55801276  13.79999916  15.16481791
#   16.66461712  18.31274635  20.12387542  22.114125    24.30121009
#   26.70459771  29.34568017  32.24796546  35.43728652  38.94203117
#   42.79339476  47.02565788  51.67649148  56.78729212  62.40355051
#   68.57525639  75.35734345  82.81017835  91.000098   100.        ]
# INFO: KDE-like perturbation sigma: 0.1
# INFO: Standard deviation of synthetic samples will NOT be modified after generation.
#
# --- Processing target ratio w (1/100): 0.1000 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3720 (generating 3342 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3720
#
# --- Processing target ratio w (2/100): 0.1047 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3554 (generating 3176 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3554
#
# --- Processing target ratio w (3/100): 0.1096 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3395 (generating 3017 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3395
#
# --- Processing target ratio w (4/100): 0.1147 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3243 (generating 2865 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3243
#
# --- Processing target ratio w (5/100): 0.1201 ---
#   INFO: Strategy: Oversample class 1 from 378 to 3098 (generating 2720 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=3098
#
# --- Processing target ratio w (6/100): 0.1257 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2960 (generating 2582 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2960
#
# --- Processing target ratio w (7/100): 0.1316 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2827 (generating 2449 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2827
#
# --- Processing target ratio w (8/100): 0.1377 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2701 (generating 2323 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2701
#
# --- Processing target ratio w (9/100): 0.1442 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2580 (generating 2202 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2580
#
# --- Processing target ratio w (10/100): 0.1509 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2465 (generating 2087 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2465
#
# --- Processing target ratio w (11/100): 0.1580 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2355 (generating 1977 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2355
#
# --- Processing target ratio w (12/100): 0.1654 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2249 (generating 1871 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2249
#
# --- Processing target ratio w (13/100): 0.1731 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2149 (generating 1771 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2149
#
# --- Processing target ratio w (14/100): 0.1812 ---
#   INFO: Strategy: Oversample class 1 from 378 to 2053 (generating 1675 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=2053
#
# --- Processing target ratio w (15/100): 0.1897 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1961 (generating 1583 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1961
#
# --- Processing target ratio w (16/100): 0.1986 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1873 (generating 1495 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1873
#
# --- Processing target ratio w (17/100): 0.2079 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1790 (generating 1412 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1790
#
# --- Processing target ratio w (18/100): 0.2176 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1710 (generating 1332 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1710
#
# --- Processing target ratio w (19/100): 0.2278 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1633 (generating 1255 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1633
#
# --- Processing target ratio w (20/100): 0.2384 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1560 (generating 1182 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1560
#
# --- Processing target ratio w (21/100): 0.2496 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1490 (generating 1112 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1490
#
# --- Processing target ratio w (22/100): 0.2613 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1424 (generating 1046 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1424
#
# --- Processing target ratio w (23/100): 0.2735 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1360 (generating 982 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1360
#
# --- Processing target ratio w (24/100): 0.2863 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1299 (generating 921 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1299
#
# --- Processing target ratio w (25/100): 0.2997 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1241 (generating 863 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1241
#
# --- Processing target ratio w (26/100): 0.3137 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1186 (generating 808 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1186
#
# --- Processing target ratio w (27/100): 0.3284 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1133 (generating 755 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1133
#
# --- Processing target ratio w (28/100): 0.3438 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1082 (generating 704 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1082
#
# --- Processing target ratio w (29/100): 0.3598 ---
#   INFO: Strategy: Oversample class 1 from 378 to 1034 (generating 656 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=1034
#
# --- Processing target ratio w (30/100): 0.3767 ---
#   INFO: Strategy: Oversample class 1 from 378 to 988 (generating 610 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=988
#
# --- Processing target ratio w (31/100): 0.3943 ---
#   INFO: Strategy: Oversample class 1 from 378 to 943 (generating 565 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=943
#
# --- Processing target ratio w (32/100): 0.4128 ---
#   INFO: Strategy: Oversample class 1 from 378 to 901 (generating 523 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=901
#
# --- Processing target ratio w (33/100): 0.4321 ---
#   INFO: Strategy: Oversample class 1 from 378 to 861 (generating 483 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=861
#
# --- Processing target ratio w (34/100): 0.4523 ---
#   INFO: Strategy: Oversample class 1 from 378 to 822 (generating 444 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=822
#
# --- Processing target ratio w (35/100): 0.4735 ---
#   INFO: Strategy: Oversample class 1 from 378 to 786 (generating 408 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=786
#
# --- Processing target ratio w (36/100): 0.4956 ---
#   INFO: Strategy: Oversample class 1 from 378 to 751 (generating 373 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=751
#
# --- Processing target ratio w (37/100): 0.5188 ---
#   INFO: Strategy: Oversample class 1 from 378 to 717 (generating 339 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=717
#
# --- Processing target ratio w (38/100): 0.5431 ---
#   INFO: Strategy: Oversample class 1 from 378 to 685 (generating 307 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=685
#
# --- Processing target ratio w (39/100): 0.5685 ---
#   INFO: Strategy: Oversample class 1 from 378 to 654 (generating 276 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=654
#
# --- Processing target ratio w (40/100): 0.5951 ---
#   INFO: Strategy: Oversample class 1 from 378 to 625 (generating 247 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=625
#
# --- Processing target ratio w (41/100): 0.6229 ---
#   INFO: Strategy: Oversample class 1 from 378 to 597 (generating 219 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=597
#
# --- Processing target ratio w (42/100): 0.6521 ---
#   INFO: Strategy: Oversample class 1 from 378 to 570 (generating 192 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=570
#
# --- Processing target ratio w (43/100): 0.6826 ---
#   INFO: Strategy: Oversample class 1 from 378 to 545 (generating 167 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=545
#
# --- Processing target ratio w (44/100): 0.7145 ---
#   INFO: Strategy: Oversample class 1 from 378 to 521 (generating 143 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=521
#
# --- Processing target ratio w (45/100): 0.7480 ---
#   INFO: Strategy: Oversample class 1 from 378 to 497 (generating 119 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=497
#
# --- Processing target ratio w (46/100): 0.7830 ---
#   INFO: Strategy: Oversample class 1 from 378 to 475 (generating 97 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=475
#
# --- Processing target ratio w (47/100): 0.8196 ---
#   INFO: Strategy: Oversample class 1 from 378 to 454 (generating 76 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=454
#
# --- Processing target ratio w (48/100): 0.8580 ---
#   INFO: Strategy: Oversample class 1 from 378 to 434 (generating 56 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=434
#
# --- Processing target ratio w (49/100): 0.8981 ---
#   INFO: Strategy: Oversample class 1 from 378 to 414 (generating 36 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=414
#
# --- Processing target ratio w (50/100): 0.9401 ---
#   INFO: Strategy: Oversample class 1 from 378 to 396 (generating 18 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=372, C1=396
#
# --- Processing target ratio w (51/100): 0.9841 ---
#   INFO: Strategy: Oversample class -1 from 378 to 378 (generating 0 samples).
#   INFO: No synthetic samples were required or generated.
#
# --- Processing target ratio w (52/100): 1.0815 ---
#   INFO: Strategy: Oversample class 0 from 372 to 409 (generating 37 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=409, C1=378
#
# --- Processing target ratio w (53/100): 1.1884 ---
#   INFO: Strategy: Oversample class 0 from 372 to 449 (generating 77 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=449, C1=378
#
# --- Processing target ratio w (54/100): 1.3059 ---
#   INFO: Strategy: Oversample class 0 from 372 to 494 (generating 122 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=494, C1=378
#
# --- Processing target ratio w (55/100): 1.4351 ---
#   INFO: Strategy: Oversample class 0 from 372 to 542 (generating 170 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=542, C1=378
#
# --- Processing target ratio w (56/100): 1.5770 ---
#   INFO: Strategy: Oversample class 0 from 372 to 596 (generating 224 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=596, C1=378
#
# --- Processing target ratio w (57/100): 1.7330 ---
#   INFO: Strategy: Oversample class 0 from 372 to 655 (generating 283 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=655, C1=378
#
# --- Processing target ratio w (58/100): 1.9044 ---
#   INFO: Strategy: Oversample class 0 from 372 to 720 (generating 348 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=720, C1=378
#
# --- Processing target ratio w (59/100): 2.0927 ---
#   INFO: Strategy: Oversample class 0 from 372 to 791 (generating 419 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=791, C1=378
#
# --- Processing target ratio w (60/100): 2.2997 ---
#   INFO: Strategy: Oversample class 0 from 372 to 869 (generating 497 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=869, C1=378
#
# --- Processing target ratio w (61/100): 2.5272 ---
#   INFO: Strategy: Oversample class 0 from 372 to 955 (generating 583 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=955, C1=378
#
# --- Processing target ratio w (62/100): 2.7771 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1050 (generating 678 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1050, C1=378
#
# --- Processing target ratio w (63/100): 3.0517 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1154 (generating 782 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1154, C1=378
#
# --- Processing target ratio w (64/100): 3.3536 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1268 (generating 896 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1268, C1=378
#
# --- Processing target ratio w (65/100): 3.6852 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1393 (generating 1021 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1393, C1=378
#
# --- Processing target ratio w (66/100): 4.0497 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1531 (generating 1159 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1531, C1=378
#
# --- Processing target ratio w (67/100): 4.4502 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1682 (generating 1310 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1682, C1=378
#
# --- Processing target ratio w (68/100): 4.8903 ---
#   INFO: Strategy: Oversample class 0 from 372 to 1849 (generating 1477 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1849, C1=378
#
# --- Processing target ratio w (69/100): 5.3740 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2031 (generating 1659 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2031, C1=378
#
# --- Processing target ratio w (70/100): 5.9055 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2232 (generating 1860 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2232, C1=378
#
# --- Processing target ratio w (71/100): 6.4895 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2453 (generating 2081 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2453, C1=378
#
# --- Processing target ratio w (72/100): 7.1314 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2696 (generating 2324 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2696, C1=378
#
# --- Processing target ratio w (73/100): 7.8366 ---
#   INFO: Strategy: Oversample class 0 from 372 to 2962 (generating 2590 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2962, C1=378
#
# --- Processing target ratio w (74/100): 8.6117 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3255 (generating 2883 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3255, C1=378
#
# --- Processing target ratio w (75/100): 9.4634 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3577 (generating 3205 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3577, C1=378
#
# --- Processing target ratio w (76/100): 10.3993 ---
#   INFO: Strategy: Oversample class 0 from 372 to 3931 (generating 3559 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3931, C1=378
#
# --- Processing target ratio w (77/100): 11.4278 ---
#   INFO: Strategy: Oversample class 0 from 372 to 4320 (generating 3948 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4320, C1=378
#
# --- Processing target ratio w (78/100): 12.5580 ---
#   INFO: Strategy: Oversample class 0 from 372 to 4747 (generating 4375 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4747, C1=378
#
# --- Processing target ratio w (79/100): 13.8000 ---
#   INFO: Strategy: Oversample class 0 from 372 to 5216 (generating 4844 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5216, C1=378
#
# --- Processing target ratio w (80/100): 15.1648 ---
#   INFO: Strategy: Oversample class 0 from 372 to 5732 (generating 5360 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5732, C1=378
#
# --- Processing target ratio w (81/100): 16.6646 ---
#   INFO: Strategy: Oversample class 0 from 372 to 6299 (generating 5927 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6299, C1=378
#
# --- Processing target ratio w (82/100): 18.3127 ---
#   INFO: Strategy: Oversample class 0 from 372 to 6922 (generating 6550 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6922, C1=378
#
# --- Processing target ratio w (83/100): 20.1239 ---
#   INFO: Strategy: Oversample class 0 from 372 to 7607 (generating 7235 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7607, C1=378
#
# --- Processing target ratio w (84/100): 22.1141 ---
#   INFO: Strategy: Oversample class 0 from 372 to 8359 (generating 7987 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8359, C1=378
#
# --- Processing target ratio w (85/100): 24.3012 ---
#   INFO: Strategy: Oversample class 0 from 372 to 9186 (generating 8814 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=9186, C1=378
#
# --- Processing target ratio w (86/100): 26.7046 ---
#   INFO: Strategy: Oversample class 0 from 372 to 10094 (generating 9722 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=10094, C1=378
#
# --- Processing target ratio w (87/100): 29.3457 ---
#   INFO: Strategy: Oversample class 0 from 372 to 11093 (generating 10721 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=11093, C1=378
#
# --- Processing target ratio w (88/100): 32.2480 ---
#   INFO: Strategy: Oversample class 0 from 372 to 12190 (generating 11818 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=12190, C1=378
#
# --- Processing target ratio w (89/100): 35.4373 ---
#   INFO: Strategy: Oversample class 0 from 372 to 13395 (generating 13023 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=13395, C1=378
#
# --- Processing target ratio w (90/100): 38.9420 ---
#   INFO: Strategy: Oversample class 0 from 372 to 14720 (generating 14348 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=14720, C1=378
#
# --- Processing target ratio w (91/100): 42.7934 ---
#   INFO: Strategy: Oversample class 0 from 372 to 16176 (generating 15804 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=16176, C1=378
#
# --- Processing target ratio w (92/100): 47.0257 ---
#   INFO: Strategy: Oversample class 0 from 372 to 17776 (generating 17404 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=17776, C1=378
#
# --- Processing target ratio w (93/100): 51.6765 ---
#   INFO: Strategy: Oversample class 0 from 372 to 19534 (generating 19162 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=19534, C1=378
#
# --- Processing target ratio w (94/100): 56.7873 ---
#   INFO: Strategy: Oversample class 0 from 372 to 21466 (generating 21094 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=21466, C1=378
#
# --- Processing target ratio w (95/100): 62.4036 ---
#   INFO: Strategy: Oversample class 0 from 372 to 23589 (generating 23217 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=23589, C1=378
#
# --- Processing target ratio w (96/100): 68.5753 ---
#   INFO: Strategy: Oversample class 0 from 372 to 25921 (generating 25549 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=25921, C1=378
#
# --- Processing target ratio w (97/100): 75.3573 ---
#   INFO: Strategy: Oversample class 0 from 372 to 28485 (generating 28113 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=28485, C1=378
#
# --- Processing target ratio w (98/100): 82.8102 ---
#   INFO: Strategy: Oversample class 0 from 372 to 31302 (generating 30930 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=31302, C1=378
#
# --- Processing target ratio w (99/100): 91.0001 ---
#   INFO: Strategy: Oversample class 0 from 372 to 34398 (generating 34026 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=34398, C1=378
#
# --- Processing target ratio w (100/100): 100.0000 ---
#   INFO: Strategy: Oversample class 0 from 372 to 37800 (generating 37428 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=37800, C1=378
# --- Starting Fold 2/4 ---
# INFO: Initial C0=382, C1=368, Ratio(0/1): 1.0380434782608696
# INFO: Target ratios (w values): [  0.1          0.10479108   0.1098117    0.11507287   0.1205861
#    0.12636347   0.13241765   0.13876188   0.14541007   0.15237678
#    0.15967727   0.16732754   0.17534433   0.18374522   0.19254859
#    0.20177375   0.21144089   0.22157119   0.23218684   0.24331109
#    0.25496832   0.26718405   0.27998505   0.29339935   0.30745635
#    0.32218682   0.33762305   0.35379883   0.37074961   0.38851252
#    0.40712646   0.42663221   0.44707249   0.46849209   0.49093791
#    0.51445913   0.53910727   0.56493633   0.59200287   0.6203662
#    0.65008843   0.68123468   0.71387317   0.74807539   0.78391627
#    0.82147432   0.8608318    0.90207493   0.94529405   0.99058383
#    1.03804348   1.13946487   1.25079558   1.37300379   1.50715227
#    1.65440765   1.81605052   1.99348661   2.18825899   2.40206147
#    2.6367534    2.89437576   3.17716894   3.48759227   3.82834531
#    4.20239141   4.61298346   5.06369214   5.55843705   6.10152069
#    6.69766599   7.35205729   8.07038549   8.85889749   9.72445058
#   10.67457199  11.71752443  12.86237789  14.11908854  15.49858534
#   17.012865    18.67509643  20.49973515  22.50264905  24.70125643
#   27.11467737  29.7639001   32.67196351  35.86415744  39.3682427
#   43.21469244  47.43695717  52.07175565  57.15939425  62.74411742
#   68.8744925   75.60383208  82.99065761  91.09920834 100.        ]
# INFO: KDE-like perturbation sigma: 0.1
# INFO: Standard deviation of synthetic samples will NOT be modified after generation.
#
# --- Processing target ratio w (1/100): 0.1000 ---
#   INFO: Strategy: Oversample class 1 from 368 to 3820 (generating 3452 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=3820
#
# --- Processing target ratio w (2/100): 0.1048 ---
#   INFO: Strategy: Oversample class 1 from 368 to 3645 (generating 3277 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=3645
#
# --- Processing target ratio w (3/100): 0.1098 ---
#   INFO: Strategy: Oversample class 1 from 368 to 3479 (generating 3111 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=3479
#
# --- Processing target ratio w (4/100): 0.1151 ---
#   INFO: Strategy: Oversample class 1 from 368 to 3320 (generating 2952 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=3320
#
# --- Processing target ratio w (5/100): 0.1206 ---
#   INFO: Strategy: Oversample class 1 from 368 to 3168 (generating 2800 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=3168
#
# --- Processing target ratio w (6/100): 0.1264 ---
#   INFO: Strategy: Oversample class 1 from 368 to 3023 (generating 2655 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=3023
#
# --- Processing target ratio w (7/100): 0.1324 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2885 (generating 2517 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2885
#
# --- Processing target ratio w (8/100): 0.1388 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2753 (generating 2385 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2753
#
# --- Processing target ratio w (9/100): 0.1454 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2627 (generating 2259 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2627
#
# --- Processing target ratio w (10/100): 0.1524 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2507 (generating 2139 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2507
#
# --- Processing target ratio w (11/100): 0.1597 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2392 (generating 2024 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2392
#
# --- Processing target ratio w (12/100): 0.1673 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2283 (generating 1915 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2283
#
# --- Processing target ratio w (13/100): 0.1753 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2179 (generating 1811 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2179
#
# --- Processing target ratio w (14/100): 0.1837 ---
#   INFO: Strategy: Oversample class 1 from 368 to 2079 (generating 1711 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=2079
#
# --- Processing target ratio w (15/100): 0.1925 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1984 (generating 1616 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1984
#
# --- Processing target ratio w (16/100): 0.2018 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1893 (generating 1525 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1893
#
# --- Processing target ratio w (17/100): 0.2114 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1807 (generating 1439 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1807
#
# --- Processing target ratio w (18/100): 0.2216 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1724 (generating 1356 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1724
#
# --- Processing target ratio w (19/100): 0.2322 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1645 (generating 1277 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1645
#
# --- Processing target ratio w (20/100): 0.2433 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1570 (generating 1202 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1570
#
# --- Processing target ratio w (21/100): 0.2550 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1498 (generating 1130 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1498
#
# --- Processing target ratio w (22/100): 0.2672 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1430 (generating 1062 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1430
#
# --- Processing target ratio w (23/100): 0.2800 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1364 (generating 996 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1364
#
# --- Processing target ratio w (24/100): 0.2934 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1302 (generating 934 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1302
#
# --- Processing target ratio w (25/100): 0.3075 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1242 (generating 874 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1242
#
# --- Processing target ratio w (26/100): 0.3222 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1186 (generating 818 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1186
#
# --- Processing target ratio w (27/100): 0.3376 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1131 (generating 763 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1131
#
# --- Processing target ratio w (28/100): 0.3538 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1080 (generating 712 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1080
#
# --- Processing target ratio w (29/100): 0.3707 ---
#   INFO: Strategy: Oversample class 1 from 368 to 1030 (generating 662 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=1030
#
# --- Processing target ratio w (30/100): 0.3885 ---
#   INFO: Strategy: Oversample class 1 from 368 to 983 (generating 615 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=983
#
# --- Processing target ratio w (31/100): 0.4071 ---
#   INFO: Strategy: Oversample class 1 from 368 to 938 (generating 570 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=938
#
# --- Processing target ratio w (32/100): 0.4266 ---
#   INFO: Strategy: Oversample class 1 from 368 to 895 (generating 527 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=895
#
# --- Processing target ratio w (33/100): 0.4471 ---
#   INFO: Strategy: Oversample class 1 from 368 to 854 (generating 486 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=854
#
# --- Processing target ratio w (34/100): 0.4685 ---
#   INFO: Strategy: Oversample class 1 from 368 to 815 (generating 447 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=815
#
# --- Processing target ratio w (35/100): 0.4909 ---
#   INFO: Strategy: Oversample class 1 from 368 to 778 (generating 410 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=778
#
# --- Processing target ratio w (36/100): 0.5145 ---
#   INFO: Strategy: Oversample class 1 from 368 to 743 (generating 375 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=743
#
# --- Processing target ratio w (37/100): 0.5391 ---
#   INFO: Strategy: Oversample class 1 from 368 to 709 (generating 341 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=709
#
# --- Processing target ratio w (38/100): 0.5649 ---
#   INFO: Strategy: Oversample class 1 from 368 to 676 (generating 308 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=676
#
# --- Processing target ratio w (39/100): 0.5920 ---
#   INFO: Strategy: Oversample class 1 from 368 to 645 (generating 277 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=645
#
# --- Processing target ratio w (40/100): 0.6204 ---
#   INFO: Strategy: Oversample class 1 from 368 to 616 (generating 248 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=616
#
# --- Processing target ratio w (41/100): 0.6501 ---
#   INFO: Strategy: Oversample class 1 from 368 to 588 (generating 220 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=588
#
# --- Processing target ratio w (42/100): 0.6812 ---
#   INFO: Strategy: Oversample class 1 from 368 to 561 (generating 193 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=561
#
# --- Processing target ratio w (43/100): 0.7139 ---
#   INFO: Strategy: Oversample class 1 from 368 to 535 (generating 167 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=535
#
# --- Processing target ratio w (44/100): 0.7481 ---
#   INFO: Strategy: Oversample class 1 from 368 to 511 (generating 143 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=511
#
# --- Processing target ratio w (45/100): 0.7839 ---
#   INFO: Strategy: Oversample class 1 from 368 to 487 (generating 119 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=487
#
# --- Processing target ratio w (46/100): 0.8215 ---
#   INFO: Strategy: Oversample class 1 from 368 to 465 (generating 97 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=465
#
# --- Processing target ratio w (47/100): 0.8608 ---
#   INFO: Strategy: Oversample class 1 from 368 to 444 (generating 76 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=444
#
# --- Processing target ratio w (48/100): 0.9021 ---
#   INFO: Strategy: Oversample class 1 from 368 to 423 (generating 55 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=423
#
# --- Processing target ratio w (49/100): 0.9453 ---
#   INFO: Strategy: Oversample class 1 from 368 to 404 (generating 36 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=404
#
# --- Processing target ratio w (50/100): 0.9906 ---
#   INFO: Strategy: Oversample class 1 from 368 to 386 (generating 18 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=382, C1=386
#
# --- Processing target ratio w (51/100): 1.0380 ---
#   INFO: Strategy: Oversample class -1 from 368 to 368 (generating 0 samples).
#   INFO: No synthetic samples were required or generated.
#
# --- Processing target ratio w (52/100): 1.1395 ---
#   INFO: Strategy: Oversample class 0 from 382 to 419 (generating 37 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=419, C1=368
#
# --- Processing target ratio w (53/100): 1.2508 ---
#   INFO: Strategy: Oversample class 0 from 382 to 460 (generating 78 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=460, C1=368
#
# --- Processing target ratio w (54/100): 1.3730 ---
#   INFO: Strategy: Oversample class 0 from 382 to 505 (generating 123 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=505, C1=368
#
# --- Processing target ratio w (55/100): 1.5072 ---
#   INFO: Strategy: Oversample class 0 from 382 to 555 (generating 173 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=555, C1=368
#
# --- Processing target ratio w (56/100): 1.6544 ---
#   INFO: Strategy: Oversample class 0 from 382 to 609 (generating 227 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=609, C1=368
#
# --- Processing target ratio w (57/100): 1.8161 ---
#   INFO: Strategy: Oversample class 0 from 382 to 668 (generating 286 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=668, C1=368
#
# --- Processing target ratio w (58/100): 1.9935 ---
#   INFO: Strategy: Oversample class 0 from 382 to 734 (generating 352 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=734, C1=368
#
# --- Processing target ratio w (59/100): 2.1883 ---
#   INFO: Strategy: Oversample class 0 from 382 to 805 (generating 423 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=805, C1=368
#
# --- Processing target ratio w (60/100): 2.4021 ---
#   INFO: Strategy: Oversample class 0 from 382 to 884 (generating 502 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=884, C1=368
#
# --- Processing target ratio w (61/100): 2.6368 ---
#   INFO: Strategy: Oversample class 0 from 382 to 970 (generating 588 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=970, C1=368
#
# --- Processing target ratio w (62/100): 2.8944 ---
#   INFO: Strategy: Oversample class 0 from 382 to 1065 (generating 683 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1065, C1=368
#
# --- Processing target ratio w (63/100): 3.1772 ---
#   INFO: Strategy: Oversample class 0 from 382 to 1169 (generating 787 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1169, C1=368
#
# --- Processing target ratio w (64/100): 3.4876 ---
#   INFO: Strategy: Oversample class 0 from 382 to 1283 (generating 901 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1283, C1=368
#
# --- Processing target ratio w (65/100): 3.8283 ---
#   INFO: Strategy: Oversample class 0 from 382 to 1409 (generating 1027 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1409, C1=368
#
# --- Processing target ratio w (66/100): 4.2024 ---
#   INFO: Strategy: Oversample class 0 from 382 to 1546 (generating 1164 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1546, C1=368
#
# --- Processing target ratio w (67/100): 4.6130 ---
#   INFO: Strategy: Oversample class 0 from 382 to 1698 (generating 1316 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1698, C1=368
#
# --- Processing target ratio w (68/100): 5.0637 ---
#   INFO: Strategy: Oversample class 0 from 382 to 1863 (generating 1481 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1863, C1=368
#
# --- Processing target ratio w (69/100): 5.5584 ---
#   INFO: Strategy: Oversample class 0 from 382 to 2046 (generating 1664 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2046, C1=368
#
# --- Processing target ratio w (70/100): 6.1015 ---
#   INFO: Strategy: Oversample class 0 from 382 to 2245 (generating 1863 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2245, C1=368
#
# --- Processing target ratio w (71/100): 6.6977 ---
#   INFO: Strategy: Oversample class 0 from 382 to 2465 (generating 2083 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2465, C1=368
#
# --- Processing target ratio w (72/100): 7.3521 ---
#   INFO: Strategy: Oversample class 0 from 382 to 2706 (generating 2324 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2706, C1=368
#
# --- Processing target ratio w (73/100): 8.0704 ---
#   INFO: Strategy: Oversample class 0 from 382 to 2970 (generating 2588 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2970, C1=368
#
# --- Processing target ratio w (74/100): 8.8589 ---
#   INFO: Strategy: Oversample class 0 from 382 to 3260 (generating 2878 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3260, C1=368
#
# --- Processing target ratio w (75/100): 9.7245 ---
#   INFO: Strategy: Oversample class 0 from 382 to 3579 (generating 3197 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3579, C1=368
#
# --- Processing target ratio w (76/100): 10.6746 ---
#   INFO: Strategy: Oversample class 0 from 382 to 3928 (generating 3546 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3928, C1=368
#
# --- Processing target ratio w (77/100): 11.7175 ---
#   INFO: Strategy: Oversample class 0 from 382 to 4312 (generating 3930 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4312, C1=368
#
# --- Processing target ratio w (78/100): 12.8624 ---
#   INFO: Strategy: Oversample class 0 from 382 to 4733 (generating 4351 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4733, C1=368
#
# --- Processing target ratio w (79/100): 14.1191 ---
#   INFO: Strategy: Oversample class 0 from 382 to 5196 (generating 4814 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5196, C1=368
#
# --- Processing target ratio w (80/100): 15.4986 ---
#   INFO: Strategy: Oversample class 0 from 382 to 5703 (generating 5321 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5703, C1=368
#
# --- Processing target ratio w (81/100): 17.0129 ---
#   INFO: Strategy: Oversample class 0 from 382 to 6261 (generating 5879 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6261, C1=368
#
# --- Processing target ratio w (82/100): 18.6751 ---
# ...
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=755
#
# --- Processing target ratio w (37/100): 0.5070 ---
#   INFO: Strategy: Oversample class 1 from 384 to 722 (generating 338 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=722
#
# --- Processing target ratio w (38/100): 0.5304 ---
#   INFO: Strategy: Oversample class 1 from 384 to 690 (generating 306 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=690
#
# --- Processing target ratio w (39/100): 0.5548 ---
#   INFO: Strategy: Oversample class 1 from 384 to 660 (generating 276 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=660
#
# --- Processing target ratio w (40/100): 0.5804 ---
#   INFO: Strategy: Oversample class 1 from 384 to 631 (generating 247 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=631
#
# --- Processing target ratio w (41/100): 0.6072 ---
#   INFO: Strategy: Oversample class 1 from 384 to 603 (generating 219 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=603
#
# --- Processing target ratio w (42/100): 0.6352 ---
#   INFO: Strategy: Oversample class 1 from 384 to 576 (generating 192 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=576
#
# --- Processing target ratio w (43/100): 0.6645 ---
#   INFO: Strategy: Oversample class 1 from 384 to 551 (generating 167 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=551
#
# --- Processing target ratio w (44/100): 0.6951 ---
#   INFO: Strategy: Oversample class 1 from 384 to 527 (generating 143 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=527
#
# --- Processing target ratio w (45/100): 0.7272 ---
#   INFO: Strategy: Oversample class 1 from 384 to 503 (generating 119 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=503
#
# --- Processing target ratio w (46/100): 0.7607 ---
#   INFO: Strategy: Oversample class 1 from 384 to 481 (generating 97 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=481
#
# --- Processing target ratio w (47/100): 0.7958 ---
#   INFO: Strategy: Oversample class 1 from 384 to 460 (generating 76 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=460
#
# --- Processing target ratio w (48/100): 0.8325 ---
#   INFO: Strategy: Oversample class 1 from 384 to 440 (generating 56 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=440
#
# --- Processing target ratio w (49/100): 0.8709 ---
#   INFO: Strategy: Oversample class 1 from 384 to 420 (generating 36 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=420
#
# --- Processing target ratio w (50/100): 0.9111 ---
#   INFO: Strategy: Oversample class 1 from 384 to 402 (generating 18 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=366, C1=402
#
# --- Processing target ratio w (51/100): 0.9531 ---
#   INFO: Strategy: Oversample class -1 from 384 to 384 (generating 0 samples).
#   INFO: No synthetic samples were required or generated.
#
# --- Processing target ratio w (52/100): 1.0481 ---
#   INFO: Strategy: Oversample class 0 from 366 to 402 (generating 36 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=402, C1=384
#
# --- Processing target ratio w (53/100): 1.1525 ---
#   INFO: Strategy: Oversample class 0 from 366 to 443 (generating 77 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=443, C1=384
#
# --- Processing target ratio w (54/100): 1.2673 ---
#   INFO: Strategy: Oversample class 0 from 366 to 487 (generating 121 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=487, C1=384
#
# --- Processing target ratio w (55/100): 1.3935 ---
#   INFO: Strategy: Oversample class 0 from 366 to 535 (generating 169 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=535, C1=384
#
# --- Processing target ratio w (56/100): 1.5324 ---
#   INFO: Strategy: Oversample class 0 from 366 to 588 (generating 222 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=588, C1=384
#
# --- Processing target ratio w (57/100): 1.6850 ---
#   INFO: Strategy: Oversample class 0 from 366 to 647 (generating 281 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=647, C1=384
#
# --- Processing target ratio w (58/100): 1.8529 ---
#   INFO: Strategy: Oversample class 0 from 366 to 711 (generating 345 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=711, C1=384
#
# --- Processing target ratio w (59/100): 2.0374 ---
#   INFO: Strategy: Oversample class 0 from 366 to 782 (generating 416 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=782, C1=384
#
# --- Processing target ratio w (60/100): 2.2404 ---
#   INFO: Strategy: Oversample class 0 from 366 to 860 (generating 494 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=860, C1=384
#
# --- Processing target ratio w (61/100): 2.4636 ---
#   INFO: Strategy: Oversample class 0 from 366 to 946 (generating 580 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=946, C1=384
#
# --- Processing target ratio w (62/100): 2.7090 ---
#   INFO: Strategy: Oversample class 0 from 366 to 1040 (generating 674 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1040, C1=384
#
# --- Processing target ratio w (63/100): 2.9789 ---
#   INFO: Strategy: Oversample class 0 from 366 to 1144 (generating 778 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1144, C1=384
#
# --- Processing target ratio w (64/100): 3.2756 ---
#   INFO: Strategy: Oversample class 0 from 366 to 1258 (generating 892 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1258, C1=384
#
# --- Processing target ratio w (65/100): 3.6019 ---
#   INFO: Strategy: Oversample class 0 from 366 to 1383 (generating 1017 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1383, C1=384
#
# --- Processing target ratio w (66/100): 3.9608 ---
#   INFO: Strategy: Oversample class 0 from 366 to 1521 (generating 1155 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1521, C1=384
#
# --- Processing target ratio w (67/100): 4.3553 ---
#   INFO: Strategy: Oversample class 0 from 366 to 1672 (generating 1306 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1672, C1=384
#
# --- Processing target ratio w (68/100): 4.7892 ---
#   INFO: Strategy: Oversample class 0 from 366 to 1839 (generating 1473 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=1839, C1=384
#
# --- Processing target ratio w (69/100): 5.2663 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2022 (generating 1656 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2022, C1=384
#
# --- Processing target ratio w (70/100): 5.7909 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2224 (generating 1858 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2224, C1=384
#
# --- Processing target ratio w (71/100): 6.3678 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2445 (generating 2079 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2445, C1=384
#
# --- Processing target ratio w (72/100): 7.0021 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2689 (generating 2323 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2689, C1=384
#
# --- Processing target ratio w (73/100): 7.6996 ---
#   INFO: Strategy: Oversample class 0 from 366 to 2957 (generating 2591 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=2957, C1=384
#
# --- Processing target ratio w (74/100): 8.4667 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3251 (generating 2885 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3251, C1=384
#
# --- Processing target ratio w (75/100): 9.3101 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3575 (generating 3209 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3575, C1=384
#
# --- Processing target ratio w (76/100): 10.2375 ---
#   INFO: Strategy: Oversample class 0 from 366 to 3931 (generating 3565 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=3931, C1=384
#
# --- Processing target ratio w (77/100): 11.2574 ---
#   INFO: Strategy: Oversample class 0 from 366 to 4323 (generating 3957 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4323, C1=384
#
# --- Processing target ratio w (78/100): 12.3788 ---
#   INFO: Strategy: Oversample class 0 from 366 to 4753 (generating 4387 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=4753, C1=384
#
# --- Processing target ratio w (79/100): 13.6120 ---
#   INFO: Strategy: Oversample class 0 from 366 to 5227 (generating 4861 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5227, C1=384
#
# --- Processing target ratio w (80/100): 14.9680 ---
#   INFO: Strategy: Oversample class 0 from 366 to 5748 (generating 5382 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=5748, C1=384
#
# --- Processing target ratio w (81/100): 16.4591 ---
#   INFO: Strategy: Oversample class 0 from 366 to 6320 (generating 5954 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6320, C1=384
#
# --- Processing target ratio w (82/100): 18.0987 ---
#   INFO: Strategy: Oversample class 0 from 366 to 6950 (generating 6584 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=6950, C1=384
#
# --- Processing target ratio w (83/100): 19.9016 ---
#   INFO: Strategy: Oversample class 0 from 366 to 7642 (generating 7276 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=7642, C1=384
#
# --- Processing target ratio w (84/100): 21.8842 ---
#   INFO: Strategy: Oversample class 0 from 366 to 8404 (generating 8038 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=8404, C1=384
#
# --- Processing target ratio w (85/100): 24.0643 ---
#   INFO: Strategy: Oversample class 0 from 366 to 9241 (generating 8875 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=9241, C1=384
#
# --- Processing target ratio w (86/100): 26.4615 ---
#   INFO: Strategy: Oversample class 0 from 366 to 10161 (generating 9795 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=10161, C1=384
#
# --- Processing target ratio w (87/100): 29.0975 ---
#   INFO: Strategy: Oversample class 0 from 366 to 11173 (generating 10807 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=11173, C1=384
#
# --- Processing target ratio w (88/100): 31.9962 ---
#   INFO: Strategy: Oversample class 0 from 366 to 12287 (generating 11921 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=12287, C1=384
#
# --- Processing target ratio w (89/100): 35.1836 ---
#   INFO: Strategy: Oversample class 0 from 366 to 13510 (generating 13144 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=13510, C1=384
#
# --- Processing target ratio w (90/100): 38.6885 ---
#   INFO: Strategy: Oversample class 0 from 366 to 14856 (generating 14490 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=14856, C1=384
#
# --- Processing target ratio w (91/100): 42.5425 ---
#   INFO: Strategy: Oversample class 0 from 366 to 16336 (generating 15970 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=16336, C1=384
#
# --- Processing target ratio w (92/100): 46.7805 ---
#   INFO: Strategy: Oversample class 0 from 366 to 17964 (generating 17598 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=17964, C1=384
#
# --- Processing target ratio w (93/100): 51.4407 ---
#   INFO: Strategy: Oversample class 0 from 366 to 19753 (generating 19387 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=19753, C1=384
#
# --- Processing target ratio w (94/100): 56.5652 ---
#   INFO: Strategy: Oversample class 0 from 366 to 21721 (generating 21355 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=21721, C1=384
#
# --- Processing target ratio w (95/100): 62.2001 ---
#   INFO: Strategy: Oversample class 0 from 366 to 23885 (generating 23519 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=23885, C1=384
#
# --- Processing target ratio w (96/100): 68.3963 ---
#   INFO: Strategy: Oversample class 0 from 366 to 26264 (generating 25898 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=26264, C1=384
#
# --- Processing target ratio w (97/100): 75.2098 ---
#   INFO: Strategy: Oversample class 0 from 366 to 28881 (generating 28515 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=28881, C1=384
#
# --- Processing target ratio w (98/100): 82.7021 ---
#   INFO: Strategy: Oversample class 0 from 366 to 31758 (generating 31392 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=31758, C1=384
#
# --- Processing target ratio w (99/100): 90.9407 ---
#   INFO: Strategy: Oversample class 0 from 366 to 34921 (generating 34555 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=34921, C1=384
#
# --- Processing target ratio w (100/100): 100.0000 ---
#   INFO: Strategy: Oversample class 0 from 366 to 38400 (generating 38034 samples).
#   INFO: Using KDE-like generator. Perturbation sigma: 0.1
#   INFO: KDE-like generation complete. New C0=38400, C1=384

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Save the data
save_to_pickle(list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader, filename='pickle/Logistic_data2_oversampling.pkl')
# Out:
# Data saved to pickle/Logistic_data2_oversampling.pkl
# {'best_models': [[{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.48360655737704916),
#     'threshold': np.float64(0.077722731492786)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.015625),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.05581299382844901)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.03125),
#     'tpr': np.float64(0.5163934426229508),
#     'threshold': np.float64(0.23535748994653802)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0390625),
#     'tpr': np.float64(0.5245901639344263),
#     'threshold': np.float64(0.350233221403356)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.046875),
#     'tpr': np.float64(0.5327868852459017),
#     'threshold': np.float64(0.06977223989954748)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0546875),
#     'tpr': np.float64(0.5409836065573771),
#     'threshold': np.float64(0.1331440813493389)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0703125),
#     'tpr': np.float64(0.5491803278688525),
#     'threshold': np.float64(0.37112869467800735)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0859375),
#     'tpr': np.float64(0.5573770491803278),
#     'threshold': np.float64(0.2780410984666443)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.109375),
#     'tpr': np.float64(0.5655737704918032),
#     'threshold': np.float64(0.4028837451980422)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.12333333333333334),
#     'tpr': np.float64(0.5733333333333334),
#     'threshold': np.float64(0.6128107468526331)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.13333333333333333),
#     'tpr': np.float64(0.5966666666666667),
#     'threshold': np.float64(0.5921121500909501)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.14),
#     'tpr': np.float64(0.6066666666666667),
#     'threshold': np.float64(0.5893643085997512)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15),
#     'tpr': np.float64(0.6166666666666667),
#     'threshold': np.float64(0.5737868356967218)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.6633333333333333),
#     'threshold': np.float64(0.5425752171226073)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.19333333333333333),
#     'tpr': np.float64(0.6666666666666666),
#     'threshold': np.float64(0.5386871765592103)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1953125),
#     'tpr': np.float64(0.6721311475409836),
#     'threshold': np.float64(0.6098721702720843)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.2),
#     'tpr': np.float64(0.6733333333333333),
#     'threshold': np.float64(0.529011807242643)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.203125),
#     'tpr': np.float64(0.7131147540983607),
#     'threshold': np.float64(0.5904540481313449)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2109375),
#     'tpr': np.float64(0.7213114754098361),
#     'threshold': np.float64(0.7573290106645976)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.21875),
#     'tpr': np.float64(0.7459016393442623),
#     'threshold': np.float64(0.7844290188997052)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.234375),
#     'tpr': np.float64(0.7540983606557377),
#     'threshold': np.float64(0.8165148527646363)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.25),
#     'tpr': np.float64(0.7868852459016393),
#     'threshold': np.float64(0.8115135485757677)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2734375),
#     'tpr': np.float64(0.7950819672131147),
#     'threshold': np.float64(0.8370812377441688)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.28125),
#     'tpr': np.float64(0.819672131147541),
#     'threshold': np.float64(0.8358658429844766)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3046875),
#     'tpr': np.float64(0.8278688524590164),
#     'threshold': np.float64(0.8342129012619082)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3203125),
#     'tpr': np.float64(0.8360655737704918),
#     'threshold': np.float64(0.8644307863117574)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.328125),
#     'tpr': np.float64(0.8524590163934426),
#     'threshold': np.float64(0.8095744968253759)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3359375),
#     'tpr': np.float64(0.8688524590163934),
#     'threshold': np.float64(0.8093708076227694)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.34375),
#     'tpr': np.float64(0.8770491803278688),
#     'threshold': np.float64(0.8382312487855323)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3515625),
#     'tpr': np.float64(0.8852459016393442),
#     'threshold': np.float64(0.880079362600097)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.359375),
#     'tpr': np.float64(0.9016393442622951),
#     'threshold': np.float64(0.7103621399658763)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3984375),
#     'tpr': np.float64(0.9098360655737705),
#     'threshold': np.float64(0.8533284988825698)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.421875),
#     'tpr': np.float64(0.9344262295081968),
#     'threshold': np.float64(0.8486001530148897)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4375),
#     'tpr': np.float64(0.9426229508196722),
#     'threshold': np.float64(0.8384682834016288)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4453125),
#     'tpr': np.float64(0.9508196721311475),
#     'threshold': np.float64(0.8353740546474586)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.453125),
#     'tpr': np.float64(0.9590163934426229),
#     'threshold': np.float64(0.8209071582472944)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4765625),
#     'tpr': np.float64(0.9672131147540983),
#     'threshold': np.float64(0.796576612407103)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.484375),
#     'tpr': np.float64(0.9754098360655737),
#     'threshold': np.float64(0.7740568880760366)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4921875),
#     'tpr': np.float64(0.9836065573770492),
#     'threshold': np.float64(0.7584595065372552)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(0.9918032786885246),
#     'threshold': np.float64(0.7360638036059666)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.6328125),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.4662817360751255)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.44696969696969696),
#     'threshold': np.float64(0.20111007618418567)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.00847457627118644),
#     'tpr': np.float64(0.4696969696969697),
#     'threshold': np.float64(0.05212826018526133)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.025423728813559324),
#     'tpr': np.float64(0.4772727272727273),
#     'threshold': np.float64(0.03517922921301907)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0423728813559322),
#     'tpr': np.float64(0.48484848484848486),
#     'threshold': np.float64(0.05241908911327994)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.05084745762711865),
#     'tpr': np.float64(0.5378787878787878),
#     'threshold': np.float64(0.06013467640059898)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.059322033898305086),
#     'tpr': np.float64(0.5454545454545454),
#     'threshold': np.float64(0.07819301838252478)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0847457627118644),
#     'tpr': np.float64(0.5606060606060606),
#     'threshold': np.float64(0.12763217776726066)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0
},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.26666666666666666),
#     'tpr': np.float64(0.7923076923076923),
#     'threshold': np.float64(0.0841818088925539)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.275),
#     'tpr': np.float64(0.8),
#     'threshold': np.float64(0.09400551710207837)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2833333333333333),
#     'tpr': np.float64(0.8076923076923077),
#     'threshold': np.float64(0.4269474488519882)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2916666666666667),
#     'tpr': np.float64(0.8153846153846154),
#     'threshold': np.float64(0.26434585651374026)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3),
#     'tpr': np.float64(0.8307692307692308),
#     'threshold': np.float64(0.3933114226800626)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.30833333333333335),
#     'tpr': np.float64(0.8384615384615385),
#     'threshold': np.float64(0.5148833047881094)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.325),
#     'tpr': np.float64(0.8461538461538461),
#     'threshold': np.float64(0.27803744447373163)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3416666666666667),
#     'tpr': np.float64(0.8538461538461538),
#     'threshold': np.float64(0.5452673278240087)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.38333333333333336),
#     'tpr': np.float64(0.8769230769230769),
#     'threshold': np.float64(0.8240131001666243)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.39166666666666666),
#     'tpr': np.float64(0.8923076923076924),
#     'threshold': np.float64(0.8174229425030496)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4083333333333333),
#     'tpr': np.float64(0.9230769230769231),
#     'threshold': np.float64(0.7831423134724437)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.43333333333333335),
#     'tpr': np.float64(0.9384615384615385),
#     'threshold': np.float64(0.768262751956491)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4583333333333333),
#     'tpr': np.float64(0.9461538461538461),
#     'threshold': np.float64(0.7401734587863619)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.475),
#     'tpr': np.float64(0.9692307692307692),
#     'threshold': np.float64(0.6972447706662068)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.48333333333333334),
#     'tpr': np.float64(0.9769230769230769),
#     'threshold': np.float64(0.6891484002082403)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(0.9846153846153847),
#     'threshold': np.float64(0.6575366695953058)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.6666666666666666),
#     'tpr': np.float64(0.9923076923076923),
#     'threshold': np.float64(0.37622412751803697)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.6833333333333333),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.36396713053540025)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.47413793103448276),
#     'threshold': np.float64(0.06400721377789155)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.007462686567164179),
#     'tpr': np.float64(0.4827586206896552),
#     'threshold': np.float64(0.06266928637253978)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.014925373134328358),
#     'tpr': np.float64(0.49137931034482757),
#     'threshold': np.float64(0.048652862645386354)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.022388059701492536),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.31918699391328925)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.029850746268656716),
#     'tpr': np.float64(0.5603448275862069),
#     'threshold': np.float64(0.4493261543916804)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.04477611940298507),
#     'tpr': np.float64(0.5862068965517241),
#     'threshold': np.float64(0.271926506260687)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.05970149253731343),
#     'tpr': np.float64(0.603448275862069),
#     'threshold': np.float64(0.2899477470069918)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.07462686567164178),
#     'tpr': np.float64(0.6120689655172413),
#     'threshold': np.float64(0.28372514769762197)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.08955223880597014),
#     'tpr': np.float64(0.6206896551724138),
#     'threshold': np.float64(0.30406654889387164)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.09701492537313433),
#     'tpr': np.float64(0.6293103448275862),
#     'threshold': np.float64(0.46140929913703066)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.12686567164179105),
#     'tpr': np.float64(0.6379310344827587),
#     'threshold': np.float64(0.23415394632484768)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1417910447761194),
#     'tpr': np.float64(0.646551724137931),
#     'threshold': np.float64(0.8359926703196635)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.15671641791044777),
#     'tpr': np.float64(0.6551724137931034),
#     'threshold': np.float64(0.7179695311331871)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1791044776119403),
#     'tpr': np.float64(0.6724137931034483),
#     'threshold': np.float64(0.8403788274084257)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.2),
#     'tpr': np.float64(0.6733333333333333),
#     'threshold': np.float64(0.529011807242643)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.20149253731343283),
#     'tpr': np.float64(0.6896551724137931),
#     'threshold': np.float64(0.7027081375026053)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21),
#     'tpr': np.float64(0.7),
#     'threshold': np.float64(0.5138248258215651)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21333333333333335),
#     'tpr': np.float64(0.7033333333333334),
#     'threshold': np.float64(0.5052511534785067)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.22388059701492538),
#     'tpr': np.float64(0.7068965517241379),
#     'threshold': np.float64(0.7026929045717362)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.23134328358208955),
#     'tpr': np.float64(0.7241379310344828),
#     'threshold': np.float64(0.44087459038165355)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2462686567164179),
#     'tpr': np.float64(0.75),
#     'threshold': np.float64(0.41208698710472785)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2537313432835821),
#     'tpr': np.float64(0.7586206896551724),
#     'threshold': np.float64(0.5758331908134606)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.26119402985074625),
#     'tpr': np.float64(0.7758620689655172),
#     'threshold': np.float64(0.7379477576517831)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.26865671641791045),
#     'tpr': np.float64(0.7844827586206896),
#     'threshold': np.float64(0.6077464997654893)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.291044776119403),
#     'tpr': np.float64(0.7931034482758621),
#     'threshold': np.float64(0.8101687449328177)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.29850746268656714),
#     'tpr': np.float64(0.8017241379310345),
#     'threshold': np.float64(0.7037408420025693)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.30597014925373134),
#     'tpr': np.float64(0.8362068965517241),
#     'threshold': np.float64(0.8972852509158968)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.31343283582089554),
#     'tpr': np.float64(0.8448275862068966),
#     'threshold': np.float64(0.8948754561275206)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3208955223880597),
#     'tpr': np.float64(0.8879310344827587),
#     'threshold': np.float64(0.8571487703960975)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3283582089552239),
#     'tpr': np.float64(0.9051724137931034),
#     'threshold': np.float64(0.8182895208441798)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.34328358208955223),
#     'tpr': np.float64(0.9137931034482759),
#     'threshold': np.float64(0.8565711657954488)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3582089552238806),
#     'tpr': np.float64(0.9224137931034483),
#     'threshold': np.float64(0.8469960539115022)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3880597014925373),
#     'tpr': np.float64(0.9310344827586207),
#     'threshold': np.float64(0.43940784652954323)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.40298507462686567),
#     'tpr': np.float64(0.9396551724137931),
#     'threshold': np.float64(0.8268306518572279)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.44776119402985076),
#     'tpr': np.float64(0.9482758620689655),
#     'threshold': np.float64(0.7872534768435252)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4626865671641791),
#     'tpr': np.float64(0.9568965517241379),
#     'threshold': np.float64(0.5877367716171277)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.47761194029850745),
#     'tpr': np.float64(0.9655172413793104),
#     'threshold': np.float64(0.7586512770253883)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4925373134328358),
#     'tpr': np.float64(0.9741379310344828),
#     'threshold': np.float64(0.7452066148454598)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5074626865671642),
#     'tpr': np.float64(0.9827586206896551),
#     'threshold': np.float64(0.7115482922788369)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.
#          0.46461653, 0.46338811, 0.46124579, 0.45479833, 0.45154339,
#          0.44376617, 0.4404012 , 0.44003808, 0.43327701, 0.43251074,
#          0.43168754, 0.43074778, 0.42761753, 0.42704473, 0.4239242 ,
#          0.41289363, 0.41231114, 0.41111916, 0.41101159, 0.40598082,
#          0.40383325, 0.40379073, 0.39784952, 0.3948533 , 0.39316228,
#          0.3916173 , 0.38613937, 0.37488422, 0.37376655, 0.37273492,
#          0.37078469, 0.35481691, 0.35438355, 0.35037054, 0.34849693,
#          0.34506844, 0.3435108 , 0.33436833, 0.33076733, 0.33047434,
#          0.33028278, 0.32589732, 0.31592191, 0.31493237, 0.3114461 ,
#          0.31002279, 0.30708706, 0.29775991, 0.29533317, 0.28724221,
#          0.28645115, 0.28305874, 0.28248536, 0.27591325, 0.27583821,
#          0.27475734, 0.27262154, 0.27261047, 0.27138951, 0.2652133 ,
#          0.26476858, 0.26443569, 0.26198753, 0.2549473 , 0.25162899,
#          0.24105439, 0.24037919, 0.23319289, 0.2319992 , 0.21978977,
#          0.21789182, 0.21323005, 0.21012376, 0.20137866, 0.1991743 ,
#          0.19267026, 0.19174481, 0.19076747, 0.18967964, 0.18944254,
#          0.18777554, 0.18412117, 0.18379505, 0.18192144, 0.17945039,
#          0.16978321, 0.16748933, 0.164734  , 0.16369108, 0.16366304,
#          0.16225953, 0.15495405, 0.14640905, 0.10930001, 0.10892123,
#          0.10767635, 0.10712183, 0.09504582, 0.08834955, 0.0134105 ]),
#   'name': 'Logistic Regression',
#   'auc': np.float64(0.8326333333333332),
#   'model': LogisticRegression()},
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x78e0b18193a0>}

# %% [markdown]
# # Load pickle

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Load the data
list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader = load_from_pickle(filename='pickle/Logistic_data2_oversampling.pkl')
# Out:
# Data loaded successfully.

# %% [markdown]
# ### Ensemble prediction using voting

# %%
import numpy as np

# --- Loop through all the FPR values to generate the ensemble ROC curve ---



results_tuple = predict_ensemble_and_evaluate(list_folds_best_models=list_folds_best_models,
    test_loader=test_loader)

ensemble_results_soft = results_tuple['soft_voting']
ensemble_results_hard = results_tuple['hard_voting']
# Out:
# Creating a single ensemble from 178 models across all folds.
# Extracting full dataset...
# Getting predictions from all models...
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
#results_lists.append(ensemble_results_soft)
results_lists.append(ensemble_results_hard)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["MaxROCFold 1", "MaxROCFold 2", "MaxROCFold 3", "MaxROCFold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Ensemble_voting_hard"],
    results_original_roc=results_original_roc, plot_name="logistic_oversampling_data2"
)
# Out:
# --- Plotting all ROC curves for comparison ---
