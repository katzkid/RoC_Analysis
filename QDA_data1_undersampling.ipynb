# %% [markdown]
# ### Imports

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        y_prob = clf_model.predict_proba(X_test)[:, 1]
        y_pred = (y_prob >= threshold).astype(int)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data1")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Undersampling

# %%
import numpy as np
from collections import Counter

# --- This block generates the list of ratios for your experiment ---
def generate_ratios(train_data):
    # 1. Get original class counts from your train_dataset

    try:
        original_labels = np.array(train_data.targets).flatten()
    except AttributeError:
        original_labels = train_data[:, -1]

    original_counts = Counter(original_labels)
    num_pos_original = original_counts.get(1, 0)  
    num_neg_original = original_counts.get(0, 0)  
    print(f"Original class counts: {num_pos_original} positives, {num_neg_original} negatives")

    # The pivot point for your function's logic
    orig_sample_ratio = num_pos_original / num_neg_original 

    # 2. Define how many steps for each regime
    N_POINTS_PER_REGIME = 200  # You can change this

    # 3. Generate ratios for Regime 1 (from near 0 up to the pivot)
    # This will test scenarios from extreme negative-class dominance up to the original balance.
    print(f"Generating ratios for Regime 1 (target ratio < {orig_sample_ratio})...")
    ratios_regime1 = np.geomspace(
        start=2/(num_neg_original-1),                      # A small starting ratio (e.g., 1 positive for every 10 negatives)
        stop=orig_sample_ratio,         # Go up to the original ratio
        num=N_POINTS_PER_REGIME,
        endpoint=False                  # Exclude the pivot itself to avoid the 'else' block
    )

    # 4. Generate ratios for Regime 2 (from the pivot up to 3494)
    # This will test scenarios from the original balance up to extreme positive-class dominance.
    print(f"Generating ratios for Regime 2 (target ratio > {orig_sample_ratio})...")
    ratios_regime2 = np.geomspace(
        start=orig_sample_ratio, # Start just above the pivot
        stop=(num_pos_original-1)/2,                      # Your specified upper limit
        num=N_POINTS_PER_REGIME
    )

    # 5. Combine, sort, and create the final list for the loop
    #    We also add the original ratio to ensure we have a baseline run.
    all_ratios = sorted(list(np.concatenate([ratios_regime1, ratios_regime2, [orig_sample_ratio]])))

    print(f"\nGenerated {len(all_ratios)} unique sample ratios to test.")
    print("First few ratios:", np.round(all_ratios[:5], 3))
    print("Last few ratios:", np.round(all_ratios[-5:], 2))

    return all_ratios

# %%
import numpy as np
def undersample_dataset(train_dataset, sample_ratio):

    
    
    # Get the labels from the dataset (0 for normal, 1 for pneumonia)
    try:
        labels = np.array(train_dataset.targets).flatten()
    except AttributeError:
        labels = train_dataset[:, -1]

    # Find the indices for the positive (pneumonia) and negative (normal) classes
    positive_indices = np.where(labels == 1)[0]
    negative_indices = np.where(labels == 0)[0]
    num_orig_positive = len(positive_indices)
    num_orig_negative = len(negative_indices)

    orig_sample_ratio = num_orig_positive / num_orig_negative
    print(f"Original sample ratio (positive:negative): {orig_sample_ratio:.2f}")

    #based on sample ratio find the number of positive or negative samples
    if sample_ratio>orig_sample_ratio:
        neg_samples = int(num_orig_positive / sample_ratio)
        pos_samples = num_orig_positive
        sampled_negative_indices = np.random.choice(negative_indices, neg_samples, replace=False)
        final_indices = np.concatenate([sampled_negative_indices, positive_indices])
    elif sample_ratio<orig_sample_ratio:
        pos_samples = int(sample_ratio * num_orig_negative)
        neg_samples = num_orig_negative
        sampled_positive_indices = np.random.choice(positive_indices, pos_samples, replace=False)
        final_indices = np.concatenate([sampled_positive_indices, negative_indices])
    else:
        pos_samples = num_orig_positive
        neg_samples = num_orig_negative
        final_indices = np.concatenate([positive_indices, negative_indices])
        
    # Shuffle the final indices to mix positive and negative samples
    np.random.shuffle(final_indices)

    # Create a subset of the original dataset with the sampled indices
    return train_dataset[final_indices]

# %% [markdown]
# ### Regular training

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = QuadraticDiscriminantAnalysis()
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "Quadratic Discriminant Analysis", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Undersampling ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds

list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    all_ratios = generate_ratios(np.c_[X_train_fold, y_train_fold])  # Combine features and labels for ratio generation
    for i, sample_ratio in enumerate(all_ratios):
        print("="*60)
        print(f"--- STARTING STAGE {i+1} FOR SAMPLE RATIO: {sample_ratio} ---")
        print("="*60)

        undersampled_train_dataset = undersample_dataset(np.c_[X_train_fold, y_train_fold], sample_ratio)
        X_train_resampled = undersampled_train_dataset[:, :-1]  # All columns except the last one
        y_train_resampled = undersampled_train_dataset[:, -1]   # Last column is the target

        clf_weighted = QuadraticDiscriminantAnalysis(reg_param=0.001)
        clf_weighted.fit(X_train_resampled, y_train_resampled)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# Original class counts: 378 positives, 372 negatives
# Generating ratios for Regime 1 (target ratio < 1.0161290322580645)...
# Generating ratios for Regime 2 (target ratio > 1.0161290322580645)...
#
# Generated 401 unique sample ratios to test.
# First few ratios: [0.005 0.006 0.006 0.006 0.006]
# Last few ratios: [169.71 174.23 178.86 183.62 188.5 ]
# ============================================================
# --- STARTING STAGE 1 FOR SAMPLE RATIO: 0.005390835579514825 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 2 FOR SAMPLE RATIO: 0.0055339158378351905 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 3 FOR SAMPLE RATIO: 0.005680793644795109 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 4 FOR SAMPLE RATIO: 0.005831569792606157 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 5 FOR SAMPLE RATIO: 0.0059863477486451055 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 6 FOR SAMPLE RATIO: 0.006145233726456505 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 7 FOR SAMPLE RATIO: 0.006308336758639795 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 8 FOR SAMPLE RATIO: 0.006475768771670934 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 9 FOR SAMPLE RATIO: 0.006647644662709896 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 10 FOR SAMPLE RATIO: 0.006824082378446748 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 11 FOR SAMPLE RATIO: 0.007005202996040414 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 12 FOR SAMPLE RATIO: 0.007191130806205658 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 13 FOR SAMPLE RATIO: 0.007381993398505322 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 14 FOR SAMPLE RATIO: 0.007577921748906329 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 15 FOR SAMPLE RATIO: 0.007779050309659545 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 16 FOR SAMPLE RATIO: 0.007985517101565196 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 17 FOR SAMPLE RATIO: 0.008197463808687072 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 18 FOR SAMPLE RATIO: 0.008415035875580722 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 19 FOR SAMPLE RATIO: 0.008638382607102 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 20 FOR SAMPLE RATIO: 0.008867657270864897 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 21 FOR SAMPLE RATIO: 0.009103017202418594 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 22 FOR SAMPLE RATIO: 0.009344623913216112 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 23 FOR SAMPLE RATIO: 0.0095926432014486 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 24 FOR SAMPLE RATIO: 0.00984724526582132 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 25 FOR SAMPLE RATIO: 0.010108604822349392 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 26 FOR SAMPLE RATIO: 0.01037690122425346 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 27 FOR SAMPLE RATIO: 0.010652318585037585 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 28 FOR SAMPLE RATIO: 0.01093504590483375 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 29 FOR SAMPLE RATIO: 0.011225277200099762 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 30 FOR SAMPLE RATIO: 0.011523211636759498 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 31 FOR SAMPLE RATIO: 0.01182905366687688 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 32 FOR SAMPLE RATIO: 0.012143013168957365 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 33 FOR SAMPLE RATIO: 0.012465305591973244 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 34 FOR SAMPLE RATIO: 0.012796152103211559 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 35 FOR SAMPLE RATIO: 0.013135779740046108 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 36 FOR SAMPLE RATIO: 0.013484421565737703 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 37 FOR SAMPLE RATIO: 0.013842316829369566 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 38 FOR SAMPLE RATIO: 0.014209711130027652 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 39 FOR SAMPLE RATIO: 0.014586856585338523 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 40 FOR SAMPLE RATIO: 0.014974012004480472 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 41 FOR SAMPLE RATIO: 0.01537144306578659 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 42 FOR SAMPLE RATIO: 0.015779422499061665 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 43 FOR SAMPLE RATIO: 0.016198230272738035 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# ============================================================
# --- STARTING STAGE 44 FOR SAMPLE RATIO: 0.01662815378599881 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 45 FOR SAMPLE RATIO: 0.017069488066000286 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 46 FOR SAMPLE RATIO: 0.017522535970328983 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 47 FOR SAMPLE RATIO: 0.017987608394832096 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 48 FOR SAMPLE RATIO: 0.01846502448696411 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 49 FOR SAMPLE RATIO: 0.018955111864795902 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 50 FOR SAMPLE RATIO: 0.01945820684183665 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 51 FOR SAMPLE RATIO: 0.019974654657822853 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 52 FOR SAMPLE RATIO: 0.02050480971563277 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 53 FOR SAMPLE RATIO: 0.021049035824488936 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 54 FOR SAMPLE RATIO: 0.0216077064496156 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 55 FOR SAMPLE RATIO: 0.02218120496852237 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 56 FOR SAMPLE RATIO: 0.02276992493409009 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 57 FOR SAMPLE RATIO: 0.023374270344639268 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 58 FOR SAMPLE RATIO: 0.023994655921166553 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 59 FOR SAMPLE RATIO: 0.024631507391939443 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 60 FOR SAMPLE RATIO: 0.025285261784644544 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 61 FOR SAMPLE RATIO: 0.025956367726289804 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 62 FOR SAMPLE RATIO: 0.02664528575106663 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 63 FOR SAMPLE RATIO: 0.02735248861638306 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 64 FOR SAMPLE RATIO: 0.028078461627284876 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 65 FOR SAMPLE RATIO: 0.028823702969487344 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 66 FOR SAMPLE RATIO: 0.02958872405124606 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 67 FOR SAMPLE RATIO: 0.030374049854301508 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 68 FOR SAMPLE RATIO: 0.031180219294138205 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 69 FOR SAMPLE RATIO: 0.03200778558980559 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 70 FOR SAMPLE RATIO: 0.03285731664355449 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 71 FOR SAMPLE RATIO: 0.0337293954305497 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 72 FOR SAMPLE RATIO: 0.034624620398925984 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 73 FOR SAMPLE RATIO: 0.0355436058804622 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 74 FOR SAMPLE RATIO: 0.03648698251215528 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 75 FOR SAMPLE RATIO: 0.037455397668983294 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 76 FOR SAMPLE RATIO: 0.03844951590815478 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 77 FOR SAMPLE RATIO: 0.03947001942514891 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 78 FOR SAMPLE RATIO: 0.040517608521859684 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 79 FOR SAMPLE RATIO: 0.041593002087165376 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 80 FOR SAMPLE RATIO: 0.04269693809025283 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 81 FOR SAMPLE RATIO: 0.043830174087035344 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 82 FOR SAMPLE RATIO: 0.04499348774001159 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 83 FOR SAMPLE RATIO: 0.04618767735192228 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 84 FOR SAMPLE RATIO: 0.04741356241357085 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 85 FOR SAMPLE RATIO: 0.04867198416618405 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 86 FOR SAMPLE RATIO: 0.04996380617869836 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 87 FOR SAMPLE RATIO: 0.05128991494036835 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 88 FOR SAMPLE RATIO: 0.05265122046910386 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 89 FOR SAMPLE RATIO: 0.05404865693595304 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 90 FOR SAMPLE RATIO: 0.055483183306160214 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 91 FOR SAMPLE RATIO: 0.056955783997238274 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 92 FOR SAMPLE RATIO: 0.05846746955450718 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 93 FOR SAMPLE RATIO: 0.06001927734456225 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 94 FOR SAMPLE RATIO: 0.06161227226714801 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 95 FOR SAMPLE RATIO: 0.0632475474859262 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 96 FOR SAMPLE RATIO: 0.06492622517863937 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 97 FOR SAMPLE RATIO: 0.06664945730718487 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 98 FOR SAMPLE RATIO: 0.06841842640812758 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 99 FOR SAMPLE RATIO: 0.07023434640419413 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 100 FOR SAMPLE RATIO: 0.07209846343730511 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 101 FOR SAMPLE RATIO: 0.07401205672371725 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 102 FOR SAMPLE RATIO: 0.07597643943186214 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 103 FOR SAMPLE RATIO: 0.07799295958348416 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 104 FOR SAMPLE RATIO: 0.0800630009786957 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 105 FOR SAMPLE RATIO: 0.08218798414558477 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 106 FOR SAMPLE RATIO: 0.08436936731502641 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 107 FOR SAMPLE RATIO: 0.08660864742136688 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 108 FOR SAMPLE RATIO: 0.08890736112966777 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 109 FOR SAMPLE RATIO: 0.09126708589021407 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 110 FOR SAMPLE RATIO: 0.09368944102101075 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 111 FOR SAMPLE RATIO: 0.09617608881901009 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 112 FOR SAMPLE RATIO: 0.09872873570083265 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 113 FOR SAMPLE RATIO: 0.10134913337376443 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 114 FOR SAMPLE RATIO: 0.10403908003783403 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 115 FOR SAMPLE RATIO: 0.10680042161979458 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 116 FOR SAMPLE RATIO: 0.10963505303985724 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 117 FOR SAMPLE RATIO: 0.11254491951204555 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 118 FOR SAMPLE RATIO: 0.11553201787906303 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 119 FOR SAMPLE RATIO: 0.11859839798259003 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 120 FOR SAMPLE RATIO: 0.12174616406995009 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 121 FOR SAMPLE RATIO: 0.12497747623811131 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 122 FOR SAMPLE RATIO: 0.12829455191601316 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 123 FOR SAMPLE RATIO: 0.131699667386237 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 124 FOR SAMPLE RATIO: 0.1351951593470631 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 125 FOR SAMPLE RATIO: 0.1387834265159872 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 126 FOR SAMPLE RATIO: 0.1424669312757967 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 127 FOR SAMPLE RATIO: 0.1462482013643357 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 128 FOR SAMPLE RATIO: 0.15012983160911894 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 129 FOR SAMPLE RATIO: 0.15411448570798486 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 130 FOR SAMPLE RATIO: 0.15820489805700957 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 131 FOR SAMPLE RATIO: 0.16240387562693606 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 132 FOR SAMPLE RATIO: 0.16671429988940673 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 133 FOR SAMPLE RATIO: 0.17113912879432067 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 134 FOR SAMPLE RATIO: 0.17568139879967257 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 135 FOR SAMPLE RATIO: 0.18034422695526678 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 136 FOR SAMPLE RATIO: 0.18513081304173556 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 137 FOR SAMPLE RATIO: 0.19004444176633029 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 138 FOR SAMPLE RATIO: 0.19508848501699172 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 139 FOR SAMPLE RATIO: 0.20026640417624617 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 140 FOR SAMPLE RATIO: 0.20558175249651664 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 141 FOR SAMPLE RATIO: 0.211038177538477 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 142 FOR SAMPLE RATIO: 0.21663942367412384 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 143 FOR SAMPLE RATIO: 0.2223893346562835 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 144 FOR SAMPLE RATIO: 0.22829185625631707 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 145 FOR SAMPLE RATIO: 0.23435103897183404 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 146 FOR SAMPLE RATIO: 0.24057104080627217 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 147 FOR SAMPLE RATIO: 0.24695613012225148 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 148 FOR SAMPLE RATIO: 0.25351068857066 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 149 FOR SAMPLE RATIO: 0.26023921409748174 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 150 FOR SAMPLE RATIO: 0.2671463240304299 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 151 FOR SAMPLE RATIO: 0.27423675824750365 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 152 FOR SAMPLE RATIO: 0.2815153824296429 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 153 FOR SAMPLE RATIO: 0.28898719139971285 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 154 FOR SAMPLE RATIO: 0.29665731255010974 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 155 FOR SAMPLE RATIO: 0.3045310093613406 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 156 FOR SAMPLE RATIO: 0.31261368501399045 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 157 FOR SAMPLE RATIO: 0.3209108860965561 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 158 FOR SAMPLE RATIO: 0.32942830641169135 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 159 FOR SAMPLE RATIO: 0.3381717908834749 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 160 FOR SAMPLE RATIO: 0.3471473395683828 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 161 FOR SAMPLE RATIO: 0.35636111177271756 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 162 FOR SAMPLE RATIO: 0.3658194302793196 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 163 FOR SAMPLE RATIO: 0.3755287856864615 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 164 FOR SAMPLE RATIO: 0.38549584086190214 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 165 FOR SAMPLE RATIO: 0.39572743551515854 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 166 FOR SAMPLE RATIO: 0.40623059089113117 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 167 FOR SAMPLE RATIO: 0.417012514588305 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 168 FOR SAMPLE RATIO: 0.4280806055048324 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 169 FOR SAMPLE RATIO: 0.43944245891589184 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 170 FOR SAMPLE RATIO: 0.4511058716858067 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 171 FOR SAMPLE RATIO: 0.46307884761850043 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 172 FOR SAMPLE RATIO: 0.4753696029499618 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 173 FOR SAMPLE RATIO: 0.48798657198648593 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 174 FOR SAMPLE RATIO: 0.5009384128925632 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 175 FOR SAMPLE RATIO: 0.5142340136323865 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 176 FOR SAMPLE RATIO: 0.527882498069054 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 177 FOR SAMPLE RATIO: 0.541893232225654 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 178 FOR SAMPLE RATIO: 0.556275830712526 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 179 FOR SAMPLE RATIO: 0.5710401633251131 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 180 FOR SAMPLE RATIO: 0.5861963618169275 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 181 FOR SAMPLE RATIO: 0.6017548268522819 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 182 FOR SAMPLE RATIO: 0.617726235143555 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 183 FOR SAMPLE RATIO: 0.6341215467778902 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 184 FOR SAMPLE RATIO: 0.650952012738356 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 185 FOR SAMPLE RATIO: 0.6682291826247263 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 186 FOR SAMPLE RATIO: 0.6859649125791835 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 187 FOR SAMPLE RATIO: 0.7041713734223782 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 188 FOR SAMPLE RATIO: 0.722861059005434 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 189 FOR SAMPLE RATIO: 0.742046794783623 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 190 FOR SAMPLE RATIO: 0.7617417466176015 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 191 FOR SAMPLE RATIO: 0.7819594298082403 ---
# ...
# ============================================================
# --- STARTING STAGE 346 FOR SAMPLE RATIO: 45.413106885001454 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 347 FOR SAMPLE RATIO: 46.617032578734346 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 348 FOR SAMPLE RATIO: 47.85287498496393 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 349 FOR SAMPLE RATIO: 49.121480232767716 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 350 FOR SAMPLE RATIO: 50.423716882556434 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 351 FOR SAMPLE RATIO: 51.76047652074083 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 352 FOR SAMPLE RATIO: 53.13267437016299 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 353 FOR SAMPLE RATIO: 54.54124991671099 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 354 FOR SAMPLE RATIO: 55.987167552544925 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 355 FOR SAMPLE RATIO: 57.471417236375714 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 356 FOR SAMPLE RATIO: 58.99501517124788 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 357 FOR SAMPLE RATIO: 60.55900450029078 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 358 FOR SAMPLE RATIO: 62.16445602091481 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 359 FOR SAMPLE RATIO: 63.81246891794092 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 360 FOR SAMPLE RATIO: 65.50417151616622 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 361 FOR SAMPLE RATIO: 67.24072205288024 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 362 FOR SAMPLE RATIO: 69.0233094708609 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 363 FOR SAMPLE RATIO: 70.85315423239366 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 364 FOR SAMPLE RATIO: 72.73150915487025 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 365 FOR SAMPLE RATIO: 74.65966026853997 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 366 FOR SAMPLE RATIO: 76.63892769700018 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 367 FOR SAMPLE RATIO: 78.67066656102908 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 368 FOR SAMPLE RATIO: 80.75626790637986 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 369 FOR SAMPLE RATIO: 82.89715965617066 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 370 FOR SAMPLE RATIO: 85.09480758852352 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 371 FOR SAMPLE RATIO: 87.35071634012041 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 372 FOR SAMPLE RATIO: 89.66643043636466 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 373 FOR SAMPLE RATIO: 92.0435353488521 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 374 FOR SAMPLE RATIO: 94.48365858087641 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 375 FOR SAMPLE RATIO: 96.98847078171205 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 376 FOR SAMPLE RATIO: 99.55968689043704 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 377 FOR SAMPLE RATIO: 102.1990673100794 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 378 FOR SAMPLE RATIO: 104.90841911289077 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 379 FOR SAMPLE RATIO: 107.6895972775722 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 380 FOR SAMPLE RATIO: 110.54450595929991 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 381 FOR SAMPLE RATIO: 113.47509979341979 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 382 FOR SAMPLE RATIO: 116.48338523370353 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 383 FOR SAMPLE RATIO: 119.57142192608322 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 384 FOR SAMPLE RATIO: 122.74132411880313 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 385 FOR SAMPLE RATIO: 125.99526210995664 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 386 FOR SAMPLE RATIO: 129.33546373339783 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 387 FOR SAMPLE RATIO: 132.76421588404455 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 388 FOR SAMPLE RATIO: 136.2838660836193 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 389 FOR SAMPLE RATIO: 139.89682408789776 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 390 FOR SAMPLE RATIO: 143.60556353656733 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 391 FOR SAMPLE RATIO: 147.41262364682305 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 392 FOR SAMPLE RATIO: 151.32061095186245 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 393 FOR SAMPLE RATIO: 155.3322010854694 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 394 FOR SAMPLE RATIO: 159.45014061390643 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 395 FOR SAMPLE RATIO: 163.6772489163732 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 396 FOR SAMPLE RATIO: 168.01642011531666 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# ============================================================
# --- STARTING STAGE 397 FOR SAMPLE RATIO: 172.47062505791354 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 398 FOR SAMPLE RATIO: 177.04291335008443 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 399 FOR SAMPLE RATIO: 181.7364154444299 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 400 FOR SAMPLE RATIO: 186.55434478351967 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 401 FOR SAMPLE RATIO: 191.5 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/kartik/anaconda3/envs/MLlabs/lib/python3.12/site-packages/sklearn/discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
plot_roc_comparison(
    results_lists=results_lists,
    names=["Fold 1", "Fold 2", "Fold 3", "Fold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4"],
    results_original_roc=results_original_roc
)

# %% [markdown]
# ### Ensemble prediction using voting

# %%
# --- Loop through all the FPR values to generate the ensemble ROC curve ---

ensemble_results_soft = []
ensemble_results_hard = []

print("\n--- Generating Ensemble ROC Curve by iterating through FPR values ---")
# We iterate from a low to high target_fpr to trace the curve
for target_fpr in np.linspace(0.0, 1.0, 50): 
    # 1. Assign the function's output to a single variable first.
    result_tuple = predict_ensemble_and_evaluate(
        list_folds_best_models=list_folds_best_models,
        test_loader=test_loader,
        target_fpr=target_fpr
    )
    
    if result_tuple is not None:
        
        for voting_method, metrics in result_tuple.items():
            # Create a dictionary for each point and append it to the list
            if voting_method == 'soft_voting':
                point_dict = {'fpr': metrics['fpr'], 'tpr': metrics['tpr']}
                ensemble_results_soft.append(point_dict)
            else:
                point_dict = {'fpr': metrics['fpr'], 'tpr': metrics['tpr']}
                ensemble_results_hard.append(point_dict)
            
        
# Ensure the curve starts at (0, 0)
    if not ensemble_results_soft or ensemble_results_soft[0]['fpr'] > 0.0:
        ensemble_results_soft.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if ensemble_results_soft[-1]['fpr'] < 1.0 or ensemble_results_soft[-1]['tpr'] < 1.0:
        ensemble_results_soft.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    if not ensemble_results_hard or ensemble_results_hard[0]['fpr'] > 0.0:
        ensemble_results_hard.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if ensemble_results_hard[-1]['fpr'] < 1.0 or ensemble_results_hard[-1]['tpr'] < 1.0:
        ensemble_results_hard.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })
# Out:
# --- Generating Ensemble ROC Curve by iterating through FPR values ---
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0000
# Soft Voting -> Achieved [TPR: 0.0000, FPR: 0.0000]
# Hard Voting -> Resulted in [TPR: 0.9100, FPR: 0.0100]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0204
# Soft Voting -> Achieved [TPR: 0.9433, FPR: 0.0233]
# Hard Voting -> Resulted in [TPR: 0.9367, FPR: 0.0200]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0408
# Soft Voting -> Achieved [TPR: 0.9633, FPR: 0.0433]
# Hard Voting -> Resulted in [TPR: 0.9667, FPR: 0.0433]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0612
# Soft Voting -> Achieved [TPR: 0.9700, FPR: 0.0600]
# Hard Voting -> Resulted in [TPR: 0.9700, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.0816
# Soft Voting -> Achieved [TPR: 0.9800, FPR: 0.0733]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1020
# Soft Voting -> Achieved [TPR: 0.9833, FPR: 0.1133]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1224
# Soft Voting -> Achieved [TPR: 0.9833, FPR: 0.1133]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1429
# Soft Voting -> Achieved [TPR: 0.9867, FPR: 0.1467]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1633
# Soft Voting -> Achieved [TPR: 0.9867, FPR: 0.1467]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.1837
# Soft Voting -> Achieved [TPR: 0.9900, FPR: 0.2033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2041
# Soft Voting -> Achieved [TPR: 0.9900, FPR: 0.2033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2245
# Soft Voting -> Achieved [TPR: 0.9900, FPR: 0.2033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2449
# Soft Voting -> Achieved [TPR: 0.9900, FPR: 0.2033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2653
# Soft Voting -> Achieved [TPR: 0.9933, FPR: 0.3033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.2857
# Soft Voting -> Achieved [TPR: 0.9933, FPR: 0.3033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3061
# Soft Voting -> Achieved [TPR: 0.9933, FPR: 0.3033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3265
# Soft Voting -> Achieved [TPR: 0.9933, FPR: 0.3033]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3469
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3673
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.3878
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4082
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4286
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4490
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4694
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.4898
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
#
# --- Ensemble Results ---
# Target FPR: 0.5102
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9733, FPR: 0.0400]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
#
# --- Ensemble Results ---
# Target FPR: 0.5306
# Soft Voting -> Achieved [TPR: 0.9967, FPR: 0.3533]
# Hard Voting -> Resulted in [TPR: 0.9800, FPR: 0.0667]
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.
# Extracting full dataset from DataLoader for scikit-learn compatibility...
# -> Extracted 600 samples.
#
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Error: No model probabilities were generated. Cannot calculate metrics.

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
results_lists.append(ensemble_results_soft)
results_lists.append(ensemble_results_hard)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["Fold 1", "Fold 2", "Fold 3", "Fold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Ensemble_voting_soft", "Ensemble_voting_hard"],
    results_original_roc=results_original_roc
)
# Out:
# --- Plotting all ROC curves for comparison ---
