# %% [markdown]
# ### Imports

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        #y_prob = clf_model.predict_proba(X_test)[:, 1]
        #y_pred = (y_prob >= threshold).astype(int)
        y_pred = clf_model.predict(X_test)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data2")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Undersampling

# %%
import numpy as np
from collections import Counter

# --- This block generates the list of ratios for your experiment ---
def generate_ratios(train_data):
    # 1. Get original class counts from your train_dataset

    try:
        original_labels = np.array(train_data.targets).flatten()
    except AttributeError:
        original_labels = train_data[:, -1]

    original_counts = Counter(original_labels)
    num_pos_original = original_counts.get(1, 0)  
    num_neg_original = original_counts.get(0, 0)  
    print(f"Original class counts: {num_pos_original} positives, {num_neg_original} negatives")

    # The pivot point for your function's logic
    orig_sample_ratio = num_pos_original / num_neg_original 

    # 2. Define how many steps for each regime
    N_POINTS_PER_REGIME = 50  # You can change this

    # 3. Generate ratios for Regime 1 (from near 0 up to the pivot)
    # This will test scenarios from extreme negative-class dominance up to the original balance.
    print(f"Generating ratios for Regime 1 (target ratio < {orig_sample_ratio})...")
    ratios_regime1 = np.geomspace(
        start=1/num_neg_original,                      # A small starting ratio (e.g., 1 positive for every 10 negatives)
        stop=orig_sample_ratio,         # Go up to the original ratio
        num=N_POINTS_PER_REGIME,
        endpoint=False                  # Exclude the pivot itself to avoid the 'else' block
    )

    # 4. Generate ratios for Regime 2 (from the pivot up to 3494)
    # This will test scenarios from the original balance up to extreme positive-class dominance.
    print(f"Generating ratios for Regime 2 (target ratio > {orig_sample_ratio})...")
    ratios_regime2 = np.geomspace(
        start=orig_sample_ratio, # Start just above the pivot
        stop=num_pos_original,                      # Your specified upper limit
        num=N_POINTS_PER_REGIME
    )

    # 5. Combine, sort, and create the final list for the loop
    #    We also add the original ratio to ensure we have a baseline run.
    all_ratios = sorted(list(np.concatenate([ratios_regime1, ratios_regime2, [orig_sample_ratio]])))

    print(f"\nGenerated {len(all_ratios)} unique sample ratios to test.")
    print("First few ratios:", np.round(all_ratios[:5], 3))
    print("Last few ratios:", np.round(all_ratios[-5:], 2))

    return all_ratios

# %%
import numpy as np
def undersample_dataset(train_dataset, sample_ratio):

    
    
    # Get the labels from the dataset (0 for normal, 1 for pneumonia)
    try:
        labels = np.array(train_dataset.targets).flatten()
    except AttributeError:
        labels = train_dataset[:, -1]

    # Find the indices for the positive (pneumonia) and negative (normal) classes
    positive_indices = np.where(labels == 1)[0]
    negative_indices = np.where(labels == 0)[0]
    num_orig_positive = len(positive_indices)
    num_orig_negative = len(negative_indices)

    orig_sample_ratio = num_orig_positive / num_orig_negative
    print(f"Original sample ratio (positive:negative): {orig_sample_ratio:.2f}")

    #based on sample ratio find the number of positive or negative samples
    if sample_ratio>orig_sample_ratio:
        neg_samples = int(num_orig_positive / sample_ratio)
        pos_samples = num_orig_positive
        sampled_negative_indices = np.random.choice(negative_indices, neg_samples, replace=False)
        final_indices = np.concatenate([sampled_negative_indices, positive_indices])
    elif sample_ratio<orig_sample_ratio:
        pos_samples = int(sample_ratio * num_orig_negative)
        neg_samples = num_orig_negative
        sampled_positive_indices = np.random.choice(positive_indices, pos_samples, replace=False)
        final_indices = np.concatenate([sampled_positive_indices, negative_indices])
    else:
        pos_samples = num_orig_positive
        neg_samples = num_orig_negative
        final_indices = np.concatenate([positive_indices, negative_indices])
        
    # Shuffle the final indices to mix positive and negative samples
    np.random.shuffle(final_indices)

    # Create a subset of the original dataset with the sampled indices
    return train_dataset[final_indices]

# %% [markdown]
# ### Regular training

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "RF Regression", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Undersampling ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds

list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    all_ratios = generate_ratios(np.c_[X_train_fold, y_train_fold])  # Combine features and labels for ratio generation
    for i, sample_ratio in enumerate(all_ratios):
        print("="*60)
        print(f"--- STARTING STAGE {i+1} FOR SAMPLE RATIO: {sample_ratio} ---")
        print("="*60)

        undersampled_train_dataset = undersample_dataset(np.c_[X_train_fold, y_train_fold], sample_ratio)
        X_train_resampled = undersampled_train_dataset[:, :-1]  # All columns except the last one
        y_train_resampled = undersampled_train_dataset[:, -1]   # Last column is the target

        clf_weighted = RandomForestClassifier(random_state=42)
        clf_weighted.fit(X_train_resampled, y_train_resampled)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# Original class counts: 378 positives, 372 negatives
# Generating ratios for Regime 1 (target ratio < 1.0161290322580645)...
# Generating ratios for Regime 2 (target ratio > 1.0161290322580645)...
#
# Generated 101 unique sample ratios to test.
# First few ratios: [0.003 0.003 0.003 0.004 0.004]
# Last few ratios: [233.16 263.09 296.87 334.99 378.  ]
# ============================================================
# --- STARTING STAGE 1 FOR SAMPLE RATIO: 0.002688172043010753 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 2 FOR SAMPLE RATIO: 0.0030269614925120462 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 3 FOR SAMPLE RATIO: 0.003408448466300083 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 4 FOR SAMPLE RATIO: 0.003838014119493177 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 5 FOR SAMPLE RATIO: 0.004321717792441494 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 6 FOR SAMPLE RATIO: 0.004866382482191542 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 7 FOR SAMPLE RATIO: 0.00547969108589158 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 8 FOR SAMPLE RATIO: 0.006170294773722182 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 9 FOR SAMPLE RATIO: 0.006947935020032003 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 10 FOR SAMPLE RATIO: 0.007823581014017953 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 11 FOR SAMPLE RATIO: 0.008809584388228821 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 12 FOR SAMPLE RATIO: 0.00991985344745186 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 13 FOR SAMPLE RATIO: 0.011170049355609463 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 14 FOR SAMPLE RATIO: 0.012577807048026657 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 15 FOR SAMPLE RATIO: 0.014162983985199863 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 16 FOR SAMPLE RATIO: 0.0159479402569225 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 17 FOR SAMPLE RATIO: 0.017957853987842394 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 18 FOR SAMPLE RATIO: 0.020221076493479238 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 19 FOR SAMPLE RATIO: 0.02276953219643961 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 20 FOR SAMPLE RATIO: 0.025639168943942567 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 21 FOR SAMPLE RATIO: 0.02887046507871685 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 22 FOR SAMPLE RATIO: 0.03250900041587856 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 23 FOR SAMPLE RATIO: 0.03660609917983917 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 24 FOR SAMPLE RATIO: 0.04121955397034339 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 25 FOR SAMPLE RATIO: 0.04641444096971152 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 26 FOR SAMPLE RATIO: 0.05226403789038598 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 27 FOR SAMPLE RATIO: 0.05885085761110867 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 28 FOR SAMPLE RATIO: 0.06626781208193035 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 29 FOR SAMPLE RATIO: 0.0746195229157903 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 30 FOR SAMPLE RATIO: 0.0840237971535269 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 31 FOR SAMPLE RATIO: 0.09461328901907334 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE
---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 73 FOR SAMPLE RATIO: 13.166941009882681 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 74 FOR SAMPLE RATIO: 14.852543409926378 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 75 FOR SAMPLE RATIO: 16.75393286703219 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 76 FOR SAMPLE RATIO: 18.898733958617846 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 77 FOR SAMPLE RATIO: 21.31810769884525 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 78 FOR SAMPLE RATIO: 24.047204265359277 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 79 FOR SAMPLE RATIO: 27.12567368309321 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 80 FOR SAMPLE RATIO: 30.598241884675158 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 81 FOR SAMPLE RATIO: 34.51536051680195 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 82 FOR SAMPLE RATIO: 38.93393993337467 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 83 FOR SAMPLE RATIO: 43.918176024779335 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 84 FOR SAMPLE RATIO: 49.540482896006736 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 85 FOR SAMPLE RATIO: 55.88254494414349 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 86 FOR SAMPLE RATIO: 63.0365036204752 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 87 FOR SAMPLE RATIO: 71.10629611922529 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 88 FOR SAMPLE RATIO: 80.20916544223833 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 89 FOR SAMPLE RATIO: 90.47736377877382 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 90 FOR SAMPLE RATIO: 102.06007394817912 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 91 FOR SAMPLE RATIO: 115.12557682136482 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 92 FOR SAMPLE RATIO: 129.86369621073968 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 93 FOR SAMPLE RATIO: 146.48855674949874 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 94 FOR SAMPLE RATIO: 165.24169482846182 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 95 FOR SAMPLE RATIO: 186.39556778810277 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 96 FOR SAMPLE RATIO: 210.25751234950943 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 97 FOR SAMPLE RATIO: 237.1742097948416 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 98 FOR SAMPLE RATIO: 267.5367227702237 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 99 FOR SAMPLE RATIO: 301.7861768889014 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 100 FOR SAMPLE RATIO: 340.4201696805555 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 101 FOR SAMPLE RATIO: 384.0 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Save the data
save_to_pickle(list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader, filename='pickle/RF_data2_undersampling.pkl')
# Out:
# Data saved to pickle/RF_data2_undersampling.pkl
# {'best_models': [[{'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0078125),
#     'tpr': np.float64(0.5327868852459017),
#     'threshold': np.float64(0.55)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0390625),
#     'tpr': np.float64(0.5655737704918032),
#     'threshold': np.float64(0.52)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.046875),
#     'tpr': np.float64(0.5819672131147541),
#     'threshold': np.float64(0.01)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0703125),
#     'tpr': np.float64(0.5901639344262295),
#     'threshold': np.float64(0.37)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.078125),
#     'tpr': np.float64(0.6065573770491803),
#     'threshold': np.float64(0.36)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0859375),
#     'tpr': np.float64(0.6229508196721312),
#     'threshold': np.float64(0.31)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.109375),
#     'tpr': np.float64(0.6557377049180327),
#     'threshold': np.float64(0.28)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.1171875),
#     'tpr': np.float64(0.6639344262295082),
#     'threshold': np.float64(0.27)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.140625),
#     'tpr': np.float64(0.680327868852459),
#     'threshold': np.float64(0.25)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.1640625),
#     'tpr': np.float64(0.7131147540983607),
#     'threshold': np.float64(0.9)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.1875),
#     'tpr': np.float64(0.7295081967213115),
#     'threshold': np.float64(0.89)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.203125),
#     'tpr': np.float64(0.7459016393442623),
#     'threshold': np.float64(0.93)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.21875),
#     'tpr': np.float64(0.7540983606557377),
#     'threshold': np.float64(0.87)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2421875),
#     'tpr': np.float64(0.7704918032786885),
#     'threshold': np.float64(0.95)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2734375),
#     'tpr': np.float64(0.7950819672131147),
#     'threshold': np.float64(0.94)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.28125),
#     'tpr': np.float64(0.8032786885245902),
#     'threshold': np.float64(0.93)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.296875),
#     'tpr': np.float64(0.819672131147541),
#     'threshold': np.float64(0.92)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3046875),
#     'tpr': np.float64(0.8278688524590164),
#     'threshold': np.float64(0.94)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3125),
#     'tpr': np.float64(0.8442622950819673),
#     'threshold': np.float64(0.93)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3359375),
#     'tpr': np.float64(0.8934426229508197),
#     'threshold': np.float64(0.93)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3515625),
#     'tpr': np.float64(0.9262295081967213),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3984375),
#     'tpr': np.float64(0.9344262295081968),
#     'threshold': np.float64(0.89)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.40625),
#     'tpr': np.float64(0.9508196721311475),
#     'threshold': np.float64(0.86)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.4453125),
#     'tpr': np.float64(0.9590163934426229),
#     'threshold': np.float64(0.81)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.453125),
#     'tpr': np.float64(0.9754098360655737),
#     'threshold': np.float64(1.0)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.46875),
#     'tpr': np.float64(0.9918032786885246),
#     'threshold': np.float64(0.99)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.4765625),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.98)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.4696969696969697),
#     'threshold': np.float64(0.41)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.00847457627118644),
#     'tpr': np.float64(0.48484848484848486),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.01694915254237288),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.9)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.025423728813559324),
#     'tpr': np.float64(0.553030303030303),
#     'threshold': np.float64(0.43)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0423728813559322),
#     'tpr': np.float64(0.5681818181818182),
#     'threshold': np.float64(0.41)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.059322033898305086),
#     'tpr': np.float64(0.5757575757575758),
#     'threshold': np.float64(0.55)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.06779661016949153),
#     'tpr': np.float64(0.6060606060606061),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.07627118644067797),
#     'tpr': np.float64(0.6136363636363636),
#     'threshold': np.float64(0.32)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.09322033898305085),
#     'tpr': np.float64(0.6212121212121212),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.11864406779661017),
#     'tpr': np.float64(0.6363636363636364),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.1271186440677966),
#     'tpr': np.float64(0.6590909090909091),
#     'threshold': np.float64(0.06)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.1440677966101695),
#     'tpr': np.float64(0.6666666666666666),
#     'threshold': np.float64(0.05)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.16101694915254236),
#     'tpr': np.float64(0.6893939393939394),
#     'threshold': np.float64(0.09)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.19491525423728814),
#     'tpr': np.float64(0.75),
#     'threshold': np.float64(0.07)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2542372881355932),
#     'tpr': np.float64(0.7727272727272727),
#     'threshold': np.float64(0.06)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2711864406779661),
#     'tpr': np.float64(0.7878787878787878),
#     'threshold': np.float64(0.1)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2796610169491525),
#     'tpr': np.float64(0.7954545454545454),
#     'threshold': np.float64(0.74)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.288135593220339),
#     'tpr': np.float64(0.803030303030303),
#     'threshold': np.float64(0.34)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3050847457627119),
#     'tpr': np.float64(0.8181818181818182),
#     'threshold': np.float64(0.33)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3135593220338983),
#     'tpr': np.float64(0.8409090909090909),
#     'threshold': np.float64(0.04)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3305084745762712),
#     'tpr': np.float64(0.8636363636363636),
#     'threshold': np.float64(0.91)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3474576271186441),
#     'tpr': np.float64(0.9166666666666666),
#     'threshold': np.float64(0.88)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3559322033898305),
#     'tpr': np.float64(0.9242424242424242),
#     'threshold': np.float64(0.87)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3898305084745763),
#     'tpr': np.float64(0.946969696969697),
#     'threshold': np.float64(0.85)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.4152542372881356),
#     'tpr': np.float64(0.9545454545454546),
#     'threshold': np.float64(0.84)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.4491525423728814),
#     'tpr': np.float64(0.9621212121212122),
#     'threshold': np.float64(0.81)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.4661016949152542),
#     'tpr': np.float64(0.9696969696969697),
#     'threshold': np.float64(0.8)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.4915254237288136),
#     'tpr': np.float64(0.9772727272727273),
#     'threshold': np.float64(0.18)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(0.9848484848484849),
#     'threshold': np.float64(0.12)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.5266666666666666),
#     'tpr': np.float64(0.9866666666666667),
#     'threshold': np.float64(0.13)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.53),
#     'tpr': np.float64(0.99),
#     'threshold': np.float64(0.12)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.5338983050847458),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.11)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.5076923076923077),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.008333333333333333),
#     'tpr': np.float64(0.6),
#     'threshold': np.float64(0.43)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.016666666666666666),
#     'tpr': np.float64(0.6153846153846154),
#     'threshold': np.float64(0.4)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.025),
#     'tpr': np.float64(0.6307692307692307),
#     'threshold': np.float64(0.38)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.03333333333333333),
#     'tpr': np.float64(0.6384615384615384),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.041666666666666664),
#     'tpr': np.float64(0.6461538461538462),
#     'threshold': np.float64(0.33)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.05),
#     'tpr': np.float64(0.6538461538461539),
#     'threshold': np.float64(0.48)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.058333333333333334),
#     'tpr': np.float64(0.6692307692307692),
#     'threshold': np.float64(0.52)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.06666666666666667),
#     'tpr': np.float64(0.6846153846153846),
#     'threshold': np.float64(0.49)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.075),
#     'tpr': np.float64(0.7153846153846154),
#     'threshold': np.float64(0.51)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.08333333333333333),
#     'tpr': np.float64(0.7307692307692307),
#     'threshold': np.float64(0.5)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.11666666666666667),
#     'tpr': np.float64(0.7384615384615385),
#     'threshold': np.float64(0.67)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.13333333333333333),
#     'tpr': np.float64(0.7461538461538462),
#     'threshold': np.float64(0.66)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.14166666666666666),
#     'tpr': np.float64(0.7615384615384615),
#     'threshold': np.float64(0.64)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.15),
#     'tpr': np.float64(0.7769230769230769),
#     'threshold': np.float64(0.26)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.16666666666666666),
#     'tpr': np.float64(0.7923076923076923),
#     'threshold': np.float64(0.25)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.8076923076923077),
#     'threshold': np.float64(0.23)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2),
#     'tpr': np.float64(0.8461538461538461),
#     'threshold': np.float64(0.21)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.225),
#     'tpr': np.float64(0.8538461538461538),
#     'threshold': np.float64(0.2)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.23333333333333334),
#     'tpr': np.float64(0.8615384615384616),
#     'threshold': np.float64(0.19)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.26666666666666666),
#     'tpr': np.float64(0.8769230769230769),
#     'threshold': np.float64(0.16)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2916666666666667),
#     'tpr': np.float64(0.8923076923076924),
#     'threshold': np.float64(0.21)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.31666666666666665),
#     'tpr': np.float64(0.9153846153846154),
#     'threshold': np.float64(0.62)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.325),
#     'tpr': np.float64(0.9230769230769231),
#     'threshold': np.float64(0.6)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.35),
#     'tpr': np.float64(0.9307692307692308),
#     'threshold': np.float64(0.59)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.36666666666666664),
#     'tpr': np.float64(0.9461538461538461),
#     'threshold': np.float64(0.1)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.38333333333333336),
#     'tpr': np.float64(0.9769230769230769),
#     'threshold': np.float64(0.28)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.4166666666666667),
#     'tpr': np.float64(0.9846153846153847),
#     'threshold': np.float64(0.07)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.44166666666666665),
#     'tpr': np.float64(0.9923076923076923),
#     'threshold': np.float64(0.49)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.475),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.55)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.45689655172413796),
#     'threshold': np.float64(0.65)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.007462686567164179),
#     'tpr': np.float64(0.4827586206896552),
#     'threshold': np.float64(0.31)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.022388059701492536),
#     'tpr': np.float64(0.5258620689655172),
#     'threshold': np.float64(0.42)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.03731343283582089),
#     'tpr': np.float64(0.5431034482758621),
#     'threshold': np.float64(0.39)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.04477611940298507),
#     'tpr': np.float64(0.5775862068965517),
#     'threshold': np.float64(0.31)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.05223880597014925),
#     'tpr': np.float64(0.5862068965517241),
#     'threshold': np.float64(0.29)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.05970149253731343),
#     'tpr': np.float64(0.6120689655172413),
#     'threshold': np.float64(0.02)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.08955223880597014),
#     'tpr': np.float64(0.6379310344827587),
#     'threshold': np.float64(0.57)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.11194029850746269),
#     'tpr': np.float64(0.6896551724137931),
#     'threshold': np.float64(0.01)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.13432835820895522),
#     'tpr': np.float64(0.7155172413793104),
#     'threshold': np.float64(0.31)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.14925373134328357),
#     'tpr': np.float64(0.7241379310344828),
#     'threshold': np.float64(0.3)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.1791044776119403),
#     'tpr': np.float64(0.7327586206896551),
#     'threshold': np.float64(0.28)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.1865671641791045),
#     'tpr': np.float64(0.7413793103448276),
#     'threshold': np.float64(0.39)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.20149253731343283),
#     'tpr': np.float64(0.7672413793103449),
#     'threshold': np.float64(0.37)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.21641791044776118),
#     'tpr': np.float64(0.7758620689655172),
#     'threshold': np.float64(0.35)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.23880597014925373),
#     'tpr': np.float64(0.7844827586206896),
#     'threshold': np.float64(0.32)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2537313432835821),
#     'tpr': np.float64(0.8017241379310345),
#     'threshold': np.float64(0.2)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.2835820895522388),
#     'tpr': np.float64(0.8189655172413793),
#     'threshold': np.float64(0.22)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.291044776119403),
#     'tpr': np.float64(0.8362068965517241),
#     'threshold': np.float64(0.16)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.30597014925373134),
#     'tpr': np.float64(0.853448275862069),
#     'threshold': np.float64(0.15)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3208955223880597),
#     'tpr': np.float64(0.8620689655172413),
#     'threshold': np.float64(0.14)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3283582089552239),
#     'tpr': np.float64(0.8706896551724138),
#     'threshold': np.float64(0.51)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.3358208955223881),
#     'tpr': np.float64(0.8879310344827587),
#     'threshold': np.float64(0.17)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0.34328358208955223),
#     'tpr': np.float64(0.9051724137931034),
#     'threshold': np.float64(0.65)},
#    {'model': RandomForestClassifier(random_state=42),
#     'fpr': np.float64(0
#          0.84      , 0.84      , 0.85      , 0.85666667, 0.86      ,
#          0.87      , 0.87333333, 0.88666667, 0.89333333, 0.90666667,
#          0.91666667, 0.92666667, 0.93      , 0.93666667, 0.94      ,
#          0.95      , 0.95333333, 0.96      , 0.96333333, 0.96666667,
#          0.97333333, 0.98      , 0.98666667, 0.99      , 0.99      ,
#          0.99      , 0.99333333, 0.99333333, 0.99666667, 0.99666667,
#          1.        , 1.        , 1.        , 1.        ]),
#   'thresholds': array([ inf, 1.  , 0.99, 0.98, 0.97, 0.95, 0.94, 0.93, 0.92, 0.91, 0.9 ,
#          0.89, 0.88, 0.87, 0.86, 0.85, 0.84, 0.83, 0.82, 0.81, 0.8 , 0.77,
#          0.76, 0.75, 0.74, 0.73, 0.72, 0.71, 0.7 , 0.69, 0.68, 0.67, 0.66,
#          0.65, 0.64, 0.63, 0.62, 0.61, 0.6 , 0.59, 0.58, 0.57, 0.56, 0.55,
#          0.54, 0.53, 0.52, 0.5 , 0.49, 0.48, 0.47, 0.46, 0.45, 0.44, 0.43,
#          0.42, 0.41, 0.4 , 0.39, 0.38, 0.37, 0.36, 0.35, 0.34, 0.33, 0.32,
#          0.31, 0.29, 0.28, 0.27, 0.26, 0.25, 0.24, 0.23, 0.22, 0.2 , 0.19,
#          0.18, 0.17, 0.16, 0.15, 0.14, 0.13, 0.12, 0.1 , 0.08, 0.07, 0.06,
#          0.05, 0.04, 0.03, 0.02, 0.01, 0.  ]),
#   'name': 'RF Regression',
#   'auc': np.float64(0.8513166666666666),
#   'model': RandomForestClassifier(random_state=42)},
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x7ff5b27ae300>}

# %% [markdown]
# # Load pickle

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Load the data
list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader = load_from_pickle(filename='pickle/RF_data2_undersampling.pkl')
# Out:
# Data loaded successfully.

# %% [markdown]
# ### Ensemble prediction using voting

# %%
import numpy as np

# --- Loop through all the FPR values to generate the ensemble ROC curve ---



results_tuple = predict_ensemble_and_evaluate(list_folds_best_models=list_folds_best_models,
    test_loader=test_loader)

ensemble_results_soft = results_tuple['soft_voting']
ensemble_results_hard = results_tuple['hard_voting']
# Out:
# Creating a single ensemble from 124 models across all folds.
# Extracting full dataset...
# Getting predictions from all models...
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
#results_lists.append(ensemble_results_soft)
results_lists.append(ensemble_results_hard)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["MaxROCFold 1", "MaxROCFold 2", "MaxROCFold 3", "MaxROCFold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Ensemble_voting_hard"],
    results_original_roc=results_original_roc, plot_name="RF_undersampling_data2"
)
# Out:
# --- Plotting all ROC curves for comparison ---
