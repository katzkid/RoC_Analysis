# %% [markdown]
# ### Imports

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        y_prob = clf_model.predict_proba(X_test)[:, 1]
        y_pred = (y_prob >= threshold).astype(int)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data2")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Undersampling

# %%
import numpy as np
from collections import Counter

# --- This block generates the list of ratios for your experiment ---
def generate_ratios(train_data):
    # 1. Get original class counts from your train_dataset

    try:
        original_labels = np.array(train_data.targets).flatten()
    except AttributeError:
        original_labels = train_data[:, -1]

    original_counts = Counter(original_labels)
    num_pos_original = original_counts.get(1, 0)  
    num_neg_original = original_counts.get(0, 0)  
    print(f"Original class counts: {num_pos_original} positives, {num_neg_original} negatives")

    # The pivot point for your function's logic
    orig_sample_ratio = num_pos_original / num_neg_original 

    # 2. Define how many steps for each regime
    N_POINTS_PER_REGIME = 50  # You can change this

    # 3. Generate ratios for Regime 1 (from near 0 up to the pivot)
    # This will test scenarios from extreme negative-class dominance up to the original balance.
    print(f"Generating ratios for Regime 1 (target ratio < {orig_sample_ratio})...")
    ratios_regime1 = np.geomspace(
        start=1/num_neg_original,                      # A small starting ratio (e.g., 1 positive for every 10 negatives)
        stop=orig_sample_ratio,         # Go up to the original ratio
        num=N_POINTS_PER_REGIME,
        endpoint=False                  # Exclude the pivot itself to avoid the 'else' block
    )

    # 4. Generate ratios for Regime 2 (from the pivot up to 3494)
    # This will test scenarios from the original balance up to extreme positive-class dominance.
    print(f"Generating ratios for Regime 2 (target ratio > {orig_sample_ratio})...")
    ratios_regime2 = np.geomspace(
        start=orig_sample_ratio, # Start just above the pivot
        stop=num_pos_original,                      # Your specified upper limit
        num=N_POINTS_PER_REGIME
    )

    # 5. Combine, sort, and create the final list for the loop
    #    We also add the original ratio to ensure we have a baseline run.
    all_ratios = sorted(list(np.concatenate([ratios_regime1, ratios_regime2, [orig_sample_ratio]])))

    print(f"\nGenerated {len(all_ratios)} unique sample ratios to test.")
    print("First few ratios:", np.round(all_ratios[:5], 3))
    print("Last few ratios:", np.round(all_ratios[-5:], 2))

    return all_ratios

# %%
import numpy as np
def undersample_dataset(train_dataset, sample_ratio):

    
    
    # Get the labels from the dataset (0 for normal, 1 for pneumonia)
    try:
        labels = np.array(train_dataset.targets).flatten()
    except AttributeError:
        labels = train_dataset[:, -1]

    # Find the indices for the positive (pneumonia) and negative (normal) classes
    positive_indices = np.where(labels == 1)[0]
    negative_indices = np.where(labels == 0)[0]
    num_orig_positive = len(positive_indices)
    num_orig_negative = len(negative_indices)

    orig_sample_ratio = num_orig_positive / num_orig_negative
    print(f"Original sample ratio (positive:negative): {orig_sample_ratio:.2f}")

    #based on sample ratio find the number of positive or negative samples
    if sample_ratio>orig_sample_ratio:
        neg_samples = int(num_orig_positive / sample_ratio)
        pos_samples = num_orig_positive
        sampled_negative_indices = np.random.choice(negative_indices, neg_samples, replace=False)
        final_indices = np.concatenate([sampled_negative_indices, positive_indices])
    elif sample_ratio<orig_sample_ratio:
        pos_samples = int(sample_ratio * num_orig_negative)
        neg_samples = num_orig_negative
        sampled_positive_indices = np.random.choice(positive_indices, pos_samples, replace=False)
        final_indices = np.concatenate([sampled_positive_indices, negative_indices])
    else:
        pos_samples = num_orig_positive
        neg_samples = num_orig_negative
        final_indices = np.concatenate([positive_indices, negative_indices])
        
    # Shuffle the final indices to mix positive and negative samples
    np.random.shuffle(final_indices)

    # Create a subset of the original dataset with the sampled indices
    return train_dataset[final_indices]

# %% [markdown]
# ### Regular training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = LogisticRegression(fit_intercept=True)
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "Logistic Regression", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Undersampling ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds

list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    all_ratios = generate_ratios(np.c_[X_train_fold, y_train_fold])  # Combine features and labels for ratio generation
    for i, sample_ratio in enumerate(all_ratios):
        print("="*60)
        print(f"--- STARTING STAGE {i+1} FOR SAMPLE RATIO: {sample_ratio} ---")
        print("="*60)

        undersampled_train_dataset = undersample_dataset(np.c_[X_train_fold, y_train_fold], sample_ratio)
        X_train_resampled = undersampled_train_dataset[:, :-1]  # All columns except the last one
        y_train_resampled = undersampled_train_dataset[:, -1]   # Last column is the target

        clf_weighted = LogisticRegression(fit_intercept=True)
        clf_weighted.fit(X_train_resampled, y_train_resampled)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# Original class counts: 378 positives, 372 negatives
# Generating ratios for Regime 1 (target ratio < 1.0161290322580645)...
# Generating ratios for Regime 2 (target ratio > 1.0161290322580645)...
#
# Generated 101 unique sample ratios to test.
# First few ratios: [0.003 0.003 0.003 0.004 0.004]
# Last few ratios: [233.16 263.09 296.87 334.99 378.  ]
# ============================================================
# --- STARTING STAGE 1 FOR SAMPLE RATIO: 0.002688172043010753 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 2 FOR SAMPLE RATIO: 0.0030269614925120462 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 3 FOR SAMPLE RATIO: 0.003408448466300083 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 4 FOR SAMPLE RATIO: 0.003838014119493177 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 5 FOR SAMPLE RATIO: 0.004321717792441494 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 6 FOR SAMPLE RATIO: 0.004866382482191542 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 7 FOR SAMPLE RATIO: 0.00547969108589158 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 8 FOR SAMPLE RATIO: 0.006170294773722182 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 9 FOR SAMPLE RATIO: 0.006947935020032003 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 10 FOR SAMPLE RATIO: 0.007823581014017953 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 11 FOR SAMPLE RATIO: 0.008809584388228821 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 12 FOR SAMPLE RATIO: 0.00991985344745186 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 13 FOR SAMPLE RATIO: 0.011170049355609463 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 14 FOR SAMPLE RATIO: 0.012577807048026657 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 15 FOR SAMPLE RATIO: 0.014162983985199863 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 16 FOR SAMPLE RATIO: 0.0159479402569225 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 17 FOR SAMPLE RATIO: 0.017957853987842394 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 18 FOR SAMPLE RATIO: 0.020221076493479238 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 19 FOR SAMPLE RATIO: 0.02276953219643961 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 20 FOR SAMPLE RATIO: 0.025639168943942567 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 21 FOR SAMPLE RATIO: 0.02887046507871685 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 22 FOR SAMPLE RATIO: 0.03250900041587856 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 23 FOR SAMPLE RATIO: 0.03660609917983917 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 24 FOR SAMPLE RATIO: 0.04121955397034339 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 25 FOR SAMPLE RATIO: 0.04641444096971152 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 26 FOR SAMPLE RATIO: 0.05226403789038598 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 27 FOR SAMPLE RATIO: 0.05885085761110867 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 28 FOR SAMPLE RATIO: 0.06626781208193035 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 29 FOR SAMPLE RATIO: 0.0746195229157903 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 30 FOR SAMPLE RATIO: 0.0840237971535269 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 31 FOR SAMPLE RATIO: 0.09461328901907334 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 32 FOR SAMPLE RATIO: 0.10653737110512095 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 33 FOR SAMPLE RATIO: 0.11996424138370401 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 34 FOR SAMPLE RATIO: 0.13508329576264386 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 35 FOR SAMPLE RATIO: 0.1521077996545115 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 36 FOR SAMPLE RATIO: 0.17127789624255896 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 37 FOR SAMPLE RATIO: 0.1928639938774283 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 38 FOR SAMPLE RATIO: 0.2171705803863683 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 39 FOR SAMPLE RATIO: 0.24454051809860256 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 40 FOR SAMPLE RATIO: 0.27535988017135044 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 41 FOR SAMPLE RATIO: 0.31006339643644404 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 42 FOR SAMPLE RATIO: 0.3491405855852282 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 43 FOR SAMPLE RATIO: 0.39314266019072813 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 44 FOR SAMPLE RATIO: 0.4426903019675225 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 45 FOR SAMPLE RATIO: 0.49848241694509027 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 46 FOR SAMPLE RATIO: 0.5613059940528093 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 47 FOR SAMPLE RATIO: 0.6320472061792268 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 48 FOR SAMPLE RATIO: 0.7117039102942146 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 49 FOR SAMPLE RATIO: 0.8013997229574704 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 50 FOR SAMPLE RATIO: 0.9023998697587762 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 51 FOR SAMPLE RATIO: 1.0161290322580645 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 52 FOR SAMPLE RATIO: 1.0161290322580645 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 53 FOR SAMPLE RATIO: 1.1465920334306032 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 54 FOR SAMPLE RATIO: 1.293805461108644 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 55 FOR SAMPLE RATIO: 1.4599199387302084 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 56 FOR SAMPLE RATIO: 1.6473622129216217 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 57 FOR SAMPLE RATIO: 1.8588706055500561 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 58 FOR SAMPLE RATIO: 2.097535017541666 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 59 FOR SAMPLE RATIO: 2.366842068876344 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 60 FOR SAMPLE RATIO: 2.6707260342038954 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 61 FOR SAMPLE RATIO: 3.013626318193992 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 62 FOR SAMPLE RATIO: 3.400552310270444 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 63 FOR SAMPLE RATIO: 3.837156566184883 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 64 FOR SAMPLE RATIO: 4.329817385530762 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 65 FOR SAMPLE RATIO: 4.8857319915627215 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 66 FOR SAMPLE RATIO: 5.513021674574234 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 67 FOR SAMPLE RATIO: 6.2208504348605995 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 68 FOR SAMPLE RATIO: 7.019558858508205 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 69 FOR SAMPLE RATIO: 7.920815181785541 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 70 FOR SAMPLE RATIO: 8.937785751017643 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 71 FOR SAMPLE RATIO: 10.085327368172004 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 72 FOR SAMPLE RATIO: 11.38020433210969 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 73 FOR SAMPLE RATIO: 12.841333346231481 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 74 FOR SAMPLE RATIO: 14.490059870345673 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 75 FOR SAMPLE RATIO: 16.35046995394907 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 76 FOR SAMPLE RATIO: 18.449742106456437 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 77 FOR SAMPLE RATIO: 20.81854434480874 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 78 FOR SAMPLE RATIO: 23.49148221888135 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 79 FOR SAMPLE RATIO: 26.50760435984212 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 80 FOR SAMPLE RATIO: 29.910972936955055 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 81 FOR SAMPLE RATIO: 33.75130735656515 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 82 FOR SAMPLE RATIO: 38.08471060698618 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 83 FOR SAMPLE RATIO: 42.97448886037748 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 84 FOR SAMPLE RATIO: 48.492076305075926 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 85 FOR SAMPLE RATIO: 54.718078719148515 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 86 FOR SAMPLE RATIO: 61.74345103060741 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 87 FOR SAMPLE RATIO: 69.67082606712438 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 88 FOR SAMPLE RATIO: 78.61601390679093 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 89 FOR SAMPLE RATIO: 88.70969373376113 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 90 FOR SAMPLE RATIO: 100.09932291489451 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 91 FOR SAMPLE RATIO: 112.95129118687231 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 92 FOR SAMPLE RATIO: 127.4533514240512 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 93 FOR SAMPLE RATIO: 143.81736249785047 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 94 FOR SAMPLE RATIO: 162.28238429778207 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 95 FOR SAMPLE RATIO: 183.11817012891345 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 96 FOR SAMPLE RATIO: 206.6291075057862 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 97 FOR SAMPLE RATIO: 233.1586649133749 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 98 FOR SAMPLE RATIO: 263.09440949729304 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 99 FOR SAMPLE RATIO: 296.8736689860784 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 100 FOR SAMPLE RATIO: 334.9899205599143 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# ============================================================
# --- STARTING STAGE 101 FOR SAMPLE RATIO: 378.0 ---
# ============================================================
# Original sample ratio (positive:negative): 1.02
# --- Starting Fold 2/4 ---
# Original class counts: 368 positives, 382 negatives
# Generating ratios for Regime 1 (target ratio < 0.9633507853403142)...
# Generating ratios for Regime 2 (target ratio > 0.9633507853403142)...
#
# Generated 101 unique sample ratios to test.
# First few ratios: [0.003 0.003 0.003 0.004 0.004]
# Last few ratios: [226.5  255.72 288.71 325.95 368.  ]
# ============================================================
# --- STARTING STAGE 1 FOR SAMPLE RATIO: 0.002617801047120419 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 2 FOR SAMPLE RATIO: 0.002946141444091603 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 3 FOR SAMPLE RATIO: 0.0033156642740829654 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 4 FOR SAMPLE RATIO: 0.003731534886241636 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 5 FOR SAMPLE RATIO: 0.004199566498960306 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 6 FOR SAMPLE RATIO: 0.004726301459545754 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 7 FOR SAMPLE RATIO: 0.005319102695965057 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 8 FOR SAMPLE RATIO: 0.005986256639021499 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 9 FOR SAMPLE RATIO: 0.006737089053650478 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 10 FOR SAMPLE RATIO: 0.007582095398475303 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 11 FOR SAMPLE RATIO: 0.008533087535844648 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 12 FOR SAMPLE RATIO: 0.009603358843127926 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 13 FOR SAMPLE RATIO: 0.010807870033265098 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 14 FOR SAMPLE RATIO: 0.012163458282050753 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 15 FOR SAMPLE RATIO: 0.013689072585423474 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 16 FOR SAMPLE RATIO: 0.015406038636686006 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 17 FOR SAMPLE RATIO: 0.017338356926224156 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 18 FOR SAMPLE RATIO: 0.019513038230690227 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 19 FOR SAMPLE RATIO: 0.02196048118126371 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 20 FOR SAMPLE RATIO: 0.024714897188800225 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 21 FOR SAMPLE RATIO: 0.027814788665655982 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 22 FOR SAMPLE RATIO: 0.03130348722897769 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 23 FOR SAMPLE RATIO: 0.035229759408695445 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 24 FOR SAMPLE RATIO: 0.03964848832706548 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 25 FOR SAMPLE RATIO: 0.0446214408785728 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 26 FOR SAMPLE RATIO: 0.05021813113416458 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 27 FOR SAMPLE RATIO: 0.05651679203885024 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 28 FOR SAMPLE RATIO: 0.0636054689854755 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 29 FOR SAMPLE RATIO: 0.07158325055111513 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 30 FOR SAMPLE RATIO: 0.08056165359984753 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 31 FOR SAMPLE RATIO: 0.09066618211347377 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 32 FOR SAMPLE RATIO: 0.10203808154018763 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 33 FOR SAMPLE RATIO: 0.11483631318423743 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 34 FOR SAMPLE RATIO: 0.12923977623544813 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 35 FOR SAMPLE RATIO: 0.1454498084990887 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 36 FOR SAMPLE RATIO: 0.16369300078236254 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 37 FOR SAMPLE RATIO: 0.1842243642782275 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 38 FOR SAMPLE RATIO: 0.2073308952215986 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 39 FOR SAMPLE RATIO: 0.23333558664623283 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 40 FOR SAMPLE RATIO: 0.26260194332035924 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 41 FOR SAMPLE RATIO: 0.29553906297277 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 42 FOR SAMPLE RATIO: 0.3326073548369327 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 43 FOR SAMPLE RATIO: 0.37432497544940196 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 44 FOR SAMPLE RATIO: 0.42127507166488115 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 45 FOR SAMPLE RATIO: 0.4741139321339241 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 46 FOR SAMPLE RATIO: 0.5335801611881374 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 47 FOR SAMPLE RATIO: 0.6005050033693933 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 48 FOR SAMPLE RATIO: 0.6758239629237783 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 49 FOR SAMPLE RATIO: 0.7605898806825481 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 50 FOR SAMPLE RATIO: 0.8559876511243775 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 51 FOR SAMPLE RATIO: 0.9633507853403142 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 52 FOR SAMPLE RATIO: 0.9633507853403142 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 53 FOR SAMPLE RATIO: 1.0876261138587189 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 54 FOR SAMPLE RATIO: 1.2279333567258532 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 55 FOR SAMPLE RATIO: 1.3863406821030828 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 56 FOR SAMPLE RATIO: 1.565183058450892 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 57 FOR SAMPLE RATIO: 1.7670966726197035 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 58 FOR SAMPLE RATIO: 1.9950577879843578 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 59 FOR SAMPLE RATIO: 2.2524266154020585 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 60 FOR SAMPLE RATIO: 2.542996843664035 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 61 FOR SAMPLE RATIO: 2.8710515595336776 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 62 FOR SAMPLE RATIO: 3.2414263816482225 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 63 FOR SAMPLE RATIO: 3.6595807388954142 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 64 FOR SAMPLE RATIO: 4.131678343928448 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 65 FOR SAMPLE RATIO: 4.664678048021385 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 66 FOR SAMPLE RATIO: 5.266436416491144 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 67 FOR SAMPLE RATIO: 5.945823536676572 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 68 FOR SAMPLE RATIO: 6.712853765516748 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 69 FOR SAMPLE RATIO: 7.57883334398452 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 70 FOR SAMPLE RATIO: 8.55652705425351 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 71 FOR SAMPLE RATIO: 9.660346376171983 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 72 FOR SAMPLE RATIO: 10.90656191652289 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 73 FOR SAMPLE RATIO: 12.313543242337028 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 74 FOR SAMPLE RATIO: 13.902029653469633 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 75 FOR SAMPLE RATIO: 15.695435885704368 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 76 FOR SAMPLE RATIO: 17.720197250534124 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 77 FOR SAMPLE RATIO: 20.00615929907609 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 78 FOR SAMPLE RATIO: 22.58701775387656 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 79 FOR SAMPLE RATIO: 25.500815193323742 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 80 FOR SAMPLE RATIO: 28.79050180993652 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 81 FOR SAMPLE RATIO: 32.50456850826347 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 82 FOR SAMPLE RATIO: 36.6977616744334 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 83 FOR SAMPLE RATIO: 41.4318901532608 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 84 FOR SAMPLE RATIO: 46.77673632797589 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 85 FOR SAMPLE RATIO: 52.8110847321498 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 86 FOR SAMPLE RATIO: 59.62388335584399 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 87 FOR SAMPLE RATIO: 67.31555476396245 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 88 FOR SAMPLE RATIO: 75.99947635305922 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 89 FOR SAMPLE RATIO: 85.80365156600273 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 90 FOR SAMPLE RATIO: 96.87259669866988 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 91 FOR SAMPLE RATIO: 109.36947111073067 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 92 FOR SAMPLE RATIO: 123.47848224042907 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 93 FOR SAMPLE RATIO: 139.40760087395208 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 94 FOR SAMPLE RATIO: 157.3916266932208 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 95 FOR SAMPLE RATIO: 177.6956492891398 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 96 FOR SAMPLE RATIO: 200.61895565660998 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 97 FOR SAMPLE RATIO: 226.49944176888022 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 98 FOR SAMPLE RATIO: 255.71859325908127 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 99 FOR SAMPLE RATIO: 288.70710862558934 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 100 FOR SAMPLE RATIO: 325.9512478488416 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# ============================================================
# --- STARTING STAGE 101 FOR SAMPLE RATIO: 368.0 ---
# ============================================================
# Original sample ratio (positive:negative): 0.96
# --- Starting Fold 3/4 ---
# Original class counts: 370 positives, 380 negatives
# Generating ratios for Regime 1 (target ratio < 0.9736842105263158)...
# ...
# --- STARTING STAGE 33 FOR SAMPLE RATIO: 0.12316601727419409 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 34 FOR SAMPLE RATIO: 0.13873227965728602 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 35 FOR SAMPLE RATIO: 0.15626587466947348 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 36 FOR SAMPLE RATIO: 0.176015442451739 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 37 FOR SAMPLE RATIO: 0.19826104737846303 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 38 FOR SAMPLE RATIO: 0.2233181495901004 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 39 FOR SAMPLE RATIO: 0.25154207846560545 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 40 FOR SAMPLE RATIO: 0.2833330714719555 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 41 FOR SAMPLE RATIO: 0.3191419498456163 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 42 FOR SAMPLE RATIO: 0.3594765115915641 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 43 FOR SAMPLE RATIO: 0.40490873245761355 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 44 FOR SAMPLE RATIO: 0.4560828769995184 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 45 FOR SAMPLE RATIO: 0.513724634758113 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 46 FOR SAMPLE RATIO: 0.5786514111066602 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 47 FOR SAMPLE RATIO: 0.6517839187007 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 48 FOR SAMPLE RATIO: 0.7341592339062578 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 49 FOR SAMPLE RATIO: 0.826945503356809 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 50 FOR SAMPLE RATIO: 0.9314585091895246 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 51 FOR SAMPLE RATIO: 1.0491803278688525 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 52 FOR SAMPLE RATIO: 1.0491803278688525 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 53 FOR SAMPLE RATIO: 1.183494051717618 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 54 FOR SAMPLE RATIO: 1.3350023187110938 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 55 FOR SAMPLE RATIO: 1.505906335885191 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 56 FOR SAMPLE RATIO: 1.6986891038875593 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 57 FOR SAMPLE RATIO: 1.9161514915668107 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 58 FOR SAMPLE RATIO: 2.1614529287501383 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 59 FOR SAMPLE RATIO: 2.438157308419503 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 60 FOR SAMPLE RATIO: 2.7502847651819606 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 61 FOR SAMPLE RATIO: 3.1023700823041964 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 62 FOR SAMPLE RATIO: 3.499528575885258 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 63 FOR SAMPLE RATIO: 3.947530413374028 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 64 FOR SAMPLE RATIO: 4.452884446177431 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 65 FOR SAMPLE RATIO: 5.022932774332035 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 66 FOR SAMPLE RATIO: 5.6659574171338365 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 67 FOR SAMPLE RATIO: 6.391300639504 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 68 FOR SAMPLE RATIO: 7.209500682267367 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 69 FOR SAMPLE RATIO: 8.132444868318277 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 70 FOR SAMPLE RATIO: 9.173542309096016 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 71 FOR SAMPLE RATIO: 10.34791872055777 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 72 FOR SAMPLE RATIO: 11.672636179057617 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 73 FOR SAMPLE RATIO: 13.166941009882681 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 74 FOR SAMPLE RATIO: 14.852543409926378 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 75 FOR SAMPLE RATIO: 16.75393286703219 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 76 FOR SAMPLE RATIO: 18.898733958617846 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 77 FOR SAMPLE RATIO: 21.31810769884525 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 78 FOR SAMPLE RATIO: 24.047204265359277 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 79 FOR SAMPLE RATIO: 27.12567368309321 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 80 FOR SAMPLE RATIO: 30.598241884675158 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 81 FOR SAMPLE RATIO: 34.51536051680195 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 82 FOR SAMPLE RATIO: 38.93393993337467 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 83 FOR SAMPLE RATIO: 43.918176024779335 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 84 FOR SAMPLE RATIO: 49.540482896006736 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 85 FOR SAMPLE RATIO: 55.88254494414349 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 86 FOR SAMPLE RATIO: 63.0365036204752 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 87 FOR SAMPLE RATIO: 71.10629611922529 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 88 FOR SAMPLE RATIO: 80.20916544223833 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 89 FOR SAMPLE RATIO: 90.47736377877382 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 90 FOR SAMPLE RATIO: 102.06007394817912 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 91 FOR SAMPLE RATIO: 115.12557682136482 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 92 FOR SAMPLE RATIO: 129.86369621073968 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 93 FOR SAMPLE RATIO: 146.48855674949874 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 94 FOR SAMPLE RATIO: 165.24169482846182 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 95 FOR SAMPLE RATIO: 186.39556778810277 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 96 FOR SAMPLE RATIO: 210.25751234950943 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 97 FOR SAMPLE RATIO: 237.1742097948416 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 98 FOR SAMPLE RATIO: 267.5367227702237 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 99 FOR SAMPLE RATIO: 301.7861768889014 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 100 FOR SAMPLE RATIO: 340.4201696805555 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05
# ============================================================
# --- STARTING STAGE 101 FOR SAMPLE RATIO: 384.0 ---
# ============================================================
# Original sample ratio (positive:negative): 1.05

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Save the data
save_to_pickle(list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader, filename='pickle/Logistic_data2_undersampling.pkl')
# Out:
# Data saved to pickle/Logistic_data2_undersampling.pkl
# {'best_models': [[{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.48360655737704916),
#     'threshold': np.float64(0.18216006009309774)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0078125),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.009420980321755043)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.015625),
#     'tpr': np.float64(0.5081967213114754),
#     'threshold': np.float64(0.008529631739399631)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.03125),
#     'tpr': np.float64(0.5163934426229508),
#     'threshold': np.float64(0.008180603319242525)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0390625),
#     'tpr': np.float64(0.5245901639344263),
#     'threshold': np.float64(0.04446282291315181)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0546875),
#     'tpr': np.float64(0.5409836065573771),
#     'threshold': np.float64(0.14642571992273984)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0703125),
#     'tpr': np.float64(0.5491803278688525),
#     'threshold': np.float64(0.03909350164454051)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0859375),
#     'tpr': np.float64(0.5573770491803278),
#     'threshold': np.float64(0.03818693325214822)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1015625),
#     'tpr': np.float64(0.5655737704918032),
#     'threshold': np.float64(0.10757544227712702)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.12333333333333334),
#     'tpr': np.float64(0.5733333333333334),
#     'threshold': np.float64(0.6128107468526331)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.13333333333333333),
#     'tpr': np.float64(0.5966666666666667),
#     'threshold': np.float64(0.5921121500909501)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.14),
#     'tpr': np.float64(0.6066666666666667),
#     'threshold': np.float64(0.5893643085997512)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15),
#     'tpr': np.float64(0.6166666666666667),
#     'threshold': np.float64(0.5737868356967218)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.6633333333333333),
#     'threshold': np.float64(0.5425752171226073)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.19333333333333333),
#     'tpr': np.float64(0.6666666666666666),
#     'threshold': np.float64(0.5386871765592103)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1953125),
#     'tpr': np.float64(0.6721311475409836),
#     'threshold': np.float64(0.009243269036733321)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.2),
#     'tpr': np.float64(0.6733333333333333),
#     'threshold': np.float64(0.529011807242643)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.203125),
#     'tpr': np.float64(0.7131147540983607),
#     'threshold': np.float64(0.008131130289575675)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2109375),
#     'tpr': np.float64(0.7213114754098361),
#     'threshold': np.float64(0.007995191937027944)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.21875),
#     'tpr': np.float64(0.7459016393442623),
#     'threshold': np.float64(0.6833007035061978)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.234375),
#     'tpr': np.float64(0.7540983606557377),
#     'threshold': np.float64(0.7906744077747309)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.25),
#     'tpr': np.float64(0.7868852459016393),
#     'threshold': np.float64(0.7403159289861548)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2734375),
#     'tpr': np.float64(0.7950819672131147),
#     'threshold': np.float64(0.873292846974268)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.28125),
#     'tpr': np.float64(0.819672131147541),
#     'threshold': np.float64(0.8679001254054112)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3125),
#     'tpr': np.float64(0.8278688524590164),
#     'threshold': np.float64(0.9710980738821516)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3203125),
#     'tpr': np.float64(0.8360655737704918),
#     'threshold': np.float64(0.003443811263610038)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.328125),
#     'tpr': np.float64(0.8524590163934426),
#     'threshold': np.float64(0.7814478338119517)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3359375),
#     'tpr': np.float64(0.8688524590163934),
#     'threshold': np.float64(0.003242824563281229)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.34375),
#     'tpr': np.float64(0.8770491803278688),
#     'threshold': np.float64(0.8374371324540666)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3515625),
#     'tpr': np.float64(0.8852459016393442),
#     'threshold': np.float64(0.8598420891205726)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.359375),
#     'tpr': np.float64(0.9016393442622951),
#     'threshold': np.float64(0.745824317168269)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3984375),
#     'tpr': np.float64(0.9098360655737705),
#     'threshold': np.float64(0.7632524732126419)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4140625),
#     'tpr': np.float64(0.9426229508196722),
#     'threshold': np.float64(0.8371719474574106)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.421875),
#     'tpr': np.float64(0.9590163934426229),
#     'threshold': np.float64(0.8870164204125396)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4296875),
#     'tpr': np.float64(0.9672131147540983),
#     'threshold': np.float64(0.8818192805746679)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4453125),
#     'tpr': np.float64(0.9754098360655737),
#     'threshold': np.float64(0.866450155291389)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.453125),
#     'tpr': np.float64(0.9836065573770492),
#     'threshold': np.float64(0.856772876803732)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4765625),
#     'tpr': np.float64(0.9918032786885246),
#     'threshold': np.float64(0.002319365198435785)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5546875),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.001969758768747799)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.44696969696969696),
#     'threshold': np.float64(0.04392481761873005)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.00847457627118644),
#     'tpr': np.float64(0.4772727272727273),
#     'threshold': np.float64(0.024140204695835707)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.03389830508474576),
#     'tpr': np.float64(0.5227272727272727),
#     'threshold': np.float64(0.0055505036004045655)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.05084745762711865),
#     'tpr': np.float64(0.5378787878787878),
#     'threshold': np.float64(0.14865331174076693)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.059322033898305086),
#     'tpr': np.float64(0.5454545454545454),
#     'threshold': np.float64(0.01878741049249374)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.07627118644067797),
#     'tpr': np.float64(0.553030303030303),
#     'threshold': np.float64(0.050270885958012705)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0847457627118644),
#     'tpr': np.float64(0.5606060606060606),
#     'threshold': np.float64(0.037576689696815074)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1016949152542373),
#     'tpr': np.float64(0.5681818181818182),
#     'threshold': np.float64(0.009642910472818554)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.11016949152542373),
#     'tpr': np.float64(0.5757575757575758),
#     'threshold': np.float64(0.009477135781226442)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.11864406779661017),
#     'tpr': np.float64(0.5909090909090909),
#     'threshold': np.float64(0.21334455646488476)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1271186440677966),
#     'tpr': np.float64(0.5984848484848485),
#     'threshold': np.float64(0.028376844336755365)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.13559322033898305),
#     'tpr': np.float64(0.6060606060606061),
#     'threshold': np.float64(0.02741158960881769)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.14),
#     'tpr': np.float64(0.6066666666666667),
#     'threshold': np.float64(0.5893643085997512)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1440677966101695),
#     'tpr': np.float64(0.6287878787878788),
#     'threshold': np.float64(0.1862966043555425)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.6633333333333333),
#     'threshold': np.float64(0.5425752171226073)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1864406779661017),
#     'tpr': np.float64(0.6818181818181818),
#     'threshold': np.float64(0.23595984693724137)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2033898305084746),
#     'tpr': np.float64(0.6893939393939394),
#     'threshold': np.float64(0.007140944898467031)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21),
#     'tpr': np.float64(0.7),
#     'threshold': np.float64(0.5138248258215651)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.211864406779661),
#     'tpr': np.float64(0.7045454545454546),
#     'threshold': np.float64(0.011874683520636071)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.22033898305084745),
#     'tpr': np.float64(0.7121212121212122),
#     'threshold': np.float64(0.019979729252580847)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2457627118644068),
#     'tpr': np.float64(0.7651515151515151),
#     'threshold': np.float64(0.3252710161879182)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2542372881355932),
#     'tpr': np.float64(0.7803030303030303),
#     'threshold': np.float64(0.319997822172232)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2711864406779661),
#     'tpr': np.float64(0.803030303030303),
#     'threshold': np.float64(0.4878791250105894)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2796610169491525),
#     'tpr': np.float64(0.8181818181818182),
#     'threshold': np.float64(0.3861710259846812)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.288135593220339),
#     'tpr': np.float64(0.8333333333333334),
#     'threshold': np.float64(0.37640800741817587)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3050847457627119),
#     'tpr': np.float64(0.8409090909090909),
#     'threshold': np.float64(0.865384885418794)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3135593220338983),
#     'tpr': np.float64(0.8560606060606061),
#     'threshold': np.float64(0.006250617648111685)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3220338983050847),
#     'tpr': np.float64(0.8712121212121212),
#     'threshold': np.float64(0.020123949242620877)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3305084745762712),
#     'tpr': np.float64(0.8787878787878788),
#     'threshold': np.float64(0.6787436872200828)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3983050847457627),
#     'tpr': np.float64(0.8863636363636364),
#     'threshold': np.float64(0.25436120055096245)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4152542372881356),
#     'tpr': np.float64(0.9090909090909091),
#     'threshold': np.float64(0.8015570973653687)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.423728813559322),
#     'tpr': np.float64(0.9166666666666666),
#     'threshold': np.float64(0.3242223538724934)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4322033898305085),
#     'tpr': np.float64(0.9242424242424242),
#     'threshold': np.float64(0.252674655544108)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4406779661016949),
#     'tpr': np.float64(0.9318181818181818),
#     'threshold': np.float64(0.013734033691033095)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4491525423728814),
#     'tpr': np.float64(0.9393939393939394),
#     'threshold': np.float64(0.0048041069457555015)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4661016949152542),
#     'tpr': np.float64(0.946969696969697),
#     'threshold': np.float64(0.004543091745790305)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4745762711864407),
#     'tpr': np.float64(0.9545454545454546),
#     'threshold': np.float64(0.1522863060368768)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4830508474576271),
#     'tpr': np.float64(0.9621212121212122),
#     'threshold': np.float64(0.18426340252358403)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5084745762711864),
#     'tpr': np.float64(0.9696969696969697),
#     'threshold': np.float64(0.2748332253545627)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5254237288135594),
#     'tpr': np.float64(0.9772727272727273),
#     'threshold': np.float64(0.8091276664484995)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5338983050847458),
#     'tpr': np.float64(0.9848484848484849),
#     'threshold': np.float64(0.9207323985711001)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5423728813559322),
#     'tpr': np.float64(0.9924242424242424),
#     'threshold': np.float64(0.9896726470602556)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.635593220338983),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.8113942687268291)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.3076923076923077),
#     'threshold': np.float64(0.9989271120508594)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.008333333333333333),
#     'tpr': np.float64(0.5230769230769231),
#     'threshold': np.float64(0.9974078070789663)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.016666666666666666),
#     'tpr': np.float64(0.5769230769230769),
#     'threshold': np.float64(0.9982596813143533)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.03333333333333333),
#     'tpr': np.float64(0.5846153846153846),
#     'threshold': np.float64(0.9980136146720169)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.041666666666666664),
#     'tpr': np.float64(0.5923076923076923),
#     'threshold': np.float64(0.007211268708025966)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.05),
#     'tpr': np.float64(0.6),
#     'threshold': np.float64(0.029212015826640254)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.06666666666666667),
#     'tpr': np.float64(0.6076923076923076),
#     'threshold': np.float64(0.005571186987057783)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.075),
#     'tpr': np.float64(0.6230769230769231),
#     'threshold': np.float64(0.005045230625569695)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.08333333333333333),
#     'tpr': np.float64(0.6384615384615384),
#     'threshold': np.float64(0.18277469408200672)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.11666666666666667),
#     'tpr': np.float64(0.6615384615384615),
#     'threshold': np.float64(0.020124610364778004)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.125),
#     'tpr': np.float64(0.6692307692307692),
#     'threshold': np.float64(0.01977737323017261)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.13333333333333333),
#     'tpr': np.float64(0.676923076923077),
#     'threshold': np.float64(0.009346179756322725)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.15),
#     'tpr': np.float64(0.6846153846153846),
#     'threshold': np.float64(0.009052659074291161)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.15833333333333333),
#     'tpr': np.float64(0.7153846153846154),
#     'threshold': np.float64(0.08113142817437526)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.7230769230769231),
#     'threshold': np.float64(0.014584290141630684)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.19166666666666668),
#     'tpr': np.float64(0.7384615384615385),
#     'threshold': np.float64(0.0178296754151602)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.20833333333333334),
#     'tpr': np.float64(0.7538461538461538),
#     'threshold': np.float64(0.20741633079528315)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.25),
#     'tpr': np.float64(0.7692307692307693),
#     'threshold': np.float64(0.5602884387856648)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.26666666666666666),
#     'tpr': np.float64(0.7923076923076923),
#     'threshold': np.float64(0.006480409867025872)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.275),
#     'tpr': np.float64(0.8),
#     'threshold': np.float64(0.006282772839268557)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2833333333333333),
#     'tpr': np.float64(0.8076923076923077),
#     'threshold': np.float64(0.07171063908125352)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2916666666666667),
#     'tpr': np.float64(0.8153846153846154),
#     'threshold': np.float64(0.00956730290076758)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3),
#     'tpr': np.float64(0.8307692307692308),
#     'threshold': np.float64(0.27997110218583077)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.30833333333333335),
#     'tpr': np.float64(0.8384615384615385),
#     'threshold': np.float64(0.009615475517639853)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.325),
#     'tpr': np.float64(0.8461538461538461),
#     'threshold': np.float64(0.05538534223335994)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3416666666666667),
#     'tpr': np.float64(0.8538461538461538),
#     'threshold': np.float64(0.4453192174849507)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.38333333333333336),
#     'tpr': np.float64(0.8769230769230769),
#     'threshold': np.float64(0.7458804569944972)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.39166666666666666),
#     'tpr': np.float64(0.8923076923076924),
#     'threshold': np.float64(0.7364526939568702)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4),
#     'tpr': np.float64(0.9230769230769231),
#     'threshold': np.float64(0.8142576407530283)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4083333333333333),
#     'tpr': np.float64(0.9384615384615385),
#     'threshold': np.float64(0.9132188669200525)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.44166666666666665),
#     'tpr': np.float64(0.9461538461538461),
#     'threshold': np.float64(0.8543055963599278)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.45),
#     'tpr': np.float64(0.9846153846153847),
#     'threshold': np.float64(0.9098107259991867)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.475),
#     'tpr': np.float64(0.9923076923076923),
#     'threshold': np.float64(0.002278034567979236)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.9524982923089717)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.4827586206896552),
#     'threshold': np.float64(0.02479715660444345)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.014925373134328358),
#     'tpr': np.float64(0.49137931034482757),
#     'threshold': np.float64(0.01948246275794631)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.022388059701492536),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.0431961518211224)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.029850746268656716),
#     'tpr': np.float64(0.5603448275862069),
#     'threshold': np.float64(0.0956659478958015)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.04477611940298507),
#     'tpr': np.float64(0.5862068965517241),
#     'threshold': np.float64(0.08379218219289947)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.05970149253731343),
#     'tpr': np.float64(0.603448275862069),
#     'threshold': np.float64(0.2891159992864908)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.06716417910447761),
#     'tpr': np.float64(0.6120689655172413),
#     'threshold': np.float64(0.2855247980939426)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.08955223880597014),
#     'tpr': np.float64(0.6206896551724138),
#     'threshold': np.float64(0.09245973677171011)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.09701492537313433),
#     'tpr': np.float64(0.6293103448275862),
#     'threshold': np.float64(0.4256678532925484)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.12686567164179105),
#     'tpr': np.float64(0.6379310344827587),
#     'threshold': np.float64(0.03329633082043944)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1417910447761194),
#     'tpr': np.float64(0.646551724137931),
#     'threshold': np.float64(0.14402173827918582)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.15666666666666668),
#     'tpr': np.float64(0.6466666666666666),
#     'threshold': np.float64(0.5625030709923139)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.15671641791044777),
#     'tpr': np.float64(0.6551724137931034),
#     'threshold': np.float64(0.5719288198432017)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.16333333333333333),
#     'tpr': np.float64(0.6566666666666666),
#     'threshold': np.float64(0.5538180962294253)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.17333333333333334),
#     'tpr': np.float64(0.66),
#     'threshold': np.float64(0.5447287696813431)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.1791044776119403),
#     'tpr': np.float64(0.6724137931034483),
#     'threshold': np.float64(0.6918291023656902)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.2),
#     'tpr': np.float64(0.6733333333333333),
#     'threshold': np.float64(0.529011807242643)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.20149253731343283),
#     'tpr': np.float64(0.6896551724137931),
#     'threshold': np.float64(0.6148047295956303)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21),
#     'tpr': np.float64(0.7),
#     'threshold': np.float64(0.5138248258215651)},
#    {'model': 'original_baseline',
#     'fpr': np.float64(0.21333333333333335),
#     'tpr': np.float64(0.7033333333333334),
#     'threshold': np.float64(0.5052511534785067)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.22388059701492538),
#     'tpr': np.float64(0.7068965517241379),
#     'threshold': np.float64(0.5835000309533316)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.23134328358208955),
#     'tpr': np.float64(0.7155172413793104),
#     'threshold': np.float64(0.007218668261255794)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.23880597014925373),
#     'tpr': np.float64(0.7241379310344828),
#     'threshold': np.float64(0.007152307561436146)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2462686567164179),
#     'tpr': np.float64(0.7413793103448276),
#     'threshold': np.float64(0.007092095608895518)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.2537313432835821),
#     'tpr': np.float64(0.7586206896551724),
#     'threshold': np.float64(0.40830316900595565)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.26119402985074625),
#     'tpr': np.float64(0.7758620689655172),
#     'threshold': np.float64(0.5140688236209858)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.26865671641791045),
#     'tpr': np.float64(0.7844827586206896),
#     'threshold': np.float64(0.6902096521400392)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.291044776119403),
#     'tpr': np.float64(0.7931034482758621),
#     'threshold': np.float64(0.006573328834476943)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.29850746268656714),
#     'tpr': np.float64(0.8275862068965517),
#     'threshold': np.float64(0.9566160575782934)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.30597014925373134),
#     'tpr': np.float64(0.8448275862068966),
#     'threshold': np.float64(0.8796085470308671)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.31343283582089554),
#     'tpr': np.float64(0.853448275862069),
#     'threshold': np.float64(0.9101332395749707)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3208955223880597),
#     'tpr': np.float64(0.8793103448275862),
#     'threshold': np.float64(0.8717841729254482)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3283582089552239),
#     'tpr': np.float64(0.9051724137931034),
#     'threshold': np.float64(0.7542035761515926)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.34328358208955223),
#     'tpr': np.float64(0.9137931034482759),
#     'threshold': np.float64(0.907120465140935)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3582089552238806),
#     'tpr': np.float64(0.9224137931034483),
#     'threshold': np.float64(0.8313202088817938)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.3880597014925373),
#     'tpr': np.float64(0.9310344827586207),
#     'threshold': np.float64(0.3529539530692136)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.40298507462686567),
#     'tpr': np.float64(0.9396551724137931),
#     'threshold': np.float64(0.9390936575277194)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4253731343283582),
#     'tpr': np.float64(0.9482758620689655),
#     'threshold': np.float64(0.0027732953578399793)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.44029850746268656),
#     'tpr': np.float64(0.9568965517241379),
#     'threshold': np.float64(0.7914036144813992)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.44776119402985076),
#     'tpr': np.float64(0.9655172413793104),
#     'threshold': np.float64(0.002685308250616403)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4552238805970149),
#     'tpr': np.float64(0.9741379310344828),
#     'threshold': np.float64(0.00266882152995995)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.4701492537313433),
#     'tpr': np.float64(0.9827586206896551),
#     'threshold': np.float64(0.939989602597973)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.48507462686567165),
#     'tpr': np.float64(0.9913793103448276),
#     'threshold': np.float64(0.9430988774218482)},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.5074626865671642),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.010447488060923231)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}]],
#  'weighted_clfs': [[{'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.0),
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.       , 0.       , 0.       , 0.0078125, 0.0078125, 0.015625 ,
#             0.015625 , 0.0234375, 0.0234375, 0.03125  , 0.03125  , 0.0390625,
#             0.0390625, 0.046875 , 0.046875 , 0.0546875, 0.0546875, 0.0703125,
#             0.0703125, 0.078125 , 0.078125 , 0.1015625, 0.1015625, 0.171875 ,
#             0.171875 , 0.2421875, 0.2421875, 0.2578125, 0.2578125, 0.265625 ,
#             0.265625 , 0.3125   , 0.3125   , 0.359375 , 0.359375 , 0.3828125,
#             0.3828125, 0.390625 , 0.390625 , 0.421875 , 0.421875 , 0.4296875,
#             0.4296875, 0.4609375, 0.4609375, 0.4765625, 0.4765625, 0.484375 ,
#             0.484375 , 0.5      , 0.5      , 0.515625 , 0.515625 , 0.546875 ,
#             0.546875 , 0.5546875, 0.5546875, 0.5625   , 0.5625   , 0.578125 ,
#             0.578125 , 0.6171875, 0.6171875, 0.65625  , 0.65625  , 0.6796875,
#             0.6796875, 0.6953125, 0.6953125, 0.7109375, 0.7109375, 0.71875  ,
#             0.71875  , 0.734375 , 0.734375 , 0.7578125, 0.7578125, 0.765625 ,
#             0.765625 , 0.7734375, 0.7734375, 0.78125  , 0.78125  , 0.796875 ,
#             0.796875 , 0.8046875, 0.8046875, 0.8203125, 0.8203125, 0.875    ,
#             0.875    , 0.8828125, 0.8828125, 0.90625  , 0.90625  , 0.9609375,
#             0.9609375, 0.9765625, 0.9765625, 0.984375 , 0.984375 , 1.       ]),
#      'tpr': array([0.        , 0.00819672, 0.39344262, 0.39344262, 0.44262295,
#             0.44262295, 0.45081967, 0.45081967, 0.45901639, 0.45901639,
#             0.47540984, 0.47540984, 0.48360656, 0.48360656, 0.49180328,
#             0.49180328, 0.50819672, 0.50819672, 0.51639344, 0.51639344,
#             0.52459016, 0.52459016, 0.54098361, 0.54098361, 0.57377049,
#             0.57377049, 0.59016393, 0.59016393, 0.59836066, 0.59836066,
#             0.62295082, 0.62295082, 0.63114754, 0.63114754, 0.63934426,
#             0.63934426, 0.64754098, 0.64754098, 0.6557377 , 0.6557377 ,
#             0.66393443, 0.66393443, 0.67213115, 0.67213115, 0.68032787,
#             0.68032787, 0.69672131, 0.69672131, 0.71311475, 0.71311475,
#             0.72131148, 0.72131148, 0.7295082 , 0.7295082 , 0.73770492,
#             0.73770492, 0.74590164, 0.74590164, 0.75409836, 0.75409836,
#             0.76229508, 0.76229508, 0.7704918 , 0.7704918 , 0.77868852,
#             0.77868852, 0.79508197, 0.79508197, 0.80327869, 0.80327869,
#             0.81147541, 0.81147541, 0.81967213, 0.81967213, 0.82786885,
#             0.82786885, 0.83606557, 0.83606557, 0.8442623 , 0.8442623 ,
#             0.85245902, 0.85245902, 0.87704918, 0.87704918, 0.90983607,
#             0.90983607, 0.91803279, 0.91803279, 0.92622951, 0.92622951,
#             0.94262295, 0.94262295, 0.95081967, 0.95081967, 0.95901639,
#             0.95901639, 0.96721311, 0.96721311, 0.98360656, 0.98360656,
#             1.        , 1.        ]),
#      'thresholds': array([       inf, 0.08497336, 0.01293388, 0.0125902 , 0.01061731,
#             0.01035885, 0.01028497, 0.00967863, 0.00948737, 0.00812632,
#             0.00790859, 0.00785996, 0.00758787, 0.00746454, 0.0073884 ,
#             0.00718984, 0.00681585, 0.00591288, 0.00573522, 0.0057016 ,
#             0.00561709, 0.00512441, 0.00502882, 0.00440533, 0.00425556,
#             0.00347009, 0.00334246, 0.00331959, 0.00328776, 0.00323342,
#             0.00315651, 0.00306164, 0.00299976, 0.00284911, 0.00283978,
#             0.00280952, 0.00279108, 0.00278409, 0.00275985, 0.002663  ,
#             0.00262977, 0.00260576, 0.00259306, 0.00251348, 0.00250446,
#             0.00246824, 0.00243783, 0.00242887, 0.00238648, 0.00234542,
#             0.00234363, 0.00231767, 0.00231586, 0.00220542, 0.00220083,
#             0.0021974 , 0.00217498, 0.0021218 , 0.00211045, 0.00207947,
#             0.00206537, 0.0020163 , 0.00200873, 0.00184474, 0.00182256,
#             0.00179823, 0.00174713, 0.00173423, 0.00171966, 0.0016742 ,
#             0.00166554, 0.00151955, 0.00151773, 0.00150997, 0.00149749,
#             0.00148265, 0.00143891, 0.00142796, 0.00142152, 0.00141739,
#             0.00138201, 0.00136955, 0.00134335, 0.00128756, 0.00120531,
#             0.00120479, 0.00119392, 0.00118582, 0.00117251, 0.00110897,
#             0.0011014 , 0.00109552, 0.00108416, 0.00095771, 0.00094298,
#             0.00086501, 0.00085525, 0.00083915, 0.00070406, 0.00065033,
#             0.00064495, 0.0004987 ])}},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.0),
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.       , 0.       , 0.       , 0.0078125, 0.0078125, 0.015625 ,
#             0.015625 , 0.0234375, 0.0234375, 0.03125  , 0.03125  , 0.0390625,
#             0.0390625, 0.046875 , 0.046875 , 0.0625   , 0.0625   , 0.0703125,
#             0.0703125, 0.078125 , 0.078125 , 0.0859375, 0.0859375, 0.1015625,
#             0.1015625, 0.1171875, 0.1171875, 0.1484375, 0.1484375, 0.15625  ,
#             0.15625  , 0.171875 , 0.171875 , 0.1796875, 0.1796875, 0.1953125,
#             0.1953125, 0.2109375, 0.2109375, 0.21875  , 0.21875  , 0.2265625,
#             0.2265625, 0.234375 , 0.234375 , 0.265625 , 0.265625 , 0.2734375,
#             0.2734375, 0.28125  , 0.28125  , 0.3046875, 0.3046875, 0.3203125,
#             0.3203125, 0.328125 , 0.328125 , 0.3359375, 0.3359375, 0.3515625,
#             0.3515625, 0.359375 , 0.359375 , 0.3671875, 0.3671875, 0.3828125,
#             0.3828125, 0.4140625, 0.4140625, 0.4453125, 0.4453125, 0.453125 ,
#             0.453125 , 0.46875  , 0.46875  , 0.484375 , 0.484375 , 0.4921875,
#             0.4921875, 0.5078125, 0.5078125, 0.7109375, 0.7109375, 1.       ]),
#      'tpr': array([0.        , 0.00819672, 0.1147541 , 0.1147541 , 0.12295082,
#             0.12295082, 0.16393443, 0.16393443, 0.24590164, 0.24590164,
#             0.2704918 , 0.2704918 , 0.28688525, 0.28688525, 0.31967213,
#             0.31967213, 0.3442623 , 0.3442623 , 0.35245902, 0.35245902,
#             0.36065574, 0.36065574, 0.3852459 , 0.3852459 , 0.40163934,
#             0.40163934, 0.45081967, 0.45081967, 0.49180328, 0.49180328,
#             0.54098361, 0.54098361, 0.54918033, 0.54918033, 0.58196721,
#             0.58196721, 0.59016393, 0.59016393, 0.62295082, 0.62295082,
#             0.67213115, 0.67213115, 0.71311475, 0.71311475, 0.74590164,
#             0.74590164, 0.7704918 , 0.7704918 , 0.78688525, 0.78688525,
#             0.80327869, 0.80327869, 0.81147541, 0.81147541, 0.83606557,
#             0.83606557, 0.8442623 , 0.8442623 , 0.86885246, 0.86885246,
#             0.87704918, 0.87704918, 0.8852459 , 0.8852459 , 0.89344262,
#             0.89344262, 0.90163934, 0.90163934, 0.90983607, 0.90983607,
#             0.91803279, 0.91803279, 0.95081967, 0.95081967, 0.95901639,
#             0.95901639, 0.96721311, 0.96721311, 0.97540984, 0.97540984,
#             0.99180328, 0.99180328, 1.        , 1.        ]),
#      'thresholds': array([       inf, 0.01124122, 0.00682835, 0.00676045, 0.00669639,
#             0.00651409, 0.00619936, 0.00615887, 0.00557108, 0.00555116,
#             0.00551491, 0.00538383, 0.00533447, 0.00532131, 0.00522405,
#             0.00514778, 0.00512608, 0.00510499, 0.00506878, 0.00506816,
#             0.00500493, 0.00498676, 0.00494243, 0.00482068, 0.0047335 ,
#             0.00470841, 0.00465363, 0.00461144, 0.00447937, 0.00443796,
#             0.0043696 , 0.00430822, 0.00429273, 0.0042911 , 0.00422448,
#             0.00415702, 0.004157  , 0.00414576, 0.00402857, 0.00400791,
#             0.00390292, 0.00384735, 0.00380776, 0.00379561, 0.00370981,
#             0.00367346, 0.00361791, 0.00360001, 0.00356895, 0.00355719,
#             0.00355102, 0.00351413, 0.00350374, 0.00348425, 0.00344381,
#             0.00340612, 0.00338843, 0.00332948, 0.00324282, 0.00323697,
#             0.00322196, 0.00319849, 0.00319573, 0.0031936 , 0.00318562,
#             0.00311318, 0.00306108, 0.00295518, 0.00293967, 0.00288584,
#             0.00288194, 0.00287676, 0.00271505, 0.00267437, 0.00266805,
#             0.00255016, 0.00246611, 0.00245056, 0.00239176, 0.00233868,
#             0.00231658, 0.00169001, 0.00168453, 0.00090606])}},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.0),
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.       , 0.0078125, 0.015625 , 0.015625 , 0.0234375, 0.0234375,
#             0.03125  , 0.03125  , 0.0390625, 0.0390625, 0.046875 , 0.046875 ,
#             0.0546875, 0.0546875, 0.0703125, 0.0703125, 0.09375  , 0.09375  ,
#             0.109375 , 0.109375 , 0.1171875, 0.1171875, 0.140625 , 0.140625 ,
#             0.171875 , 0.171875 , 0.203125 , 0.203125 , 0.2109375, 0.2109375,
#             0.21875  , 0.21875  , 0.2265625, 0.2265625, 0.25     , 0.25     ,
#             0.28125  , 0.28125  , 0.296875 , 0.296875 , 0.3125   , 0.3125   ,
#             0.3203125, 0.3203125, 0.328125 , 0.328125 , 0.3359375, 0.3359375,
#             0.3515625, 0.3515625, 0.359375 , 0.359375 , 0.375    , 0.375    ,
#             0.40625  , 0.40625  , 0.421875 , 0.421875 , 0.4453125, 0.4453125,
#             0.453125 , 0.453125 , 0.4609375, 0.4609375, 0.5078125, 0.5078125,
#             0.5234375, 0.5234375, 0.53125  , 0.53125  , 0.5625   , 0.5625   ,
#             0.6015625, 0.6015625, 0.6171875, 0.6171875, 0.625    , 0.625    ,
#             0.640625 , 0.640625 , 0.6484375, 0.6484375, 0.671875 , 0.671875 ,
#             0.6953125, 0.6953125, 0.703125 , 0.703125 , 0.71875  , 0.71875  ,
#             0.7265625, 0.7265625, 0.75     , 0.75     , 0.765625 , 0.765625 ,
#             0.7734375, 0.7734375, 0.78125  , 0.78125  , 0.796875 , 0.796875 ,
#             0.8203125, 0.8203125, 0.859375 , 0.859375 , 0.875    , 0.875    ,
#             0.8828125, 0.8828125, 0.8984375, 0.8984375, 0.90625  , 0.90625  ,
#             0.9140625, 0.9140625, 0.921875 , 0.921875 , 0.9296875, 0.9296875,
#             0.9375   , 0.9375   , 0.953125 , 0.953125 , 0.96875  , 0.96875  ,
#             0.9765625, 0.9765625, 1.       ]),
#      'tpr': array([0.        , 0.        , 0.        , 0.00819672, 0.00819672,
#             0.02459016, 0.02459016, 0.07377049, 0.07377049, 0.09836066,
#             0.09836066, 0.13114754, 0.13114754, 0.13934426, 0.13934426,
#             0.14754098, 0.14754098, 0.1557377 , 0.1557377 , 0.17213115,
#             0.17213115, 0.18852459, 0.18852459, 0.19672131, 0.19672131,
#             0.21311475, 0.21311475, 0.22131148, 0.22131148, 0.23770492,
#             0.23770492, 0.25409836, 0.25409836, 0.27868852, 0.27868852,
#             0.28688525, 0.28688525, 0.29508197, 0.29508197, 0.32786885,
#             0.32786885, 0.3442623 , 0.3442623 , 0.36065574, 0.36065574,
#             0.36885246, 0.36885246, 0.37704918, 0.37704918, 0.3852459 ,
#             0.3852459 , 0.39344262, 0.39344262, 0.40163934, 0.40163934,
#             0.41803279, 0.41803279, 0.42622951, 0.42622951, 0.45081967,
#             0.45081967, 0.45901639, 0.45901639, 0.5       , 0.5       ,
#             0.50819672, 0.50819672, 0.51639344, 0.51639344, 0.53278689,
#             0.53278689, 0.56557377, 0.56557377, 0.58196721, 0.58196721,
#             0.6147541 , 0.6147541 , 0.63114754, 0.63114754, 0.63934426,
#             0.63934426, 0.66393443, 0.66393443, 0.67213115, 0.67213115,
#             0.68032787, 0.68032787, 0.71311475, 0.71311475, 0.7295082 ,
#             0.7295082 , 0.73770492, 0.73770492, 0.74590164, 0.74590164,
#             0.77868852, 0.77868852, 0.79508197, 0.79508197, 0.80327869,
#             0.80327869, 0.81967213, 0.81967213, 0.83606557, 0.83606557,
#             0.8442623 , 0.8442623 , 0.85245902, 0.85245902, 0.86065574,
#             0.86065574, 0.89344262, 0.89344262, 0.90163934, 0.90163934,
#             0.90983607, 0.90983607, 0.91803279, 0.91803279, 0.95901639,
#             0.95901639, 0.97540984, 0.97540984, 0.98360656, 0.98360656,
#             0.99180328, 0.99180328, 1.        , 1.        ]),
#      'thresholds': array([       inf, 0.00537693, 0.00520734, 0.00500148, 0.00483967,
#             0.00469476, 0.00462066, 0.00437059, 0.00435271, 0.00427698,
#             0.00425782, 0.00417764, 0.00417132, 0.00416698, 0.00410309,
#             0.00409556, 0.00408045, 0.00400278, 0.00397939, 0.00393517,
#             0.00392197, 0.0039119 , 0.0038791 , 0.00386342, 0.00381667,
#             0.00373405, 0.00370508, 0.00370369, 0.00369993, 0.00367836,
#             0.00366937, 0.00366344, 0.00364094, 0.00358618, 0.00349598,
#             0.00349264, 0.00346414, 0.00345179, 0.00342685, 0.00332239,
#             0.00329814, 0.00328827, 0.00328233, 0.00327212, 0.00327107,
#             0.0032674 , 0.00326095, 0.00325699, 0.00320483, 0.00320446,
#             0.00314374, 0.00314033, 0.00313111, 0.00312011, 0.00310045,
#             0.00309526, 0.00305872, 0.00305707, 0.00300031, 0.00294757,
#             0.00289319, 0.00279409, 0.00279265, 0.00267929, 0.00254842,
#             0.0024916 , 0.0024612 , 0.00245527, 0.00239148, 0.00232829,
#             0.00230347, 0.00225317, 0.00221062, 0.00219969, 0.00217161,
#             0.0021485 , 0.00214028, 0.00212113, 0.0021055 , 0.00208198,
#             0.00206883, 0.00199585, 0.00196192, 0.00195579, 0.0019083 ,
#             0.00188968, 0.00188797, 0.00187294, 0.00187102, 0.00185806,
#             0.00184843, 0.00184583, 0.00182848, 0.00182146, 0.00182022,
#             0.00178168, 0.00177068, 0.00175456, 0.00175023, 0.00174948,
#             0.00173979, 0.00172945, 0.00172097, 0.0017043 , 0.00168717,
#             0.00167307, 0.0016529 , 0.00165226, 0.00165069, 0.00165015,
#             0.00160317, 0.00158405, 0.00157   , 0.00156928, 0.00156244,
#             0.00155599, 0.00155545, 0.0015544 , 0.00151097, 0.00148026,
#             0.00147972, 0.00143699, 0.00142301, 0.00140077, 0.00133959,
#             0.00131088, 0.00129304, 0.00118783, 0.00114068])}},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.0),
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.       , 0.0078125, 0.0078125, 0.0234375, 0.0234375, 0.03125  ,
#             0.03125  , 0.0390625, 0.0390625, 0.0703125, 0.0703125, 0.078125 ,
#             0.078125 , 0.0859375, 0.0859375, 0.09375  , 0.09375  , 0.1015625,
#             0.1015625, 0.1171875, 0.1171875, 0.125    , 0.125    , 0.1328125,
#             0.1328125, 0.140625 , 0.140625 , 0.1484375, 0.1484375, 0.15625  ,
#             0.15625  , 0.171875 , 0.171875 , 0.1953125, 0.1953125, 0.21875  ,
#             0.21875  , 0.2265625, 0.2265625, 0.234375 , 0.234375 , 0.2421875,
#             0.2421875, 0.25     , 0.25     , 0.2578125, 0.2578125, 0.28125  ,
#             0.28125  , 0.2890625, 0.2890625, 0.296875 , 0.296875 , 0.3046875,
#             0.3046875, 0.328125 , 0.328125 , 0.3359375, 0.3359375, 0.34375  ,
#             0.34375  , 0.3671875, 0.3671875, 0.375    , 0.375    , 0.3828125,
#             0.3828125, 0.390625 , 0.390625 , 0.4140625, 0.4140625, 0.421875 ,
#             0.421875 , 0.4296875, 0.4296875, 0.4375   , 0.4375   , 0.4453125,
#             0.4453125, 0.453125 , 0.453125 , 0.4609375, 0.4609375, 0.46875  ,
#             0.46875  , 0.5078125, 0.5078125, 0.5390625, 0.5390625, 0.546875 ,
#             0.546875 , 0.5546875, 0.5546875, 1.       ]),
#      'tpr': array([0.        , 0.        , 0.00819672, 0.00819672, 0.01639344,
#             0.01639344, 0.02459016, 0.02459016, 0.03278689, 0.03278689,
#             0.04918033, 0.04918033, 0.06557377, 0.06557377, 0.07377049,
#             0.07377049, 0.09016393, 0.09016393, 0.1147541 , 0.1147541 ,
#             0.13934426, 0.13934426, 0.14754098, 0.14754098, 0.18852459,
#             0.18852459, 0.20491803, 0.20491803, 0.2295082 , 0.2295082 ,
#             0.23770492, 0.23770492, 0.24590164, 0.24590164, 0.30327869,
#             0.30327869, 0.31147541, 0.31147541, 0.32786885, 0.32786885,
#             0.36065574, 0.36065574, 0.36885246, 0.36885246, 0.40983607,
#             0.40983607, 0.42622951, 0.42622951, 0.45081967, 0.45081967,
#             0.47540984, 0.47540984, 0.5       , 0.5       , 0.50819672,
#             0.50819672, 0.53278689, 0.53278689, 0.54098361, 0.54098361,
#             0.56557377, 0.56557377, 0.59016393, 0.59016393, 0.60655738,
#             0.60655738, 0.63114754, 0.63114754, 0.64754098, 0.64754098,
#             0.72131148, 0.72131148, 0.7295082 , 0.7295082 , 0.73770492,
#             0.73770492, 0.77868852, 0.77868852, 0.87704918, 0.87704918,
#             0.90983607, 0.90983607, 0.92622951, 0.92622951, 0.96721311,
#             0.96721311, 0.97540984, 0.97540984, 0.98360656, 0.98360656,
#             0.99180328, 0.99180328, 1.        , 1.        ]),
#      'thresholds': array([       inf, 0.0068886 , 0.00677306, 0.00664638, 0.00638424,
#             0.00622371, 0.00616183, 0.00597937, 0.00585458, 0.00559626,
#             0.0054916 , 0.00547247, 0.00537256, 0.00531105, 0.00529619,
#             0.00516673, 0.00508955, 0.00508368, 0.00500051, 0.00496886,
#             0.00488385, 0.00485694, 0.00485007, 0.00482008, 0.00475579,
#             0.004737  , 0.00465071, 0.00464519, 0.00456561, 0.00456535,
#             0.00452737, 0.00449441, 0.00449031, 0.00447282, 0.0044252 ,
#             0.00439682, 0.00439372, 0.00436631, 0.00433026, 0.00432218,
#             0.00427869, 0.0042542 , 0.00424122, 0.00420273, 0.00412422,
#             0.00412303, 0.00410819, 0.00407516, 0.00397048, 0.00392483,
#             0.00388448, 0.0038742 , 0.00379812, 0.00375196, 0.00374789,
#             0.00367448, 0.0036603 , 0.00365894, 0.00364921, 0.00364546,
#             0.00362307, 0.0035799 , 0.00354436, 0.00353655, 0.00348901,
#             0.00344635, 0.00342963, 0.00342064, 0.00340588, 0.00335818,
#             0.00322394, 0.00315048, 0.00309706, 0.00304731, 0.00302292,
#             0.00299416, 0.00295532, 0.0029355 , 0.00264658, 0.00262981,
#             0.0024814 , 0.00244385, 0.00239597, 0.00232545, 0.00226621,
#             0.00216367, 0.00214112, 0.00205182, 0.00204644, 0.0020407 ,
#             0.00199983, 0.00197926, 0.00196976, 0.00071172])}},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.0),
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.       , 0.       , 0.       , 0.015625 , 0.015625 , 0.0234375,
#             0.0234375, 0.0390625, 0.0390625, 0.046875 , 0.046875 , 0.0546875,
#             0.0546875, 0.0625   , 0.0625   , 0.0703125, 0.0703125, 0.09375  ,
#             0.09375  , 0.1015625, 0.1015625, 0.109375 , 0.109375 , 0.1171875,
#             0.1171875, 0.125    , 0.125    , 0.1484375, 0.1484375, 0.1640625,
#             0.1640625, 0.171875 , 0.171875 , 0.1796875, 0.1796875, 0.1875   ,
#             0.1875   , 0.203125 , 0.203125 , 0.2109375, 0.2109375, 0.25     ,
#             0.25     , 0.265625 , 0.265625 , 0.28125  , 0.28125  , 0.296875 ,
#             0.296875 , 0.3046875, 0.3046875, 0.3125   , 0.3125   , 0.3203125,
#             0.3203125, 0.328125 , 0.328125 , 0.34375  , 0.34375  , 0.3515625,
#             0.3515625, 0.359375 , 0.359375 , 0.3671875, 0.3671875, 0.3828125,
#             0.3828125, 0.390625 , 0.390625 , 0.40625  , 0.40625  , 0.4140625,
#             0.4140625, 0.421875 , 0.421875 , 0.4296875, 0.4296875, 0.4453125,
#             0.4453125, 0.453125 , 0.453125 , 0.4765625, 0.4765625, 0.5703125,
#             0.5703125, 1.       ]),
#      'tpr': array([0.        , 0.00819672, 0.01639344, 0.01639344, 0.02459016,
#             0.02459016, 0.06557377, 0.06557377, 0.07377049, 0.07377049,
#             0.09016393, 0.09016393, 0.1147541 , 0.1147541 , 0.13114754,
#             0.13114754, 0.14754098, 0.14754098, 0.1557377 , 0.1557377 ,
#             0.18852459, 0.18852459, 0.25409836, 0.25409836, 0.2704918 ,
#             0.2704918 , 0.29508197, 0.29508197, 0.31147541, 0.31147541,
#             0.39344262, 0.39344262, 0.40983607, 0.40983607, 0.45081967,
#             0.45081967, 0.46721311, 0.46721311, 0.47540984, 0.47540984,
#             0.5       , 0.5       , 0.54918033, 0.54918033, 0.58196721,
#             0.58196721, 0.59016393, 0.59016393, 0.59836066, 0.59836066,
#             0.62295082, 0.62295082, 0.63114754, 0.63114754, 0.63934426,
#             0.63934426, 0.67213115, 0.67213115, 0.68852459, 0.68852459,
# ...
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.        , 0.        , 0.        , 0.00746269, 0.00746269,
#             0.01492537, 0.01492537, 0.02985075, 0.02985075, 0.04477612,
#             0.04477612, 0.05223881, 0.05223881, 0.08208955, 0.08208955,
#             0.08955224, 0.08955224, 0.09701493, 0.09701493, 0.1119403 ,
#             0.1119403 , 0.14179104, 0.14179104, 0.17164179, 0.17164179,
#             0.17910448, 0.17910448, 0.20149254, 0.20149254, 0.23134328,
#             0.23134328, 0.23880597, 0.23880597, 0.24626866, 0.24626866,
#             0.26119403, 0.26119403, 0.26865672, 0.26865672, 0.31343284,
#             0.31343284, 0.32835821, 0.32835821, 0.36567164, 0.36567164,
#             0.37313433, 0.37313433, 0.38059701, 0.38059701, 0.39552239,
#             0.39552239, 0.40298507, 0.40298507, 0.41044776, 0.41044776,
#             0.44029851, 0.44029851, 0.58955224, 0.58955224, 0.64925373,
#             0.64925373, 0.6641791 , 0.6641791 , 0.70149254, 0.70149254,
#             0.71641791, 0.71641791, 0.75373134, 0.75373134, 0.90298507,
#             0.90298507, 1.        ]),
#      'tpr': array([0.        , 0.00862069, 0.40517241, 0.40517241, 0.43103448,
#             0.43103448, 0.46551724, 0.46551724, 0.56034483, 0.56034483,
#             0.57758621, 0.57758621, 0.5862069 , 0.5862069 , 0.59482759,
#             0.59482759, 0.61206897, 0.61206897, 0.62068966, 0.62068966,
#             0.62931034, 0.62931034, 0.63793103, 0.63793103, 0.64655172,
#             0.64655172, 0.65517241, 0.65517241, 0.6637931 , 0.6637931 ,
#             0.67241379, 0.67241379, 0.68103448, 0.68103448, 0.69827586,
#             0.69827586, 0.70689655, 0.70689655, 0.75862069, 0.75862069,
#             0.76724138, 0.76724138, 0.78448276, 0.78448276, 0.79310345,
#             0.79310345, 0.82758621, 0.82758621, 0.8362069 , 0.8362069 ,
#             0.85344828, 0.85344828, 0.87068966, 0.87068966, 0.88793103,
#             0.88793103, 0.92241379, 0.92241379, 0.93965517, 0.93965517,
#             0.94827586, 0.94827586, 0.95689655, 0.95689655, 0.96551724,
#             0.96551724, 0.97413793, 0.97413793, 0.99137931, 0.99137931,
#             1.        , 1.        ]),
#      'thresholds': array([       inf, 0.9991709 , 0.99801238, 0.99800917, 0.99794211,
#             0.99788292, 0.99783258, 0.99776912, 0.99756577, 0.99752896,
#             0.99744999, 0.99744948, 0.99743549, 0.99740583, 0.99740505,
#             0.99738621, 0.99734242, 0.99732599, 0.99732051, 0.99727779,
#             0.99727777, 0.9971661 , 0.99716462, 0.99708224, 0.99707212,
#             0.99707193, 0.99705791, 0.99701031, 0.99698534, 0.99692227,
#             0.99688244, 0.996841  , 0.99683262, 0.99682707, 0.99680069,
#             0.99673632, 0.99673359, 0.99673071, 0.99667249, 0.99645687,
#             0.99643854, 0.99638718, 0.99634353, 0.99628498, 0.99626992,
#             0.99618754, 0.99617206, 0.99612365, 0.99611272, 0.99607736,
#             0.9960685 , 0.99603053, 0.9959902 , 0.99597162, 0.99591948,
#             0.99588554, 0.99584775, 0.99525483, 0.9952274 , 0.99496127,
#             0.99493435, 0.99489248, 0.9948697 , 0.99467195, 0.99467026,
#             0.99447268, 0.99445012, 0.994172  , 0.99413854, 0.9930789 ,
#             0.99293076, 0.98938428])}},
#    {'model': LogisticRegression(),
#     'fpr': np.float64(1.0),
#     'tpr': np.float64(1.0),
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.        , 0.        , 0.        , 0.00746269, 0.00746269,
#             0.01492537, 0.01492537, 0.02985075, 0.02985075, 0.03731343,
#             0.03731343, 0.04477612, 0.04477612, 0.05223881, 0.05223881,
#             0.05970149, 0.05970149, 0.06716418, 0.06716418, 0.07462687,
#             0.07462687, 0.08955224, 0.08955224, 0.12686567, 0.12686567,
#             0.14179104, 0.14179104, 0.17164179, 0.17164179, 0.19402985,
#             0.19402985, 0.20149254, 0.20149254, 0.2761194 , 0.2761194 ,
#             0.28358209, 0.28358209, 0.37313433, 0.37313433, 0.3880597 ,
#             0.3880597 , 0.44776119, 0.44776119, 0.46268657, 0.46268657,
#             0.49253731, 0.49253731, 0.51492537, 0.51492537, 0.53731343,
#             0.53731343, 0.58208955, 0.58208955, 0.59701493, 0.59701493,
#             0.62686567, 0.62686567, 0.67910448, 0.67910448, 0.68656716,
#             0.68656716, 0.69402985, 0.69402985, 0.71641791, 0.71641791,
#             0.73134328, 0.73134328, 0.73880597, 0.73880597, 0.74626866,
#             0.74626866, 0.75373134, 0.75373134, 0.76119403, 0.76119403,
#             0.76865672, 0.76865672, 0.78358209, 0.78358209, 0.79850746,
#             0.79850746, 0.80597015, 0.80597015, 0.82089552, 0.82089552,
#             0.8358209 , 0.8358209 , 0.85820896, 0.85820896, 0.86567164,
#             0.86567164, 0.87313433, 0.87313433, 0.89552239, 0.89552239,
#             0.91791045, 0.91791045, 0.92537313, 0.92537313, 0.95522388,
#             0.95522388, 0.97014925, 0.97014925, 0.98507463, 0.98507463,
#             0.99253731, 0.99253731, 1.        , 1.        ]),
#      'tpr': array([0.        , 0.00862069, 0.1637931 , 0.1637931 , 0.18103448,
#             0.18103448, 0.22413793, 0.22413793, 0.25862069, 0.25862069,
#             0.30172414, 0.30172414, 0.31034483, 0.31034483, 0.32758621,
#             0.32758621, 0.3362069 , 0.3362069 , 0.34482759, 0.34482759,
#             0.37068966, 0.37068966, 0.37931034, 0.37931034, 0.42241379,
#             0.42241379, 0.43103448, 0.43103448, 0.43965517, 0.43965517,
#             0.44827586, 0.44827586, 0.45689655, 0.45689655, 0.46551724,
#             0.46551724, 0.47413793, 0.47413793, 0.48275862, 0.48275862,
#             0.49137931, 0.49137931, 0.5       , 0.5       , 0.51724138,
#             0.51724138, 0.52586207, 0.52586207, 0.53448276, 0.53448276,
#             0.54310345, 0.54310345, 0.56034483, 0.56034483, 0.56896552,
#             0.56896552, 0.57758621, 0.57758621, 0.62068966, 0.62068966,
#             0.63793103, 0.63793103, 0.65517241, 0.65517241, 0.6637931 ,
#             0.6637931 , 0.67241379, 0.67241379, 0.69827586, 0.69827586,
#             0.71551724, 0.71551724, 0.72413793, 0.72413793, 0.73275862,
#             0.73275862, 0.74137931, 0.74137931, 0.75      , 0.75      ,
#             0.76724138, 0.76724138, 0.77586207, 0.77586207, 0.78448276,
#             0.78448276, 0.80172414, 0.80172414, 0.81896552, 0.81896552,
#             0.82758621, 0.82758621, 0.8362069 , 0.8362069 , 0.84482759,
#             0.84482759, 0.86206897, 0.86206897, 0.87931034, 0.87931034,
#             0.88793103, 0.88793103, 0.93965517, 0.93965517, 0.95689655,
#             0.95689655, 0.99137931, 0.99137931, 1.        ]),
#      'thresholds': array([       inf, 0.99929308, 0.99908776, 0.99903713, 0.99901996,
#             0.99900094, 0.99896069, 0.99895676, 0.99890171, 0.99890104,
#             0.99887004, 0.99886911, 0.99886402, 0.99885212, 0.99884014,
#             0.99883366, 0.99883046, 0.99882137, 0.99881883, 0.99881425,
#             0.99875961, 0.99875607, 0.99873784, 0.9986612 , 0.99852783,
#             0.99849818, 0.99849505, 0.99846653, 0.99846612, 0.99842522,
#             0.99839459, 0.99839374, 0.99836403, 0.99824527, 0.99823464,
#             0.99822183, 0.99820951, 0.99808478, 0.99805289, 0.99803122,
#             0.99802123, 0.99769943, 0.99768364, 0.99765318, 0.99758379,
#             0.99745506, 0.99741095, 0.99739725, 0.99736353, 0.99731676,
#             0.99730961, 0.99716688, 0.99711119, 0.99705916, 0.99704287,
#             0.99696242, 0.99696119, 0.99667553, 0.99661929, 0.99660678,
#             0.99657776, 0.99657483, 0.99654944, 0.99648167, 0.99645279,
#             0.99640242, 0.99633375, 0.99632525, 0.99626627, 0.99626482,
#             0.99621863, 0.99620274, 0.99611042, 0.99610077, 0.99609427,
#             0.99606787, 0.99604882, 0.99599252, 0.99597506, 0.99593079,
#             0.99584336, 0.99583963, 0.9958316 , 0.99581967, 0.99579603,
#             0.99575467, 0.99574188, 0.99558424, 0.99539807, 0.99535418,
#             0.99528612, 0.9952587 , 0.99524711, 0.99518423, 0.99515223,
#             0.99504249, 0.99496933, 0.99495981, 0.99486717, 0.99472733,
#             0.99472646, 0.99450293, 0.99422502, 0.99391017, 0.99357439,
#             0.9934558 , 0.99276403, 0.99250916, 0.99217683])}}]],
#  'roc_results': {'fpr': array([0.        , 0.        , 0.00333333, 0.00333333, 0.00666667,
#          0.00666667, 0.01      , 0.01      , 0.01333333, 0.01333333,
#          0.01666667, 0.01666667, 0.02      , 0.02      , 0.02666667,
#          0.02666667, 0.03      , 0.03      , 0.03333333, 0.03333333,
#          0.04      , 0.04      , 0.04666667, 0.04666667, 0.05      ,
#          0.05      , 0.05333333, 0.05333333, 0.05666667, 0.05666667,
#          0.06333333, 0.06333333, 0.07      , 0.07      , 0.07333333,
#          0.07333333, 0.08      , 0.08      , 0.08333333, 0.08333333,
#          0.08666667, 0.08666667, 0.1       , 0.1       , 0.10333333,
#          0.10333333, 0.11      , 0.11      , 0.11333333, 0.11333333,
#          0.12      , 0.12      , 0.12333333, 0.12333333, 0.13333333,
#          0.13333333, 0.14      , 0.14      , 0.15      , 0.15      ,
#          0.15666667, 0.15666667, 0.16333333, 0.16333333, 0.17333333,
#          0.17333333, 0.18333333, 0.18333333, 0.19333333, 0.19333333,
#          0.2       , 0.2       , 0.20333333, 0.20333333, 0.21      ,
#          0.21      , 0.21333333, 0.21333333, 0.23      , 0.23      ,
#          0.25      , 0.25      , 0.25333333, 0.25333333, 0.25666667,
#          0.25666667, 0.26      , 0.26      , 0.27333333, 0.27333333,
#          0.28333333, 0.28333333, 0.28666667, 0.28666667, 0.29      ,
#          0.29      , 0.29333333, 0.29333333, 0.29666667, 0.29666667,
#          0.31333333, 0.31333333, 0.31666667, 0.31666667, 0.32333333,
#          0.32333333, 0.32666667, 0.32666667, 0.33      , 0.33      ,
#          0.33333333, 0.33333333, 0.35      , 0.35      , 0.35666667,
#          0.35666667, 0.37333333, 0.37333333, 0.38      , 0.38      ,
#          0.38666667, 0.38666667, 0.41      , 0.41      , 0.41333333,
#          0.41333333, 0.42333333, 0.42333333, 0.42666667, 0.42666667,
#          0.43      , 0.43      , 0.44666667, 0.44666667, 0.45666667,
#          0.45666667, 0.46      , 0.46      , 0.46666667, 0.46666667,
#          0.47      , 0.47      , 0.47333333, 0.47333333, 0.48333333,
#          0.48333333, 0.48666667, 0.48666667, 0.50333333, 0.50333333,
#          0.52333333, 0.52333333, 0.54333333, 0.54333333, 0.57      ,
#          0.57      , 0.58333333, 0.58333333, 0.60333333, 0.60333333,
#          0.61333333, 0.61333333, 0.61666667, 0.61666667, 0.62      ,
#          0.62      , 0.62666667, 0.62666667, 0.63333333, 0.63333333,
#          0.65666667, 0.65666667, 0.66666667, 0.66666667, 0.67      ,
#          0.67      , 0.68666667, 0.68666667, 0.75333333, 0.75333333,
#          0.75666667, 0.75666667, 0.79      , 0.79      , 1.        ]),
#   'tpr': array([0.        , 0.00333333, 0.00333333, 0.07      , 0.07      ,
#          0.16333333, 0.16333333, 0.20666667, 0.20666667, 0.30666667,
#          0.30666667, 0.33333333, 0.33333333, 0.37666667, 0.37666667,
#          0.38666667, 0.38666667, 0.39      , 0.39      , 0.39666667,
#          0.39666667, 0.42      , 0.42      , 0.42333333, 0.42333333,
#          0.42666667, 0.42666667, 0.44      , 0.44      , 0.47666667,
#          0.47666667, 0.49      , 0.49      , 0.5       , 0.5       ,
#          0.50333333, 0.50333333, 0.51      , 0.51      , 0.51333333,
#          0.51333333, 0.51666667, 0.51666667, 0.52333333, 0.52333333,
#          0.53333333, 0.53333333, 0.53666667, 0.53666667, 0.55      ,
#          0.55      , 0.56333333, 0.56333333, 0.57333333, 0.57333333,
#          0.59666667, 0.59666667, 0.60666667, 0.60666667, 0.61666667,
#          0.61666667, 0.64666667, 0.64666667, 0.65666667, 0.65666667,
#          0.66      , 0.66      , 0.66333333, 0.66333333, 0.66666667,
#          0.66666667, 0.67333333, 0.67333333, 0.68      , 0.68      ,
#          0.7       , 0.7       , 0.70333333, 0.70333333, 0.70666667,
#          0.70666667, 0.72666667, 0.72666667, 0.73333333, 0.73333333,
#          0.74      , 0.74      , 0.74666667, 0.74666667, 0.75      ,
#          0.75      , 0.75333333, 0.75333333, 0.75666667, 0.75666667,
#          0.76      , 0.76      , 0.76666667, 0.76666667, 0.77666667,
#          0.77666667, 0.78      , 0.78      , 0.78333333, 0.78333333,
#          0.79333333, 0.79333333, 0.80666667, 0.80666667, 0.81      ,
#          0.81      , 0.81333333, 0.81333333, 0.82      , 0.82      ,
#          0.82333333, 0.82333333, 0.82666667, 0.82666667, 0.83333333,
#          0.83333333, 0.83666667, 0.83666667, 0.84666667, 0.84666667,
#          0.85      , 0.85      , 0.87666667, 0.87666667, 0.88      ,
#          0.88      , 0.88333333, 0.88333333, 0.89      , 0.89      ,
#          0.89333333, 0.89333333, 0.89666667, 0.89666667, 0.9       ,
#          0.9       , 0.90666667, 0.90666667, 0.91      , 0.91      ,
#          0.91333333, 0.91333333, 0.92      , 0.92      , 0.92333333,
#          0.92333333, 0.92666667, 0.92666667, 0.93      , 0.93      ,
#          0.93666667, 0.93666667, 0.94      , 0.94      , 0.94333333,
#          0.94333333, 0.94666667, 0.94666667, 0.95333333, 0.95333333,
#          0.95666667, 0.95666667, 0.96      , 0.96      , 0.96333333,
#          0.96333333, 0.97666667, 0.97666667, 0.98      , 0.98      ,
#          0.98333333, 0.98333333, 0.99      , 0.99      , 0.99333333,
#          0.99333333, 0.99666667, 0.99666667, 1.        , 1.        ]),
#   'thresholds': array([       inf, 0.99329354, 0.97907905, 0.94191246, 0.94151511,
#          0.90004762, 0.89861156, 0.87935338, 0.87931429, 0.8362012 ,
#          0.83507059, 0.82291058, 0.82259687, 0.7981909 , 0.79435385,
#          0.7916089 , 0.79093336, 0.78930849, 0.78895498, 0.77850008,
#          0.77642253, 0.74987512, 0.74672639, 0.74598384, 0.74328376,
#          0.74311733, 0.74210689, 0.73905784, 0.73821687, 0.71804024,
#          0.7157722 , 0.70545647, 0.70451069, 0.70051975, 0.69489299,
#          0.69297334, 0.68749778, 0.68369992, 0.68305416, 0.68125707,
#          0.67967157, 0.67956078, 0.66998106, 0.66559516, 0.6634612 ,
#          0.65529123, 0.65453617, 0.65227387, 0.64542489, 0.63275717,
#          0.62981218, 0.62035803, 0.61897678, 0.61281075, 0.61117807,
#          0.59211215, 0.59166039, 0.58936431, 0.58425584, 0.57378684,
#          0.56942325, 0.56250307, 0.56104537, 0.5538181 , 0.54690839,
#          0.54472877, 0.54329772, 0.54257522, 0.53880982, 0.53868718,
#          0.53193708, 0.52901181, 0.52892343, 0.52772453, 0.52698131,
#          0.51382483, 0.51293672, 0.50525115, 0.49436739, 0.49317454,
#          0.4837027 , 0.4762332 , 0.47311516, 0.47110378, 0.47000104,
#          0.46461653, 0.46338811, 0.46124579, 0.45479833, 0.45154339,
#          0.44376617, 0.4404012 , 0.44003808, 0.43327701, 0.43251074,
#          0.43168754, 0.43074778, 0.42761753, 0.42704473, 0.4239242 ,
#          0.41289363, 0.41231114, 0.41111916, 0.41101159, 0.40598082,
#          0.40383325, 0.40379073, 0.39784952, 0.3948533 , 0.39316228,
#          0.3916173 , 0.38613937, 0.37488422, 0.37376655, 0.37273492,
#          0.37078469, 0.35481691, 0.35438355, 0.35037054, 0.34849693,
#          0.34506844, 0.3435108 , 0.33436833, 0.33076733, 0.33047434,
#          0.33028278, 0.32589732, 0.31592191, 0.31493237, 0.3114461 ,
#          0.31002279, 0.30708706, 0.29775991, 0.29533317, 0.28724221,
#          0.28645115, 0.28305874, 0.28248536, 0.27591325, 0.27583821,
#          0.27475734, 0.27262154, 0.27261047, 0.27138951, 0.2652133 ,
#          0.26476858, 0.26443569, 0.26198753, 0.2549473 , 0.25162899,
#          0.24105439, 0.24037919, 0.23319289, 0.2319992 , 0.21978977,
#          0.21789182, 0.21323005, 0.21012376, 0.20137866, 0.1991743 ,
#          0.19267026, 0.19174481, 0.19076747, 0.18967964, 0.18944254,
#          0.18777554, 0.18412117, 0.18379505, 0.18192144, 0.17945039,
#          0.16978321, 0.16748933, 0.164734  , 0.16369108, 0.16366304,
#          0.16225953, 0.15495405, 0.14640905, 0.10930001, 0.10892123,
#          0.10767635, 0.10712183, 0.09504582, 0.08834955, 0.0134105 ]),
#   'name': 'Logistic Regression',
#   'auc': np.float64(0.8326333333333332),
#   'model': LogisticRegression()},
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x732aaf133b60>}

# %% [markdown]
# # Load pickle

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Load the data
list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader = load_from_pickle(filename='pickle/Logistic_data2_undersampling.pkl')
# Out:
# Data loaded successfully.

# %% [markdown]
# ### Ensemble prediction using voting

# %%
import numpy as np

# --- Loop through all the FPR values to generate the ensemble ROC curve ---



results_tuple, prior_proba = predict_ensemble_and_evaluate(list_folds_best_models=list_folds_best_models,
    test_loader=test_loader)

ensemble_results_soft = results_tuple['soft_voting']
ensemble_results_hard = results_tuple['hard_voting']
misclassification_risk = results_tuple['misclassification_risk']
# Out:
# Creating a single ensemble from 170 models across all folds.
# Extracting full dataset...
# Getting predictions from all models...
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>

# %% [markdown]
# ## Load NP curve pickle

# %%
from predict_ensemble_and_evaluate import load_from_pickle_constrained_roc

# Load the constrained ROC curve results
constrained_points = load_from_pickle_constrained_roc(filename='pickle/Logistic_Data2_NP_roc_curve.pkl')
# Out:
# Constrained ROC curve points loaded from pickle/Logistic_Data2_NP_roc_curve.pkl

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
results_lists.append(constrained_points)
results_lists.append(ensemble_results_hard)
results_lists.append(misclassification_risk)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["MaxROCFold 1", "MaxROCFold 2", "MaxROCFold 3", "MaxROCFold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Neyman_Pearson", "Ensemble_voting_hard", "Misclassification_Risk"],
    results_original_roc=results_original_roc, plot_name="logistic_undersampling_data2", prior_prob=prior_proba
)
# Out:
# --- Plotting all ROC curves for comparison ---
