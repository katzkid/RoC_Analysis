# %% [markdown]
# ### Import

# %%
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# %% [markdown]
# ## Display function

# %%
#function for displaying ROC curves of multiple classifiers

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc

def plot_roc_connected_points(results_list, results_original_roc, name="All Classifiers"):
    """
    Creates a plot showing the performance of all classifiers as points,
    and connects them with a line, sorted by FPR.

    Args:
        results_list: A list of dictionaries, where each dict contains 'fpr', 'tpr'.
    """
    if not results_list:
        print("No results to plot.")
        return

    # Convert results to a pandas DataFrame for easy sorting
    df = pd.DataFrame(results_list)
    
    # Sort the models by their False Positive Rate to create a left-to-right line
    df_sorted = df.sort_values(by=['fpr','tpr']).reset_index(drop=True)
    
    # --- Plotting ---
    plt.figure(figsize=(10, 10))
    
    # Plot all the individual model points as a scatter plot
    # This helps see the actual performance of each model
    plt.scatter(df_sorted['fpr'], df_sorted['tpr'], c='black', marker='o', 
                alpha=0.6, s=100, zorder=3) # zorder=3 puts dots on top

    # Plot the line connecting the points
    plt.plot(df_sorted['fpr'], df_sorted['tpr'], color='red', lw=1.5,
             alpha=0.8, label=f'{name} (AUC = {auc(df_sorted["fpr"], df_sorted["tpr"]):.2f})')
    
    #plot the original ROC curve
    plt.plot(results_original_roc["fpr"], results_original_roc["tpr"], color='blue', 
             label=f'{results_original_roc["name"]} (AUC = {results_original_roc["auc"]:.2f})')

    # Plot the "no-skill" line for reference
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Performance Path of All Trained Classifiers')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Best ROC envelope

# %%
import numpy as np
from sklearn.metrics import roc_curve

def get_best_roc_envelope(results_list, results_original_roc=None):
    """
    Constructs the upper envelope of multiple ROC curves to find the best
    possible operating points from a collection of classifiers.

    This function is guaranteed to produce a list of points that starts at
    (FPR=0, TPR=0) and ends at (FPR=1, TPR=1), making it suitable for direct
    plotting and AUC calculation.

    Args:
        results_list (list): A list of dictionaries. Each dictionary must
                             contain a 'model' name and the full ROC results
                             under the 'full_roc' key.
        results_original_roc (dict, optional): A dictionary containing the
                                               ROC results of a baseline model,
                                               which will also be included in
                                               the comparison. Defaults to None.

    Returns:
        list: A sorted list of dictionaries representing the optimal ROC
              envelope. Each dictionary includes 'model', 'fpr', 'tpr',
              and 'threshold'.
    """
    all_points = []

    # Step 1: Gather all ROC points from all provided models
    all_results = results_list[:]
    if results_original_roc:
        all_results.append({
            'model': 'original_baseline',
            'full_roc': results_original_roc
        })

    for result in all_results:
        model_name = result.get('model', 'Unknown Model')
        roc = result.get('full_roc')
        if not roc: continue

        fprs = roc.get('fpr', [])
        tprs = roc.get('tpr', [])
        thresholds = roc.get('thresholds', [])

        for i in range(len(fprs)):
            threshold = thresholds[i] if i < len(thresholds) else thresholds[-1]
            all_points.append({
                'model': model_name, 'fpr': fprs[i],
                'tpr': tprs[i], 'threshold': threshold
            })

    # Handle case with no data by returning a default diagonal line
    if not all_points:
        return [
            {'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf},
            {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}
        ]

    # Step 2: Sort all points by FPR (asc), then by TPR (desc)
    all_points.sort(key=lambda p: (p['fpr'], -p['tpr']))

    # Step 3: Build the core ROC envelope
    best_roc_envelope = []
    max_tpr_so_far = -1.0
    for point in all_points:
        # Add a point only if it has a strictly higher TPR
        if point['tpr'] > max_tpr_so_far:
            # To prevent adding multiple points at the same FPR, check if the last point
            # has the same FPR and replace it if so (since this one has a higher TPR)
            if best_roc_envelope and best_roc_envelope[-1]['fpr'] == point['fpr']:
                best_roc_envelope[-1] = point
            else:
                best_roc_envelope.append(point)
            max_tpr_so_far = point['tpr']
    
    # Step 4: Manually add extremities if they are missing
    
    # Ensure the curve starts at (0, 0)
    if not best_roc_envelope or best_roc_envelope[0]['fpr'] > 0.0:
        best_roc_envelope.insert(0, {
            'model': 'start', 'fpr': 0.0, 'tpr': 0.0, 'threshold': np.inf
        })

    # Ensure the curve ends at (1, 1)
    if best_roc_envelope[-1]['fpr'] < 1.0 or best_roc_envelope[-1]['tpr'] < 1.0:
        best_roc_envelope.append({
            'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0
        })

    return best_roc_envelope

# %% [markdown]
# ## Data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def generate_data(dataset):
    if dataset == "data1":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [0, 2], [2, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )

        

        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")
    elif dataset == "data2":
        no_predictors = 2
        no_samples = 1600
        no_classes = 2
        #kerneltype = 'linear'  #comment out for polynomial kernel
        #kerneltype = 'poly'  #comment out for linear kernel



        n_samples_per_cluster = 400
        n_clusters = 4

        # Create the clusters deterministically
        np.random.seed(0) # for reproducibility

        X = np.zeros((n_samples_per_cluster * n_clusters, 2))
        y = np.zeros(n_samples_per_cluster * n_clusters)

        # Cluster centers in corners of a square
        centers = [[0, 0], [2, 0], [1, 2], [1, 2]]

        # Assign points to clusters deterministically
        for i in range(n_clusters):
            cluster_indices = slice(i * n_samples_per_cluster, (i + 1) * n_samples_per_cluster)
            X[cluster_indices] = centers[i] + np.random.normal(scale=0.5, size=(n_samples_per_cluster, 2))
            if i == 0 or i == 3:
                y[cluster_indices] = 0
            else:
                y[cluster_indices] = 1



        #Visualize
        plt.figure(figsize=(8,8))
        plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50)
        plt.title('Four Clusters of Equal Size')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.show()

        #add intercept to X
        #X = np.hstack((np.ones((X.shape[0], 1)), X))

        # # shuffle data
        # permutation = np.random.permutation(no_samples)
        # X = X[permutation]
        # y = y[permutation]


        #Split data into training and testing sets
        # Step 1: Split off the 1000 training samples. The rest (600) go into a temporary pool.
        # We can use absolute numbers for the size.
        X_train, X_test, y_train, y_test = train_test_split(
            X, y,
            train_size=1000,  # Specify exactly 1000 samples for training
            random_state=42,
            stratify=y        # Crucial for classification: keeps class proportions the same
        )


        train_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
        test_data = np.concatenate((X_test, y_test.reshape(-1, 1)), axis=1)

        val_data = test_data

        print(f"Training data shape: {X_train.shape}, {y_train.shape}")
        print(f"Test data shape: {X_test.shape}, {y_test.shape}")

    elif dataset == "pneumoniaMNIST":
        import medmnist
        print(medmnist.__version__)
        # read in the PneumoniaMNIST dataset
        from medmnist import PneumoniaMNIST
        train_data = PneumoniaMNIST(split='train', download=True, size=224)
        test_data = PneumoniaMNIST(split='test', download=True, size=224)
        val_data = PneumoniaMNIST(split='val', download=True, size=224)
        # print the dataset info
        print(f"Number of training samples: {len(train_data)}")
        print(f"Number of test samples: {len(test_data)}")
        print(f"Number of validation samples: {len(val_data)}")

    return train_data, test_data, val_data

# %% [markdown]
# ## Calculate Statistics function

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def get_fpr_tpr(clf_model, X_test, y_test, threshold=0.5):
    """
    Calculates the False Positive Rate (FPR) and True Positive Rate (TPR) at a given threshold.

    Args:
        X_test: The test features.
        y_test: The true test labels (0 or 1).
        threshold: The probability threshold.

    Returns:
        A dictionary containing the FPR and TPR. Returns None if there's an error.
    """
    try:
        #y_prob = clf_model.predict_proba(X_test)[:, 1]
        #y_pred = (y_prob >= threshold).astype(int)
        y_pred = clf_model.predict(X_test)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  #Avoid division by zero
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0 #Avoid division by zero
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        misclassification_rate = 1 - accuracy

        return {"fpr": fpr, "tpr": tpr, "precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy, "misclassification_rate": misclassification_rate}

    except ValueError as e:
        print(f"Error calculating FPR and TPR: {e}")
        return None

# %%
# Define constants
BATCH_SIZE = 64
LEARNING_RATE = 0.001
IMAGE_SIZE = 224
NUM_CLASSES = 1
NUM_CHANNELS = 1
NUM_EPOCHS = 1
NUM_WORKERS = 4
K_FOLDS = 4

# %% [markdown]
# ## Data1: Logistic regression

# %%
from sklearn.model_selection import KFold
import torch
import torch.utils.data as data

train_data, test_data, val_data = generate_data("data1")


train_data_tensor = data.TensorDataset(torch.tensor(train_data[:, :-1], dtype=torch.float32),
                                        torch.tensor(train_data[:, -1], dtype=torch.float32))
train_loader = data.DataLoader(train_data_tensor, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS) #over-write later for k-fold cross-validation
test_data_tensor = data.TensorDataset(torch.tensor(test_data[:, :-1], dtype=torch.float32),
                                       torch.tensor(test_data[:, -1], dtype=torch.float32))
test_loader = data.DataLoader(test_data_tensor, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# initialize fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# Out:
# Training data shape: (1000, 2), (1000,)
# Test data shape: (600, 2), (600,)

# %% [markdown]
# ### Regular training

# %%
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc
# Logistic Regression
X_train = train_data[:, :-1]
y_train = train_data[:, -1]
X_test = test_data[:, :-1]
y_test = test_data[:, -1]
clf = SVC(kernel='linear', probability=True, random_state=42)
clf.fit(X_train, y_train)

#calculate ROC results
fpr_roc, tpr_roc, threshold_roc = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
results_original_roc = {"fpr": fpr_roc, "tpr": tpr_roc, "thresholds": threshold_roc, "name": "SVM Regression", "auc": auc(fpr_roc, tpr_roc), "model": clf}

# %% [markdown]
# ## Weighted ROC curve

# %%
#store the weighted classifiers of all the folds
list_folds_weighted_clfs = []  # List to store classifiers from all folds
#store the best classfiers of all the folds 
list_folds_best_models = []  # List to store best models from all folds
# Weight the X_train and y_train for cost-sensitive learning
minority_class_weight = np.arange(0.001, 0.999, 0.01)
majority_class_weight = 1.0 - minority_class_weight
list_weighted_clfs = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_data)):
    list_weighted_clfs = [] # List to store the models trained at each stage
    best_clfs = [] # List to store the best models from each stage

    print(f"--- Starting Fold {fold + 1}/{K_FOLDS} ---")
    X_train_fold = train_data[train_ids][:, :-1]
    y_train_fold = train_data[train_ids][:, -1]
    X_test_fold = train_data[val_ids][:, :-1]
    y_test_fold = train_data[val_ids][:, -1]
    for w in minority_class_weight:
        class_weights = {0: 1 - w, 1: w}

        clf_weighted = SVC(kernel='linear', probability=True, class_weight=class_weights, random_state=42)
        clf_weighted.fit(X_train_fold, y_train_fold)

        res = get_fpr_tpr(clf_weighted, X_test_fold, y_test_fold, threshold=0.5)

        array_of_all_fprs, array_of_all_tprs, threshold_vals = roc_curve(y_test_fold, clf_weighted.predict_proba(X_test_fold)[:, 1])

        current_result = {
            "model": clf_weighted,
            "fpr": res["fpr"],
            "tpr": res["tpr"],
            "threshold": 0.5,
            "full_roc": {"fpr": array_of_all_fprs, "tpr": array_of_all_tprs, "thresholds": threshold_vals},
        }
        list_weighted_clfs.append(current_result)
        best_clfs = get_best_roc_envelope(list_weighted_clfs, results_original_roc)
    list_folds_weighted_clfs.append(list_weighted_clfs)
    list_folds_best_models.append(best_clfs)
# Out:
# --- Starting Fold 1/4 ---
# --- Starting Fold 2/4 ---
# --- Starting Fold 3/4 ---
# --- Starting Fold 4/4 ---

# %% [markdown]
# ### Store list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Save the data
save_to_pickle(list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader, filename='pickle/SVM_data1_weighted.pkl')
# Out:
# Data saved to pickle/SVM_data1_weighted.pkl
# {'best_models': [[{'model': SVC(class_weight={0: np.float64(0.5990000000000001),
#                       1: np.float64(0.4009999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.36065573770491804),
#     'threshold': np.float64(0.5125685788345954)},
#    {'model': SVC(class_weight={0: np.float64(0.609), 1: np.float64(0.39099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0078125),
#     'tpr': np.float64(0.39344262295081966),
#     'threshold': np.float64(0.5097816186225009)},
#    {'model': SVC(class_weight={0: np.float64(0.619), 1: np.float64(0.38099999999999995)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.015625),
#     'tpr': np.float64(0.4098360655737705),
#     'threshold': np.float64(0.5073845623369471)},
#    {'model': SVC(class_weight={0: np.float64(0.609), 1: np.float64(0.39099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0234375),
#     'tpr': np.float64(0.4262295081967213),
#     'threshold': np.float64(0.5093731855867885)},
#    {'model': SVC(class_weight={0: np.float64(0.899), 1: np.float64(0.10099999999999998)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0390625),
#     'tpr': np.float64(0.4344262295081967),
#     'threshold': np.float64(0.5691330853817684)},
#    {'model': SVC(class_weight={0: np.float64(0.859), 1: np.float64(0.141)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.046875),
#     'tpr': np.float64(0.4426229508196721),
#     'threshold': np.float64(0.5055461354643862)},
#    {'model': SVC(class_weight={0: np.float64(0.769), 1: np.float64(0.23099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0703125),
#     'tpr': np.float64(0.45081967213114754),
#     'threshold': np.float64(0.517293914169619)},
#    {'model': SVC(class_weight={0: np.float64(0.5390000000000001),
#                       1: np.float64(0.4609999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.1171875),
#     'tpr': np.float64(0.4672131147540984),
#     'threshold': np.float64(0.5148699501527085)},
#    {'model': SVC(class_weight={0: np.float64(0.7290000000000001),
#                       1: np.float64(0.27099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.125),
#     'tpr': np.float64(0.47540983606557374),
#     'threshold': np.float64(0.5250289174320962)},
#    {'model': SVC(class_weight={0: np.float64(0.769), 1: np.float64(0.23099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.1640625),
#     'tpr': np.float64(0.48360655737704916),
#     'threshold': np.float64(0.5129237872049347)},
#    {'model': SVC(class_weight={0: np.float64(0.7290000000000001),
#                       1: np.float64(0.27099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.1875),
#     'tpr': np.float64(0.4918032786885246),
#     'threshold': np.float64(0.5210154346053011)},
#    {'model': SVC(class_weight={0: np.float64(0.769), 1: np.float64(0.23099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.234375),
#     'tpr': np.float64(0.5),
#     'threshold': np.float64(0.5108423972806764)},
#    {'model': SVC(class_weight={0: np.float64(0.869), 1: np.float64(0.13099999999999998)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.3203125),
#     'tpr': np.float64(0.5081967213114754),
#     'threshold': np.float64(0.5632825225515075)},
#    {'model': SVC(class_weight={0: np.float64(0.759), 1: np.float64(0.24099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.421875),
#     'tpr': np.float64(0.5163934426229508),
#     'threshold': np.float64(0.5076110999117919)},
#    {'model': SVC(class_weight={0: np.float64(0.12900000000000011),
#                       1: np.float64(0.8709999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.4921875),
#     'tpr': np.float64(0.8360655737704918),
#     'threshold': np.float64(0.4892367991683024)},
#    {'model': SVC(class_weight={0: np.float64(0.4890000000000001),
#                       1: np.float64(0.5109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(0.9262295081967213),
#     'threshold': np.float64(0.4934006291544552)},
#    {'model': SVC(class_weight={0: np.float64(0.4990000000000001),
#                       1: np.float64(0.5009999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.515625),
#     'tpr': np.float64(0.9344262295081968),
#     'threshold': np.float64(0.4932976908466826)},
#    {'model': SVC(class_weight={0: np.float64(0.4890000000000001),
#                       1: np.float64(0.5109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.53125),
#     'tpr': np.float64(0.9426229508196722),
#     'threshold': np.float64(0.49091482658456326)},
#    {'model': SVC(class_weight={0: np.float64(0.4990000000000001),
#                       1: np.float64(0.5009999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.546875),
#     'tpr': np.float64(0.9508196721311475),
#     'threshold': np.float64(0.4910844229653358)},
#    {'model': SVC(class_weight={0: np.float64(0.959), 1: np.float64(0.040999999999999995)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5546875),
#     'tpr': np.float64(0.9918032786885246),
#     'threshold': np.float64(0.49422274499227214)},
#    {'model': SVC(class_weight={0: np.float64(0.39900000000000013),
#                       1: np.float64(0.6009999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.609375),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.4913391715683879)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': SVC(class_weight={0: np.float64(0.5190000000000001),
#                       1: np.float64(0.4809999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.3787878787878788),
#     'threshold': np.float64(0.49125804641753695)},
#    {'model': SVC(class_weight={0: np.float64(0.5790000000000001),
#                       1: np.float64(0.42099999999999993)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.00847457627118644),
#     'tpr': np.float64(0.44696969696969696),
#     'threshold': np.float64(0.4909196310452359)},
#    {'model': SVC(class_weight={0: np.float64(0.5790000000000001),
#                       1: np.float64(0.42099999999999993)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.01694915254237288),
#     'tpr': np.float64(0.4772727272727273),
#     'threshold': np.float64(0.49087044628009796)},
#    {'model': SVC(class_weight={0: np.float64(0.5790000000000001),
#                       1: np.float64(0.42099999999999993)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.03389830508474576),
#     'tpr': np.float64(0.48484848484848486),
#     'threshold': np.float64(0.4908157965050159)},
#    {'model': SVC(class_weight={0: np.float64(0.969), 1: np.float64(0.030999999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.06779661016949153),
#     'tpr': np.float64(0.49242424242424243),
#     'threshold': np.float64(0.5513266851474226)},
#    {'model': SVC(class_weight={0: np.float64(0.039000000000000146),
#                       1: np.float64(0.9609999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.07627118644067797),
#     'tpr': np.float64(0.5075757575757576),
#     'threshold': np.float64(0.49412451292007553)},
#    {'model': SVC(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.1016949152542373),
#     'tpr': np.float64(0.5151515151515151),
#     'threshold': np.float64(0.7273209584081026)},
#    {'model': SVC(class_weight={0: np.float64(0.5990000000000001),
#                       1: np.float64(0.4009999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.11864406779661017),
#     'tpr': np.float64(0.5303030303030303),
#     'threshold': np.float64(0.49110564224990555)},
#    {'model': SVC(class_weight={0: np.float64(0.969), 1: np.float64(0.030999999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.211864406779661),
#     'tpr': np.float64(0.5378787878787878),
#     'threshold': np.float64(0.5258012950694338)},
#    {'model': SVC(class_weight={0: np.float64(0.7390000000000001),
#                       1: np.float64(0.26099999999999995)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.4830508474576271),
#     'tpr': np.float64(0.553030303030303),
#     'threshold': np.float64(0.4907034918229612)},
#    {'model': SVC(class_weight={0: np.float64(0.17900000000000016),
#                       1: np.float64(0.8209999999999998)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.4915254237288136),
#     'tpr': np.float64(0.8409090909090909),
#     'threshold': np.float64(0.4902698561763981)},
#    {'model': SVC(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(0.8712121212121212),
#     'threshold': np.float64(0.4875624922310965)},
#    {'model': SVC(class_weight={0: np.float64(0.44900000000000007),
#                       1: np.float64(0.5509999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5084745762711864),
#     'tpr': np.float64(0.9318181818181818),
#     'threshold': np.float64(0.48106391511300695)},
#    {'model': SVC(class_weight={0: np.float64(0.4590000000000001),
#                       1: np.float64(0.5409999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5169491525423728),
#     'tpr': np.float64(0.9393939393939394),
#     'threshold': np.float64(0.48170180809181734)},
#    {'model': SVC(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.5254237288135594),
#     'tpr': np.float64(0.946969696969697),
#     'threshold': np.float64(0.48646581151267726)},
#    {'model': SVC(class_weight={0: np.float64(0.44900000000000007),
#                       1: np.float64(0.5509999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5338983050847458),
#     'tpr': np.float64(0.9621212121212122),
#     'threshold': np.float64(0.4787394302124362)},
#    {'model': SVC(class_weight={0: np.float64(0.40900000000000014),
#                       1: np.float64(0.5909999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5423728813559322),
#     'tpr': np.float64(0.9772727272727273),
#     'threshold': np.float64(0.48693875119968744)},
#    {'model': SVC(class_weight={0: np.float64(0.929), 1: np.float64(0.071)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.5677966101694916),
#     'tpr': np.float64(0.9848484848484849),
#     'threshold': np.float64(0.4785074600425507)},
#    {'model': SVC(class_weight={0: np.float64(0.4590000000000001),
#                       1: np.float64(0.5409999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5847457627118644),
#     'tpr': np.float64(0.9924242424242424),
#     'threshold': np.float64(0.4763620097774128)},
#    {'model': SVC(class_weight={0: np.float64(0.32900000000000007),
#                       1: np.float64(0.6709999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.6779661016949152),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.4882134981518959)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': SVC(class_weight={0: np.float64(0.889), 1: np.float64(0.11099999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.34615384615384615),
#     'threshold': np.float64(0.49389017507235716)},
#    {'model': SVC(class_weight={0: np.float64(0.7390000000000001),
#                       1: np.float64(0.26099999999999995)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.008333333333333333),
#     'tpr': np.float64(0.36153846153846153),
#     'threshold': np.float64(0.5286159798736322)},
#    {'model': SVC(class_weight={0: np.float64(0.609), 1: np.float64(0.39099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.016666666666666666),
#     'tpr': np.float64(0.45384615384615384),
#     'threshold': np.float64(0.490685833226064)},
#    {'model': SVC(class_weight={0: np.float64(0.15900000000000014),
#                       1: np.float64(0.8409999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.025),
#     'tpr': np.float64(0.5230769230769231),
#     'threshold': np.float64(0.5099017822049379)},
#    {'model': SVC(class_weight={0: np.float64(0.15900000000000014),
#                       1: np.float64(0.8409999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.03333333333333333),
#     'tpr': np.float64(0.5384615384615384),
#     'threshold': np.float64(0.5089973666394227)},
#    {'model': SVC(class_weight={0: np.float64(0.609), 1: np.float64(0.39099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.06666666666666667),
#     'tpr': np.float64(0.5461538461538461),
#     'threshold': np.float64(0.4903412642534628)},
#    {'model': SVC(class_weight={0: np.float64(0.15900000000000014),
#                       1: np.float64(0.8409999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.075),
#     'tpr': np.float64(0.5538461538461539),
#     'threshold': np.float64(0.5071444345771885)},
#    {'model': SVC(class_weight={0: np.float64(0.15900000000000014),
#                       1: np.float64(0.8409999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.09166666666666666),
#     'tpr': np.float64(0.5615384615384615),
#     'threshold': np.float64(0.5065312915367668)},
#    {'model': SVC(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.1),
#     'tpr': np.float64(0.5692307692307692),
#     'threshold': np.float64(0.595309807104556)},
#    {'model': SVC(class_weight={0: np.float64(0.989), 1: np.float64(0.011)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.18333333333333332),
#     'tpr': np.float64(0.5769230769230769),
#     'threshold': np.float64(0.5606147682281525)},
#    {'model': SVC(class_weight={0: np.float64(0.559), 1: np.float64(0.44099999999999995)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.2833333333333333),
#     'tpr': np.float64(0.5846153846153846),
#     'threshold': np.float64(0.4946642354684879)},
#    {'model': SVC(class_weight={0: np.float64(0.1090000000000001),
#                       1: np.float64(0.8909999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.4166666666666667),
#     'tpr': np.float64(0.5923076923076923),
#     'threshold': np.float64(0.4915656743885158)},
#    {'model': SVC(class_weight={0: np.float64(0.679), 1: np.float64(0.32099999999999995)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.45),
#     'tpr': np.float64(0.6692307692307692),
#     'threshold': np.float64(0.4932165153568606)},
#    {'model': SVC(class_weight={0: np.float64(0.26900000000000013),
#                       1: np.float64(0.7309999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.4583333333333333),
#     'tpr': np.float64(0.8769230769230769),
#     'threshold': np.float64(0.4863445489374498)},
#    {'model': SVC(class_weight={0: np.float64(0.12900000000000011),
#                       1: np.float64(0.8709999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.475),
#     'tpr': np.float64(0.9230769230769231),
#     'threshold': np.float64(0.43815672380350557)},
#    {'model': SVC(class_weight={0: np.float64(0.4890000000000001),
#                       1: np.float64(0.5109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.48333333333333334),
#     'tpr': np.float64(0.9692307692307692),
#     'threshold': np.float64(0.4912509360814237)},
#    {'model': SVC(class_weight={0: np.float64(0.4890000000000001),
#                       1: np.float64(0.5109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5),
#     'tpr': np.float64(0.9769230769230769),
#     'threshold': np.float64(0.4910325381455602)},
#    {'model': SVC(class_weight={0: np.float64(0.3690000000000001),
#                       1: np.float64(0.6309999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5083333333333333),
#     'tpr': np.float64(0.9846153846153847),
#     'threshold': np.float64(0.4784790986271096)},
#    {'model': SVC(class_weight={0: np.float64(0.3890000000000001),
#                       1: np.float64(0.6109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5416666666666666),
#     'tpr': np.float64(0.9923076923076923),
#     'threshold': np.float64(0.4815102870806663)},
#    {'model': SVC(class_weight={0: np.float64(0.29900000000000015),
#                       1: np.float64(0.7009999999999998)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5833333333333334),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.40252390808182)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}],
#   [{'model': SVC(class_weight={0: np.float64(0.7090000000000001), 1: np.float64(0.291)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.3879310344827586),
#     'threshold': np.float64(0.5234487264139519)},
#    {'model': SVC(class_weight={0: np.float64(0.7090000000000001), 1: np.float64(0.291)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.007462686567164179),
#     'tpr': np.float64(0.4396551724137931),
#     'threshold': np.float64(0.5221037846001751)},
#    {'model': SVC(class_weight={0: np.float64(0.7290000000000001),
#                       1: np.float64(0.27099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.014925373134328358),
#     'tpr': np.float64(0.45689655172413796),
#     'threshold': np.float64(0.5268745318520718)},
#    {'model': SVC(class_weight={0: np.float64(0.639), 1: np.float64(0.36099999999999993)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.022388059701492536),
#     'tpr': np.float64(0.46551724137931033),
#     'threshold': np.float64(0.5132228867999357)},
#    {'model': SVC(class_weight={0: np.float64(0.639), 1: np.float64(0.36099999999999993)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.029850746268656716),
#     'tpr': np.float64(0.47413793103448276),
#     'threshold': np.float64(0.5130923472951858)},
#    {'model': SVC(class_weight={0: np.float64(0.7290000000000001),
#                       1: np.float64(0.27099999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.08208955223880597),
#     'tpr': np.float64(0.4827586206896552),
#     'threshold': np.float64(0.5214450535638854)},
#    {'model': SVC(class_weight={0: np.float64(0.8190000000000001),
#                       1: np.float64(0.18099999999999997)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.11194029850746269),
#     'tpr': np.float64(0.49137931034482757),
#     'threshold': np.float64(0.5383351612541823)},
#    {'model': SVC(class_weight={0: np.float64(0.7090000000000001), 1: np.float64(0.291)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.14925373134328357),
#     'tpr': np.float64(0.5086206896551724),
#     'threshold': np.float64(0.5156262112229996)},
#    {'model': SVC(class_weight={0: np.float64(0.8190000000000001),
#                       1: np.float64(0.18099999999999997)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.291044776119403),
#     'tpr': np.float64(0.5172413793103449),
#     'threshold': np.float64(0.5225800367524124)},
#    {'model': SVC(class_weight={0: np.float64(0.959), 1: np.float64(0.040999999999999995)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.4626865671641791),
#     'tpr': np.float64(0.7155172413793104),
#     'threshold': np.float64(0.5118092873367327)},
#    {'model': SVC(class_weight={0: np.float64(0.009000000000000119),
#                       1: np.float64(0.9909999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.4701492537313433),
#     'tpr': np.float64(0.7413793103448276),
#     'threshold': np.float64(0.5117291873317124)},
#    {'model': SVC(class_weight={0: np.float64(0.969), 1: np.float64(0.030999999999999996)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.47761194029850745),
#     'tpr': np.float64(0.7672413793103449),
#     'threshold': np.float64(0.5144628442898393)},
#    {'model': SVC(class_weight={0: np.float64(0.3890000000000001),
#                       1: np.float64(0.6109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.48507462686567165),
#     'tpr': np.float64(0.9396551724137931),
#     'threshold': np.float64(0.510314132806765)},
#    {'model': SVC(class_weight={0: np.float64(0.4890000000000001),
#                       1: np.float64(0.5109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5074626865671642),
#     'tpr': np.float64(0.9568965517241379),
#     'threshold': np.float64(0.5052665865952272)},
#    {'model': SVC(class_weight={0: np.float64(0.049000000000000155),
#                       1: np.float64(0.9509999999999998)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5223880597014925),
#     'tpr': np.float64(0.9741379310344828),
#     'threshold': np.float64(0.47394948149142585)},
#    {'model': SVC(class_weight={0: np.float64(0.08900000000000019),
#                       1: np.float64(0.9109999999999998)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5447761194029851),
#     'tpr': np.float64(0.9913793103448276),
#     'threshold': np.float64(0.5111528420829499)},
#    {'model': SVC(class_weight={0: np.float64(0.3890000000000001),
#                       1: np.float64(0.6109999999999999)},
#         kernel='linear', probability=True, random_state=42),
#     'fpr': np.float64(0.5895522388059702),
#     'tpr': np.float64(1.0),
#     'threshold': np.float64(0.508824719921254)},
#    {'model': 'end', 'fpr': 1.0, 'tpr': 1.0, 'threshold': 0.0}]],
#  'weighted_clfs': [[{'model': SVC(class_weight={0: np.float64(0.999), 1: np.float64(0.001)}, kernel='linear',
#         probability=True, random_state=42),
#     'fpr': np.float64(0.0),
#     'tpr': np.float64(0.0),
#     'threshold': 0.5,
#     'full_roc': {'fpr': array([0.       , 0.0078125, 0.328125 , 0.328125 , 0.3671875, 0.3671875,
#             0.40625  , 0.40625  , 0.4375   , 0.4375   , 0.4453125, 0.4453125,
#             0.453125 , 0.453125 , 0.4921875, 0.4921875, 0.5078125, 0.5078125,
#             0.515625 , 0.515625 , 0.5234375, 0.5234375, 0.53125  , 0.53125  ,
#             0.5390625, 0.5390625, 0.5625   , 0.5625   , 0.5859375, 0.5859375,
#          0.51628455, 0.51614133, 0.51613808, 0.51610383, 0.51604183,
#          0.51551503, 0.51455002, 0.5144776 , 0.51429423, 0.51380381,
#          0.51374178, 0.51365666, 0.51253962, 0.51249506, 0.51219016,
#          0.51214193, 0.51081385, 0.5108133 , 0.50978238, 0.5097431 ,
#          0.50845758, 0.5082738 , 0.50825348, 0.50822873, 0.50503996,
#          0.5       , 0.49190767, 0.49189765, 0.49093149, 0.49090253,
#          0.49000546, 0.48998914, 0.48955617, 0.48951222, 0.48902932,
#          0.48791998, 0.48744492, 0.48742716, 0.48692279, 0.48690262,
#          0.48662373, 0.48639858, 0.48592363, 0.48568532, 0.4853562 ,
#          0.48482736, 0.48470235, 0.48458508, 0.48418792, 0.48378626,
#          0.48377919, 0.48369917, 0.48350205, 0.48294366, 0.48288568,
#          0.47945147, 0.47913979, 0.47875247, 0.47869836, 0.4777253 ,
#          0.47749743, 0.47347218, 0.47331883, 0.47260481, 0.47245047,
#          0.452733  ]),
#   'name': 'SVM Regression',
#   'auc': np.float64(0.46321111111111113),
#   'model': SVC(kernel='linear', probability=True, random_state=42)},
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x7efe97067320>}

# %% [markdown]
# # Load from pickle

# %%
from predict_ensemble_and_evaluate import save_to_pickle, load_from_pickle
from predict_ensemble_and_evaluate import predict_ensemble_and_evaluate
from predict_ensemble_and_evaluate import plot_roc_comparison
from predict_ensemble_and_evaluate import make_curve_monotonic

# Load the data
list_folds_best_models, list_folds_weighted_clfs, results_original_roc, test_loader = load_from_pickle(filename='pickle/SVM_data1_weighted.pkl')
# Out:
# Data loaded successfully.

# %% [markdown]
# ### Ensemble prediction using voting

# %%
import numpy as np

# --- Loop through all the FPR values to generate the ensemble ROC curve ---



results_tuple, prior_proba = predict_ensemble_and_evaluate(list_folds_best_models=list_folds_best_models,
    test_loader=test_loader)

ensemble_results_soft = results_tuple['soft_voting']
ensemble_results_hard = results_tuple['hard_voting']
misclassification_risk = results_tuple['misclassification_risk']
# Out:
# Creating a single ensemble from 82 models across all folds.
# Extracting full dataset...
# Getting predictions from all models...
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>
# Warning: Skipping model of unsupported type: <class 'str'>

# %% [markdown]
# ## Load NP curve pickle

# %%
from predict_ensemble_and_evaluate import load_from_pickle_constrained_roc

# Load the constrained ROC curve results
constrained_points = load_from_pickle_constrained_roc(filename='pickle/SVM_Data1_NP_roc_curve.pkl')
# Out:
# Constrained ROC curve points loaded from pickle/SVM_Data1_NP_roc_curve.pkl

# %%
# plot the best classifiers of all folds
results_lists = []
results_lists.extend(list_folds_best_models)
results_lists.extend(list_folds_weighted_clfs)
results_lists.append(constrained_points)
results_lists.append(ensemble_results_hard)
results_lists.append(misclassification_risk)


# --- Plot the final comparison ---
print("\n--- Plotting all ROC curves for comparison ---")
plot_roc_comparison(
    results_lists=results_lists,
    names=["MaxROCFold 1", "MaxROCFold 2", "MaxROCFold 3", "MaxROCFold 4", "Weighted1", "Weighted2", "Weighted3", "Weighted4", "Neyman_Pearson", "Ensemble_voting_hard", "Misclassification_Risk"],
    results_original_roc=results_original_roc, plot_name="SVM_weighted_data1", prior_prob=prior_proba
)
# Out:
# --- Plotting all ROC curves for comparison ---
